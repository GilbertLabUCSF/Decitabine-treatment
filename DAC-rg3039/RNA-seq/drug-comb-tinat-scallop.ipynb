# %% [markdown]
# here I'm using a custom [scallop](https://github.com/Kingsford-Group/scallop) + [gtfmerge](https://github.com/Kingsford-Group/rnaseqtools#gtfmerge) pipeline to create merged gtf annotation of hg19 and tinat transcripts introduced in this
#
# Alex
# > I was curious myself so I decided to align our RNA-seq data to their chimeric transcripts... it looks promising, but let me know if there's anything in my analysis I need to change. Still working on seeing if we can identify alternative TSS without CAGE-seq.
# I'm guessing we can look for novel transcripts using [StringTie](https://ccb.jhu.edu/software/stringtie/) or cufflinks?
#
# Ray
# > I'm asking because in [this paper](https://www.nature.com/articles/ng.3889) they treated lung cancer cells with decitabine and performed Cage-seq to map and identify cryptic transcription start sites. They found cryptic TSSs that generated spliced variants, half of which were in-frame isoforms (and some of which resulted in chimeric transcripts, others original or truncated). This got me thinking about our project and whether we could see these chimeric/fusion transcripts (that are skewed toward the 5'end due Cage-seq and being TSS-induced) in HL60s.
#
#
# Luke
# > Hi Ray, Alex and Abe
# This is an interesting paper which claims genetic alterations to DNA methylation core genes drive dysregulated hematopoietic development due to CpG changes that regulate transcription factor binding (figure 4 and 5). How many TFs are methylation sensitive has been controversial in my understanding but is an interesting idea with lots of data within mylomonocytic cells. https://www.nature.com/articles/s41588-020-0595-4
# I am not suggesting a specific plan but this is an interesting idea.
#
# ___
# last update
#
#     Thu Oct 21 01:06:19 UTC 2021

# %%
# %%bash
# mkdir -p tinat/
# mkdir -p tinat/quants
#
# for f in fastq/*; do
# 	f=`basename $f`;
# 	o=${f/.fastq.gz/};
# 	echo $o
# 	echo `date`
#     salmon quant \
#         -i ../../scallop-genome/salmon.index -l A \
#         -r fastq/$f -o tinat/quants/$o -p 10;
# 	echo `date`
# done
# Out:
# hl60_combination_1
# Tue Aug 30 21:49:41 PDT 2022
# Tue Aug 30 21:51:41 PDT 2022
# hl60_combination_2
# Tue Aug 30 21:51:41 PDT 2022
# Tue Aug 30 21:54:08 PDT 2022
# hl60_decitabine_1
# Tue Aug 30 21:54:08 PDT 2022
# Tue Aug 30 21:55:31 PDT 2022
# hl60_decitabine_2
# Tue Aug 30 21:55:31 PDT 2022
# Tue Aug 30 21:56:59 PDT 2022
# hl60_dmso_1
# Tue Aug 30 21:56:59 PDT 2022
# Tue Aug 30 21:59:10 PDT 2022
# hl60_dmso_2
# Tue Aug 30 21:59:10 PDT 2022
# Tue Aug 30 22:00:23 PDT 2022
# hl60_rg3039_1
# Tue Aug 30 22:00:23 PDT 2022
# Tue Aug 30 22:01:39 PDT 2022
# hl60_rg3039_2
# Tue Aug 30 22:01:39 PDT 2022
# Tue Aug 30 22:03:40 PDT 2022
# Version Info: Could not resolve upgrade information in the alotted time.
# Check for upgrades manually at https://combine-lab.github.io/salmon
# ### salmon (mapping-based) v1.2.1
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { ../../scallop-genome/salmon.index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { fastq/hl60_combination_1.fastq.gz }
# ### [ output ] => { tinat/quants/hl60_combination_1 }
# ### [ threads ] => { 10 }
# Logs will be written to tinat/quants/hl60_combination_1/logs
# [2022-08-30 21:49:42.942] [jointLog] [info] setting maxHashResizeThreads to 10
# [2022-08-30 21:49:42.942] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2022-08-30 21:49:42.942] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2022-08-30 21:49:42.942] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2022-08-30 21:49:42.942] [jointLog] [info] parsing read library format
# [2022-08-30 21:49:42.942] [jointLog] [info] There is 1 library.
# [2022-08-30 21:49:43.018] [jointLog] [info] Loading pufferfish index
# [2022-08-30 21:49:43.019] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 275.34 ms
# -----------------------------------------
# size = 629063
# -----------------------------------------
# | Loading contig offsets | Time = 1.5411 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 501.87 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 48.624 ms
# -----------------------------------------
# size = 119911194
# Number of ones: 629062
# Number of ones per inventory item: 512
# Inventory entries filled: 1229
# -----------------------------------------
# | Loading contig boundaries | Time = 294.29 ms
# -----------------------------------------
# size = 119911194
# -----------------------------------------
# | Loading sequence | Time = 22.44 ms
# -----------------------------------------
# size = 101039334
# -----------------------------------------
# | Loading positions | Time = 178.12 ms
# -----------------------------------------
# size = 203602945
# -----------------------------------------
# | Loading reference sequence | Time = 25.084 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 551 us
# -----------------------------------------
#
#
#
#
# [2022-08-30 21:49:43.867] [jointLog] [info] done
# [2022-08-30 21:49:43.867] [jointLog] [info] Index contained 84,038 targets
# [2022-08-30 21:49:43.888] [jointLog] [info] Number of decoys : 0
# [2022-08-30 21:49:44.251] [jointLog] [info] Automatically detected most likely library type as SF
# processed 500,002 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# processed 5,000,000 fragments
# processed 5,500,000 fragments
# processed 6,000,000 fragments
# processed 6,500,000 fragments
# processed 7,000,000 fragments
# processed 7,500,000 fragments
# processed 8,000,000 fragments
# processed 8,500,001 fragments
# processed 9,000,002 fragments
# processed 9,500,000 fragments
# processed 10,000,000 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,000 fragments
# processed 13,000,000 fragments
# processed 13,500,000 fragments
# processed 14,000,000 fragments
# processed 14,500,002 fragments
# processed 15,000,000 fragments
# processed 15,500,001 fragments
# processed 16,000,000 fragments
# processed 16,500,000 fragments
# processed 17,000,000 fragments
# processed 17,500,001 fragments
# processed 18,000,000 fragments
# processed 18,500,000 fragments
# processed 19,000,000 fragments
# processed 19,500,000 fragments
# processed 20,000,000 fragments
# processed 20,500,000 fragments
# processed 21,000,001 fragments
# processed 21,500,000 fragments
# processed 22,000,000 fragments
# processed 22,000,014 fragments
# processed 22,500,000 fragments
# processed 23,000,000 fragments
# processed 23,500,001 fragments
# processed 24,000,000 fragments
# processed 24,500,000 fragments
# processed 25,000,000 fragments
# processed 25,500,000 fragments
# processed 26,000,000 fragments
# processed 26,500,000 fragments
# processed 27,000,000 fragments
# processed 27,500,001 fragments
# processed 28,000,001 fragments
# processed 28,500,000 fragments
# processed 29,000,000 fragments
# processed 29,500,000 fragments
# processed 30,000,000 fragments
# processed 30,500,000 fragments
# processed 31,000,000 fragments
# processed 31,500,000 fragments
# processed 32,000,000 fragments
# processed 32,500,000 fragments
# processed 33,000,001 fragments
# processed 33,500,000 fragments
# processed 34,000,000 fragments
# processed 34,500,000 fragments
# processed 35,000,001 fragments
# processed 35,500,000 fragments
# processed 36,000,000 fragments
# processed 36,500,000 fragments
# processed 37,000,000 fragments
# processed 37,500,000 fragments
# processed 38,000,000 fragments
# processed 38,500,000 fragments
# processed 39,000,000 fragments
# processed 39,500,000 fragments
# processed 40,000,000 fragments
# processed 40,500,000 fragments
# processed 41,000,000 fragments
# hits: 101,264,395; hits per frag:  2.47177
#
#
#
#
#
#
#
# [2022-08-30 21:51:06.990] [jointLog] [info] Thread saw mini-batch with a maximum of 0.98% zero probability fragments
# [2022-08-30 21:51:07.002] [jointLog] [info] Thread saw mini-batch with a maximum of 0.92% zero probability fragments
# [2022-08-30 21:51:07.003] [jointLog] [info] Thread saw mini-batch with a maximum of 0.94% zero probability fragments
# [2022-08-30 21:51:07.017] [jointLog] [info] Thread saw mini-batch with a maximum of 0.98% zero probability fragments
# [2022-08-30 21:51:07.023] [jointLog] [info] Thread saw mini-batch with a maximum of 0.96% zero probability fragments
# [2022-08-30 21:51:07.027] [jointLog] [info] Thread saw mini-batch with a maximum of 0.96% zero probability fragments
# [2022-08-30 21:51:07.042] [jointLog] [info] Thread saw mini-batch with a maximum of 1.02% zero probability fragments
# [2022-08-30 21:51:07.045] [jointLog] [info] Thread saw mini-batch with a maximum of 0.94% zero probability fragments
# [2022-08-30 21:51:07.047] [jointLog] [info] Thread saw mini-batch with a maximum of 0.90% zero probability fragments
# [2022-08-30 21:51:07.079] [jointLog] [info] Thread saw mini-batch with a maximum of 0.96% zero probability fragments
# [2022-08-30 21:51:07.369] [jointLog] [info] Computed 197,998 rich equivalence classes for further processing
# [2022-08-30 21:51:07.369] [jointLog] [info] Counted 28,008,386 total reads in the equivalence classes
# [2022-08-30 21:51:07.377] [jointLog] [info] Number of mappings discarded because of alignment score : 76,873,607
# [2022-08-30 21:51:07.377] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 666,645
# [2022-08-30 21:51:07.377] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2022-08-30 21:51:07.377] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 0
# [2022-08-30 21:51:07.377] [jointLog] [info] Mapping rate = 67.8882%
#
# [2022-08-30 21:51:07.377] [jointLog] [info] finished quantifyLibrary()
# [2022-08-30 21:51:07.379] [jointLog] [info] Starting optimizer
# [2022-08-30 21:51:08.610] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2022-08-30 21:51:08.632] [jointLog] [info] iteration = 0 | max rel diff. = 14638.8
# [2022-08-30 21:51:10.327] [jointLog] [info] iteration = 100 | max rel diff. = 18.399
# [2022-08-30 21:51:12.026] [jointLog] [info] iteration = 200 | max rel diff. = 10.8229
# [2022-08-30 21:51:13.681] [jointLog] [info] iteration = 300 | max rel diff. = 8.55646
# [2022-08-30 21:51:15.341] [jointLog] [info] iteration = 400 | max rel diff. = 1.74675
# [2022-08-30 21:51:16.999] [jointLog] [info] iteration = 500 | max rel diff. = 7.58929
# [2022-08-30 21:51:18.657] [jointLog] [info] iteration = 600 | max rel diff. = 0.38465
# [2022-08-30 21:51:20.315] [jointLog] [info] iteration = 700 | max rel diff. = 0.134231
# [2022-08-30 21:51:21.969] [jointLog] [info] iteration = 800 | max rel diff. = 0.961179
# [2022-08-30 21:51:23.625] [jointLog] [info] iteration = 900 | max rel diff. = 1.74031
# [2022-08-30 21:51:25.283] [jointLog] [info] iteration = 1,000 | max rel diff. = 0.360116
# [2022-08-30 21:51:26.942] [jointLog] [info] iteration = 1,100 | max rel diff. = 0.0548406
# [2022-08-30 21:51:28.595] [jointLog] [info] iteration = 1,200 | max rel diff. = 0.0328684
# [2022-08-30 21:51:30.266] [jointLog] [info] iteration = 1,300 | max rel diff. = 0.085119
# [2022-08-30 21:51:31.921] [jointLog] [info] iteration = 1,400 | max rel diff. = 0.0968746
# [2022-08-30 21:51:33.573] [jointLog] [info] iteration = 1,500 | max rel diff. = 0.0944883
# [2022-08-30 21:51:35.230] [jointLog] [info] iteration = 1,600 | max rel diff. = 0.0197353
# [2022-08-30 21:51:36.890] [jointLog] [info] iteration = 1,700 | max rel diff. = 0.0229131
# [2022-08-30 21:51:38.546] [jointLog] [info] iteration = 1,800 | max rel diff. = 0.0887468
# [2022-08-30 21:51:40.204] [jointLog] [info] iteration = 1,900 | max rel diff. = 0.0581491
# [2022-08-30 21:51:40.500] [jointLog] [info] iteration = 1,919 | max rel diff. = 0.00926557
# [2022-08-30 21:51:40.503] [jointLog] [info] Finished optimizer
# [2022-08-30 21:51:40.503] [jointLog] [info] writing output
#
# Version Info: Could not resolve upgrade information in the alotted time.
# Check for upgrades manually at https://combine-lab.github.io/salmon
# ### salmon (mapping-based) v1.2.1
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { ../../scallop-genome/salmon.index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { fastq/hl60_combination_2.fastq.gz }
# ### [ output ] => { tinat/quants/hl60_combination_2 }
# ### [ threads ] => { 10 }
# Logs will be written to tinat/quants/hl60_combination_2/logs
# [2022-08-30 21:51:42.939] [jointLog] [info] setting maxHashResizeThreads to 10
# [2022-08-30 21:51:42.939] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2022-08-30 21:51:42.939] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2022-08-30 21:51:42.939] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2022-08-30 21:51:42.939] [jointLog] [info] parsing read library format
# [2022-08-30 21:51:42.939] [jointLog] [info] There is 1 library.
# [2022-08-30 21:51:43.010] [jointLog] [info] Loading pufferfish index
# [2022-08-30 21:51:43.010] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 262.61 ms
# -----------------------------------------
# size = 629063
# -----------------------------------------
# | Loading contig offsets | Time = 1.8557 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 462.85 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 44.33 ms
# -----------------------------------------
# size = 119911194
# Number of ones: 629062
# Number of ones per inventory item: 512
# Inventory entries filled: 1229
# -----------------------------------------
# | Loading contig boundaries | Time = 239.59 ms
# -----------------------------------------
# size = 119911194
# -----------------------------------------
# | Loading sequence | Time = 14.974 ms
# -----------------------------------------
# size = 101039334
# -----------------------------------------
# | Loading positions | Time = 145.14 ms
# -----------------------------------------
# size = 203602945
# -----------------------------------------
# | Loading reference sequence | Time = 22.763 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 507.06 us
# -----------------------------------------
#
#
#
#
# [2022-08-30 21:51:43.745] [jointLog] [info] done
# [2022-08-30 21:51:43.745] [jointLog] [info] Index contained 84,038 targets
# [2022-08-30 21:51:43.767] [jointLog] [info] Number of decoys : 0
# [2022-08-30 21:51:44.101] [jointLog] [info] Automatically detected most likely library type as SF
# processed 500,003 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# processed 5,000,000 fragments
# processed 5,500,000 fragments
# processed 6,000,000 fragments
# processed 7,000,000 fragments
# processed 7,500,000 fragments
# processed 8,000,000 fragments
# processed 8,500,003 fragments
# processed 9,000,000 fragments
# processed 9,500,000 fragments
# processed 10,000,000 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,000 fragments
# processed 13,000,000 fragments
# processed 13,500,000 fragments
# processed 14,000,000 fragments
# processed 14,500,000 fragments
# processed 15,000,000 fragments
# processed 15,500,000 fragments
# processed 16,000,000 fragments
# processed 16,500,000 fragments
# processed 17,000,000 fragments
# processed 17,500,000 fragments
# processed 18,000,000 fragments
# processed 18,500,000 fragments
# processed 19,000,000 fragments
# processed 19,500,000 fragments
# processed 20,000,000 fragments
# processed 20,500,000 fragments
# processed 21,000,000 fragments
# processed 21,500,000 fragments
# processed 22,000,000 fragments
# processed 22,500,000 fragments
# processed 23,000,000 fragments
# processed 23,500,002 fragments
# processed 24,000,000 fragments
# processed 24,500,001 fragments
# processed 25,000,000 fragments
# processed 25,500,000 fragments
# processed 26,000,000 fragments
# processed 26,500,000 fragments
# processed 27,000,000 fragments
# processed 27,500,001 fragments
# processed 28,000,001 fragments
# processed 28,500,000 fragments
# processed 29,000,000 fragments
# processed 29,500,000 fragments
# processed 30,000,000 fragments
# processed 30,500,001 fragments
# processed 31,000,000 fragments
# processed 31,500,001 fragments
# processed 32,000,000 fragments
# processed 32,500,000 fragments
# processed 33,000,000 fragments
# processed 33,500,000 fragments
# processed 34,000,000 fragments
# processed 34,500,000 fragments
# processed 35,000,000 fragments
# processed 35,500,000 fragments
# processed 36,000,000 fragments
# processed 36,500,001 fragments
# processed 37,000,000 fragments
# processed 37,500,000 fragments
# processed 38,000,000 fragments
# processed 38,500,000 fragments
# processed 39,000,000 fragments
# processed 39,500,000 fragments
# processed 40,000,000 fragments
# processed 40,500,000 fragments
# processed 41,000,000 fragments
# processed 41,500,000 fragments
# processed 42,000,001 fragments
# processed 42,500,000 fragments
# processed 43,000,000 fragments
# processed 43,500,000 fragments
# processed 44,000,000 fragments
# processed 44,500,000 fragments
# processed 45,000,000 fragments
# processed 45,500,000 fragments
# processed 46,000,000 fragments
# processed 46,500,001 fragments
# processed 47,000,000 fragments
# processed 47,500,000 fragments
# processed 48,000,000 fragments
# processed 48,500,000 fragments
# processed 49,000,000 fragments
# processed 49,500,000 fragments
# processed 50,000,000 fragments
# processed 50,500,000 fragments
# hits: 120,214,108; hits per frag:  2.3811[2022-08-30 21:53:18.652] [jointLog] [info] Thread saw mini-batch with a maximum of 1.08% zero probability fragments
# [2022-08-30 21:53:18.654] [jointLog] [info] Thread saw mini-batch with a maximum of 0.94% zero probability fragments
# [2022-08-30 21:53:18.667] [jointLog] [info] Thread saw mini-batch with a maximum of 0.96% zero probability fragments
# [2022-08-30 21:53:18.683] [jointLog] [info] Thread saw mini-batch with a maximum of 0.90% zero probability fragments
# [2022-08-30 21:53:18.685] [jointLog] [info] Thread saw mini-batch with a maximum of 0.96% zero probability fragments
# [2022-08-30 21:53:18.701] [jointLog] [info] Thread saw mini-batch with a maximum of 1.12% zero probability fragments
# [2022-08-30 21:53:18.716] [jointLog] [info] Thread saw mini-batch with a maximum of 0.92% zero probability fragments
# [2022-08-30 21:53:18.719] [jointLog] [info] Thread saw mini-batch with a maximum of 0.94% zero probability fragments
# [2022-08-30 21:53:18.720] [jointLog] [info] Thread saw mini-batch with a maximum of 0.98% zero probability fragments
# [2022-08-30 21:53:18.730] [jointLog] [info] Thread saw mini-batch with a maximum of 0.90% zero probability fragments
#
#
#
#
#
#
#
#
# [2022-08-30 21:53:19.196] [jointLog] [info] Computed 347,837 rich equivalence classes for further processing
# [2022-08-30 21:53:19.196] [jointLog] [info] Counted 34,322,067 total reads in the equivalence classes
# [2022-08-30 21:53:19.206] [jointLog] [info] Number of mappings discarded because of alignment score : 79,876,255
# [2022-08-30 21:53:19.206] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 1,067,951
# [2022-08-30 21:53:19.206] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2022-08-30 21:53:19.206] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 0
# [2022-08-30 21:53:19.206] [jointLog] [info] Mapping rate = 67.8702%
#
# [2022-08-30 21:53:19.206] [jointLog] [info] finished quantifyLibrary()
# [2022-08-30 21:53:19.208] [jointLog] [info] Starting optimizer
# [2022-08-30 21:53:19.340] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2022-08-30 21:53:19.383] [jointLog] [info] iteration = 0 | max rel diff. = 12768.4
# [2022-08-30 21:53:22.625] [jointLog] [info] iteration = 100 | max rel diff. = 18.9837
# [2022-08-30 21:53:25.782] [jointLog] [info] iteration = 200 | max rel diff. = 1.7837
# [2022-08-30 21:53:28.914] [jointLog] [info] iteration = 300 | max rel diff. = 12.0082
# [2022-08-30 21:53:32.040] [jointLog] [info] iteration = 400 | max rel diff. = 7.65007
# [2022-08-30 21:53:35.161] [jointLog] [info] iteration = 500 | max rel diff. = 0.226589
# [2022-08-30 21:53:38.285] [jointLog] [info] iteration = 600 | max rel diff. = 0.363663
# [2022-08-30 21:53:41.411] [jointLog] [info] iteration = 700 | max rel diff. = 4.1272
# [2022-08-30 21:53:44.551] [jointLog] [info] iteration = 800 | max rel diff. = 0.157064
# [2022-08-30 21:53:47.688] [jointLog] [info] iteration = 900 | max rel diff. = 0.0476826
# [2022-08-30 21:53:50.815] [jointLog] [info] iteration = 1,000 | max rel diff. = 4.5951
# [2022-08-30 21:53:53.937] [jointLog] [info] iteration = 1,100 | max rel diff. = 0.0795377
# [2022-08-30 21:53:57.053] [jointLog] [info] iteration = 1,200 | max rel diff. = 1.11304
# [2022-08-30 21:54:00.224] [jointLog] [info] iteration = 1,300 | max rel diff. = 0.239532
# [2022-08-30 21:54:03.361] [jointLog] [info] iteration = 1,400 | max rel diff. = 0.0430553
# [2022-08-30 21:54:06.470] [jointLog] [info] iteration = 1,500 | max rel diff. = 0.088034
# [2022-08-30 21:54:08.210] [jointLog] [info] iteration = 1,557 | max rel diff. = 0.00814068
# [2022-08-30 21:54:08.213] [jointLog] [info] Finished optimizer
# [2022-08-30 21:54:08.213] [jointLog] [info] writing output
#
# Version Info: Could not resolve upgrade information in the alotted time.
# Check for upgrades manually at https://combine-lab.github.io/salmon
# ### salmon (mapping-based) v1.2.1
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { ../../scallop-genome/salmon.index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { fastq/hl60_decitabine_1.fastq.gz }
# ### [ output ] => { tinat/quants/hl60_decitabine_1 }
# ### [ threads ] => { 10 }
# Logs will be written to tinat/quants/hl60_decitabine_1/logs
# [2022-08-30 21:54:09.961] [jointLog] [info] setting maxHashResizeThreads to 10
# [2022-08-30 21:54:09.961] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2022-08-30 21:54:09.962] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2022-08-30 21:54:09.962] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2022-08-30 21:54:09.962] [jointLog] [info] parsing read library format
# [2022-08-30 21:54:09.962] [jointLog] [info] There is 1 library.
# [2022-08-30 21:54:10.038] [jointLog] [info] Loading pufferfish index
# [2022-08-30 21:54:10.038] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 183.45 ms
# -----------------------------------------
# size = 629063
# -----------------------------------------
# | Loading contig offsets | Time = 1.5278 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 503.8 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 34.301 ms
# -----------------------------------------
# size = 119911194
# Number of ones: 629062
# Number of ones per inventory item: 512
# Inventory entries filled: 1229
# -----------------------------------------
# | Loading contig boundaries | Time = 176.21 ms
# -----------------------------------------
# size = 119911194
# -----------------------------------------
# | Loading sequence | Time = 15.024 ms
# -----------------------------------------
# size = 101039334
# -----------------------------------------
# | Loading positions | Time = 169.08 ms
# -----------------------------------------
# size = 203602945
# -----------------------------------------
# | Loading reference sequence | Time = 25.582 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 628.01 us
# -----------------------------------------
#
#
#
#
# [2022-08-30 21:54:10.646] [jointLog] [info] done
# [2022-08-30 21:54:10.646] [jointLog] [info] Index contained 84,038 targets
# [2022-08-30 21:54:10.668] [jointLog] [info] Number of decoys : 0
# [2022-08-30 21:54:10.999] [jointLog] [info] Automatically detected most likely library type as SF
# processed 500,001 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# processed 5,000,000 fragments
# processed 5,500,000 fragments
# processed 6,000,000 fragments
# processed 6,500,000 fragments
# processed 7,000,000 fragments
# processed 7,500,000 fragments
# processed 8,000,000 fragments
# processed 8,500,000 fragments
# processed 9,000,000 fragments
# processed 9,500,000 fragments
# processed 10,000,000 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,000 fragments
# processed 13,000,000 fragments
# processed 13,500,000 fragments
# processed 14,000,000 fragments
# processed 14,500,000 fragments
# processed 15,000,000 fragments
# processed 15,500,000 fragments
# processed 16,000,000 fragments
# processed 16,500,000 fragments
# processed 17,500,000 fragments
# processed 18,000,000 fragments
# processed 18,500,001 fragments
# processed 19,000,000 fragments
# processed 19,500,000 fragments
# processed 20,000,000 fragments
# processed 20,500,000 fragments
# processed 21,000,001 fragments
# processed 21,500,001 fragments
# processed 22,000,000 fragments
# processed 22,500,000 fragments
# processed 23,000,000 fragments
# processed 23,500,001 fragments
# processed 24,000,000 fragments
# processed 24,500,000 fragments
# processed 25,000,000 fragments
# processed 25,500,000 fragments
# processed 26,000,000 fragments
# processed 26,500,000 fragments
# hits: 62,072,722; hits per frag:  2.34595[2022-08-30 21:55:03.612] [jointLog] [info] Thread saw mini-batch with a maximum of 0.96% zero probability fragments
# [2022-08-30 21:55:03.621] [jointLog] [info] Thread saw mini-batch with a maximum of 1.06% zero probability fragments
# [2022-08-30 21:55:03.633] [jointLog] [info] Thread saw mini-batch with a maximum of 0.96% zero probability fragments
# [2022-08-30 21:55:03.644] [jointLog] [info] Thread saw mini-batch with a maximum of 0.96% zero probability fragments
# [2022-08-30 21:55:03.662] [jointLog] [info] Thread saw mini-batch with a maximum of 1.02% zero probability fragments
# [2022-08-30 21:55:03.669] [jointLog] [info] Thread saw mini-batch with a maximum of 0.94% zero probability fragments
# [2022-08-30 21:55:03.673] [jointLog] [info] Thread saw mini-batch with a maximum of 1.04% zero probability fragments
# [2022-08-30 21:55:03.676] [jointLog] [info] Thread saw mini-batch with a maximum of 1.08% zero probability fragments
# [2022-08-30 21:55:03.676] [jointLog] [info] Thread saw mini-batch with a maximum of 0.96% zero probability fragments
# [2022-08-30 21:55:03.692] [jointLog] [info] Thread saw mini-batch with a maximum of 1.18% zero probability fragments
#
#
#
#
#
#
#
#
# [2022-08-30 21:55:04.002] [jointLog] [info] Computed 225,821 rich equivalence classes for further processing
# [2022-08-30 21:55:04.002] [jointLog] [info] Counted 17,626,430 total reads in the equivalence classes
# [2022-08-30 21:55:04.012] [jointLog] [info] Number of mappings discarded because of alignment score : 52,327,794
# [2022-08-30 21:55:04.012] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 593,339
# [2022-08-30 21:55:04.012] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2022-08-30 21:55:04.012] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 0
# [2022-08-30 21:55:04.012] [jointLog] [info] Mapping rate = 65.8776%
#
# [2022-08-30 21:55:04.012] [jointLog] [info] finished quantifyLibrary()
# [2022-08-30 21:55:04.014] [jointLog] [info] Starting optimizer
# [2022-08-30 21:55:04.103] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2022-08-30 21:55:04.125] [jointLog] [info] iteration = 0 | max rel diff. = 13567.6
# [2022-08-30 21:55:05.969] [jointLog] [info] iteration = 100 | max rel diff. = 11.0892
# [2022-08-30 21:55:07.783] [jointLog] [info] iteration = 200 | max rel diff. = 19.0972
# [2022-08-30 21:55:09.595] [jointLog] [info] iteration = 300 | max rel diff. = 1.62863
# [2022-08-30 21:55:11.428] [jointLog] [info] iteration = 400 | max rel diff. = 1.07221
# [2022-08-30 21:55:13.247] [jointLog] [info] iteration = 500 | max rel diff. = 0.411217
# [2022-08-30 21:55:15.060] [jointLog] [info] iteration = 600 | max rel diff. = 0.100084
# [2022-08-30 21:55:16.864] [jointLog] [info] iteration = 700 | max rel diff. = 1.04604
# [2022-08-30 21:55:18.674] [jointLog] [info] iteration = 800 | max rel diff. = 0.31675
# [2022-08-30 21:55:20.478] [jointLog] [info] iteration = 900 | max rel diff. = 0.12107
# [2022-08-30 21:55:22.289] [jointLog] [info] iteration = 1,000 | max rel diff. = 0.161029
# [2022-08-30 21:55:24.100] [jointLog] [info] iteration = 1,100 | max rel diff. = 0.176168
# [2022-08-30 21:55:25.923] [jointLog] [info] iteration = 1,200 | max rel diff. = 0.0135777
# [2022-08-30 21:55:27.741] [jointLog] [info] iteration = 1,300 | max rel diff. = 0.105077
# [2022-08-30 21:55:29.556] [jointLog] [info] iteration = 1,400 | max rel diff. = 0.0298136
# [2022-08-30 21:55:30.808] [jointLog] [info] iteration = 1,470 | max rel diff. = 0.00936644
# [2022-08-30 21:55:30.810] [jointLog] [info] Finished optimizer
# [2022-08-30 21:55:30.810] [jointLog] [info] writing output
#
# Version Info: Could not resolve upgrade information in the alotted time.
# Check for upgrades manually at https://combine-lab.github.io/salmon
# ### salmon (mapping-based) v1.2.1
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { ../../scallop-genome/salmon.index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { fastq/hl60_decitabine_2.fastq.gz }
# ### [ output ] => { tinat/quants/hl60_decitabine_2 }
# ### [ threads ] => { 10 }
# Logs will be written to tinat/quants/hl60_decitabine_2/logs
# [2022-08-30 21:55:32.454] [jointLog] [info] setting maxHashResizeThreads to 10
# [2022-08-30 21:55:32.454] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2022-08-30 21:55:32.454] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2022-08-30 21:55:32.454] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2022-08-30 21:55:32.454] [jointLog] [info] parsing read library format
# [2022-08-30 21:55:32.454] [jointLog] [info] There is 1 library.
# [2022-08-30 21:55:32.531] [jointLog] [info] Loading pufferfish index
# [2022-08-30 21:55:32.531] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 203.02 ms
# -----------------------------------------
# size = 629063
# -----------------------------------------
# | Loading contig offsets | Time = 1.1481 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 385.46 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 34.389 ms
# -----------------------------------------
# size = 119911194
# Number of ones: 629062
# Number of ones per inventory item: 512
# Inventory entries filled: 1229
# -----------------------------------------
# | Loading contig boundaries | Time = 169.67 ms
# -----------------------------------------
# size = 119911194
# -----------------------------------------
# | Loading sequence | Time = 15.129 ms
# -----------------------------------------
# size = 101039334
# -----------------------------------------
# | Loading positions | Time = 159.29 ms
# -----------------------------------------
# size = 203602945
# -----------------------------------------
# | Loading reference sequence | Time = 23.636 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 568.15 us
# -----------------------------------------
#
#
#
#
# [2022-08-30 21:55:33.140] [jointLog] [info] done
# [2022-08-30 21:55:33.140] [jointLog] [info] Index contained 84,038 targets
# [2022-08-30 21:55:33.161] [jointLog] [info] Number of decoys : 0
# [2022-08-30 21:55:33.475] [jointLog] [info] Automatically detected most likely library type as SF
# processed 500,002 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# processed 5,000,000 fragments
# processed 5,500,000 fragments
# processed 6,000,001 fragments
# processed 6,500,001 fragments
# processed 7,000,000 fragments
# processed 7,500,001 fragments
# processed 8,000,000 fragments
# processed 8,500,000 fragments
# processed 9,000,000 fragments
# processed 9,500,000 fragments
# processed 10,000,000 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,000 fragments
# processed 13,000,000 fragments
# processed 13,500,000 fragments
# processed 14,000,000 fragments
# processed 14,500,000 fragments
# processed 15,000,000 fragments
# processed 15,500,000 fragments
# processed 16,000,000 fragments
# processed 16,500,000 fragments
# processed 17,000,000 fragments
# processed 17,500,000 fragments
# processed 18,000,000 fragments
# processed 18,500,000 fragments
# processed 19,000,001 fragments
# processed 19,500,000 fragments
# processed 20,000,000 fragments
# processed 20,500,000 fragments
# processed 21,000,000 fragments
# processed 21,500,000 fragments
# processed 22,000,000 fragments
# processed 22,500,000 fragments
# processed 23,000,000 fragments
# processed 23,500,000 fragments
# processed 24,000,000 fragments
# processed 24,500,001 fragments
# processed 25,000,000 fragments
# processed 25,500,000 fragments
# processed 26,000,000 fragments
# processed 26,500,000 fragments
# processed 27,000,001 fragments
# processed 27,500,000 fragments
# processed 28,000,000 fragments
# processed 28,500,000 fragments
# processed 29,000,000 fragments
# processed 29,500,000 fragments
# processed 30,000,000 fragments
# processed 30,500,001 fragments
# processed 31,000,000 fragments
# processed 31,500,000 fragments
# processed 32,000,000 fragments
# processed 32,500,000 fragments
# processed 33,000,000 fragments
# processed 33,500,000 fragments
# processed 34,000,000 fragments
# processed 34,500,000 fragments
# hits: 85,242,901; hits per frag:  2.47204[2022-08-30 21:56:38.552] [jointLog] [info] Thread saw mini-batch with a maximum of 0.88% zero probability fragments
# [2022-08-30 21:56:38.572] [jointLog] [info] Thread saw mini-batch with a maximum of 0.86% zero probability fragments
# [2022-08-30 21:56:38.584] [jointLog] [info] Thread saw mini-batch with a maximum of 0.84% zero probability fragments
# [2022-08-30 21:56:38.599] [jointLog] [info] Thread saw mini-batch with a maximum of 0.92% zero probability fragments
# [2022-08-30 21:56:38.599] [jointLog] [info] Thread saw mini-batch with a maximum of 0.86% zero probability fragments
# [2022-08-30 21:56:38.603] [jointLog] [info] Thread saw mini-batch with a maximum of 0.86% zero probability fragments
# [2022-08-30 21:56:38.610] [jointLog] [info] Thread saw mini-batch with a maximum of 0.86% zero probability fragments
# [2022-08-30 21:56:38.633] [jointLog] [info] Thread saw mini-batch with a maximum of 0.90% zero probability fragments
# [2022-08-30 21:56:38.635] [jointLog] [info] Thread saw mini-batch with a maximum of 0.84% zero probability fragments
# [2022-08-30 21:56:38.648] [jointLog] [info] Thread saw mini-batch with a maximum of 0.88% zero probability fragments
#
#
#
#
#
#
#
#
# [2022-08-30 21:56:38.960] [jointLog] [info] Computed 211,854 rich equivalence classes for further processing
# [2022-08-30 21:56:38.960] [jointLog] [info] Counted 24,618,499 total reads in the equivalence classes
# [2022-08-30 21:56:38.970] [jointLog] [info] Number of mappings discarded because of alignment score : 55,134,503
# [2022-08-30 21:56:38.970] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 536,159
# [2022-08-30 21:56:38.970] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2022-08-30 21:56:38.970] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 0
# [2022-08-30 21:56:38.970] [jointLog] [info] Mapping rate = 70.6977%
#
# [2022-08-30 21:56:38.970] [jointLog] [info] finished quantifyLibrary()
# [2022-08-30 21:56:38.972] [jointLog] [info] Starting optimizer
# [2022-08-30 21:56:39.063] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2022-08-30 21:56:39.087] [jointLog] [info] iteration = 0 | max rel diff. = 14850.7
# [2022-08-30 21:56:40.925] [jointLog] [info] iteration = 100 | max rel diff. = 17.9618
# [2022-08-30 21:56:42.708] [jointLog] [info] iteration = 200 | max rel diff. = 6.35966
# [2022-08-30 21:56:44.475] [jointLog] [info] iteration = 300 | max rel diff. = 18.6979
# [2022-08-30 21:56:46.236] [jointLog] [info] iteration = 400 | max rel diff. = 5.64678
# [2022-08-30 21:56:48.003] [jointLog] [info] iteration = 500 | max rel diff. = 0.0579458
# [2022-08-30 21:56:49.764] [jointLog] [info] iteration = 600 | max rel diff. = 0.425943
# [2022-08-30 21:56:51.527] [jointLog] [info] iteration = 700 | max rel diff. = 0.0807601
# [2022-08-30 21:56:53.286] [jointLog] [info] iteration = 800 | max rel diff. = 0.231281
# [2022-08-30 21:56:55.043] [jointLog] [info] iteration = 900 | max rel diff. = 0.123456
# [2022-08-30 21:56:56.807] [jointLog] [info] iteration = 1,000 | max rel diff. = 0.187713
# [2022-08-30 21:56:58.408] [jointLog] [info] iteration = 1,092 | max rel diff. = 0.00800464
# [2022-08-30 21:56:58.410] [jointLog] [info] Finished optimizer
# [2022-08-30 21:56:58.410] [jointLog] [info] writing output
#
# Version Info: Could not resolve upgrade information in the alotted time.
# Check for upgrades manually at https://combine-lab.github.io/salmon
# ### salmon (mapping-based) v1.2.1
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { ../../scallop-genome/salmon.index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { fastq/hl60_dmso_1.fastq.gz }
# ### [ output ] => { tinat/quants/hl60_dmso_1 }
# ### [ threads ] => { 10 }
# Logs will be written to tinat/quants/hl60_dmso_1/logs
# [2022-08-30 21:57:00.439] [jointLog] [info] setting maxHashResizeThreads to 10
# [2022-08-30 21:57:00.439] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2022-08-30 21:57:00.439] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2022-08-30 21:57:00.439] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2022-08-30 21:57:00.439] [jointLog] [info] parsing read library format
# [2022-08-30 21:57:00.439] [jointLog] [info] There is 1 library.
# [2022-08-30 21:57:00.510] [jointLog] [info] Loading pufferfish index
# [2022-08-30 21:57:00.511] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 279.57 ms
# -----------------------------------------
# size = 629063
# -----------------------------------------
# | Loading contig offsets | Time = 1.9514 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 522.5 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 43.592 ms
# -----------------------------------------
# size = 119911194
# Number of ones: 629062
# Number of ones per inventory item: 512
# Inventory entries filled: 1229
# -----------------------------------------
# | Loading contig boundaries | Time = 202.21 ms
# -----------------------------------------
# size = 119911194
# -----------------------------------------
# | Loading sequence | Time = 15.123 ms
# -----------------------------------------
# size = 101039334
# -----------------------------------------
# | Loading positions | Time = 167.09 ms
# -----------------------------------------
# size = 203602945
# -----------------------------------------
# | Loading reference sequence | Time = 25.034 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 581.29 us
# -----------------------------------------
#
#
#
#
# [2022-08-30 21:57:01.249] [jointLog] [info] done
# [2022-08-30 21:57:01.249] [jointLog] [info] Index contained 84,038 targets
# [2022-08-30 21:57:01.271] [jointLog] [info] Number of decoys : 0
# [2022-08-30 21:57:01.564] [jointLog] [info] Automatically detected most likely library type as SF
# processed 500,002 fragments
# processed 1,000,001 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,001 fragments
# processed 5,000,001 fragments
# processed 5,500,000 fragments
# processed 6,000,000 fragments
# processed 6,500,000 fragments
# processed 7,000,000 fragments
# processed 7,500,000 fragments
# processed 8,000,000 fragments
# processed 8,500,000 fragments
# processed 9,000,000 fragments
# processed 9,500,001 fragments
# processed 10,000,001 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,000 fragments
# processed 13,000,000 fragments
# processed 13,500,000 fragments
# processed 14,000,000 fragments
# processed 14,500,000 fragments
# processed 15,000,000 fragments
# processed 15,500,000 fragments
# processed 16,000,001 fragments
# processed 16,500,000 fragments
# processed 17,000,000 fragments
# processed 17,500,000 fragments
# processed 18,000,000 fragments
# processed 18,500,000 fragments
# processed 19,000,000 fragments
# processed 19,500,001 fragments
# processed 20,000,000 fragments
# processed 20,500,000 fragments
# processed 21,000,000 fragments
# processed 21,500,000 fragments
# processed 22,000,000 fragments
# processed 22,500,000 fragments
# processed 23,000,000 fragments
# processed 23,500,000 fragments
# processed 24,000,000 fragments
# processed 24,500,000 fragments
# processed 25,000,000 fragments
# processed 25,500,001 fragments
# processed 26,000,000 fragments
# processed 26,500,001 fragments
# processed 27,000,000 fragments
# processed 27,500,000 fragments
# processed 28,000,000 fragments
# processed 28,500,000 fragments
# processed 29,000,000 fragments
# processed 29,500,000 fragments
# processed 30,000,000 fragments
# processed 30,500,001 fragments
# processed 31,000,000 fragments
# processed 31,500,000 fragments
# processed 32,000,000 fragments
# processed 32,500,000 fragments
# processed 33,000,000 fragments
# processed 33,500,000 fragments
# processed 34,000,000 fragments
# processed 34,500,000 fragments
# processed 35,000,000 fragments
# processed 35,500,000 fragments
# processed 36,000,000 fragments
# processed 36,500,000 fragments
# processed 37,000,000 fragments
# processed 37,500,002 fragments
# processed 38,000,000 fragments
# processed 38,500,000 fragments
# processed 39,000,000 fragments
# processed 39,500,000 fragments
# processed 40,000,000 fragments
# processed 40,500,000 fragments
# processed 41,000,000 fragments
# processed 41,500,001 fragments
# processed 42,000,000 fragments
# processed 42,500,001 fragments
# processed 43,000,001 fragments
# processed 43,500,000 fragments
# processed 44,000,000 fragments
# processed 44,500,000 fragments
# processed 45,000,000 fragments
# processed 45,500,000 fragments
# processed 46,000,001 fragments
# processed 46,500,000 fragments
# processed 47,000,000 fragments
# processed 47,500,000 fragments
# processed 48,000,000 fragments
# hits: 118,991,967; hits per frag:  2.48026
#
#
#
#
#
#
#
# [2022-08-30 21:58:31.462] [jointLog] [info] Thread saw mini-batch with a maximum of 0.90% zero probability fragments
# [2022-08-30 21:58:31.472] [jointLog] [info] Thread saw mini-batch with a maximum of 0.88% zero probability fragments
# [2022-08-30 21:58:31.494] [jointLog] [info] Thread saw mini-batch with a maximum of 0.84% zero probability fragments
# [2022-08-30 21:58:31.501] [jointLog] [info] Thread saw mini-batch with a maximum of 0.82% zero probability fragments
# [2022-08-30 21:58:31.502] [jointLog] [info] Thread saw mini-batch with a maximum of 0.96% zero probability fragments
# [2022-08-30 21:58:31.512] [jointLog] [info] Thread saw mini-batch with a maximum of 0.80% zero probability fragments
# [2022-08-30 21:58:31.523] [jointLog] [info] Thread saw mini-batch with a maximum of 0.88% zero probability fragments
# [2022-08-30 21:58:31.525] [jointLog] [info] Thread saw mini-batch with a maximum of 0.90% zero probability fragments
# [2022-08-30 21:58:31.529] [jointLog] [info] Thread saw mini-batch with a maximum of 0.80% zero probability fragments
# [2022-08-30 21:58:31.542] [jointLog] [info] Thread saw mini-batch with a maximum of 0.84% zero probability fragments
# [2022-08-30 21:58:31.841] [jointLog] [info] Computed 231,389 rich equivalence classes for further processing
# [2022-08-30 21:58:31.841] [jointLog] [info] Counted 34,723,686 total reads in the equivalence classes
# [2022-08-30 21:58:31.851] [jointLog] [info] Number of mappings discarded because of alignment score : 81,194,534
# [2022-08-30 21:58:31.851] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 686,693
# [2022-08-30 21:58:31.851] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2022-08-30 21:58:31.851] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 0
# [2022-08-30 21:58:31.851] [jointLog] [info] Mapping rate = 71.627%
#
# [2022-08-30 21:58:31.851] [jointLog] [info] finished quantifyLibrary()
# [2022-08-30 21:58:31.853] [jointLog] [info] Starting optimizer
# [2022-08-30 21:58:31.947] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2022-08-30 21:58:31.971] [jointLog] [info] iteration = 0 | max rel diff. = 12579.9
# [2022-08-30 21:58:33.910] [jointLog] [info] iteration = 100 | max rel diff. = 20.5226
# [2022-08-30 21:58:35.819] [jointLog] [info] iteration = 200 | max rel diff. = 9.17033
# [2022-08-30 21:58:37.711] [jointLog] [info] iteration = 300 | max rel diff. = 1.21258
# [2022-08-30 21:58:39.650] [jointLog] [info] iteration = 400 | max rel diff. = 0.202819
# [2022-08-30 21:58:41.570] [jointLog] [info] iteration = 500 | max rel diff. = 7.6839
# [2022-08-30 21:58:43.469] [jointLog] [info] iteration = 600 | max rel diff. = 0.364088
# [2022-08-30 21:58:45.363] [jointLog] [info] iteration = 700 | max rel diff. = 0.0326804
# [2022-08-30 21:58:47.259] [jointLog] [info] iteration = 800 | max rel diff. = 0.0958066
# [2022-08-30 21:58:49.153] [jointLog] [info] iteration = 900 | max rel diff. = 0.0457794
# [2022-08-30 21:58:51.052] [jointLog] [info] iteration = 1,000 | max rel diff. = 0.280081
# [2022-08-30 21:58:52.955] [jointLog] [info] iteration = 1,100 | max rel diff. = 0.906094
# [2022-08-30 21:58:54.847] [jointLog] [info] iteration = 1,200 | max rel diff. = 0.0637886
# [2022-08-30 21:58:56.749] [jointLog] [info] iteration = 1,300 | max rel diff. = 1.27799
# [2022-08-30 21:58:58.644] [jointLog] [info] iteration = 1,400 | max rel diff. = 0.116148
# [2022-08-30 21:59:00.542] [jointLog] [info] iteration = 1,500 | max rel diff. = 0.0448074
# [2022-08-30 21:59:02.440] [jointLog] [info] iteration = 1,600 | max rel diff. = 0.0967341
# [2022-08-30 21:59:04.343] [jointLog] [info] iteration = 1,700 | max rel diff. = 0.0186231
# [2022-08-30 21:59:06.239] [jointLog] [info] iteration = 1,800 | max rel diff. = 0.0484406
# [2022-08-30 21:59:08.134] [jointLog] [info] iteration = 1,900 | max rel diff. = 0.208295
# [2022-08-30 21:59:09.005] [jointLog] [info] iteration = 1,947 | max rel diff. = 0.0084911
# [2022-08-30 21:59:09.008] [jointLog] [info] Finished optimizer
# [2022-08-30 21:59:09.008] [jointLog] [info] writing output
#
# Version Info: Could not resolve upgrade information in the alotted time.
# Check for upgrades manually at https://combine-lab.github.io/salmon
# ### salmon (mapping-based) v1.2.1
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { ../../scallop-genome/salmon.index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { fastq/hl60_dmso_2.fastq.gz }
# ### [ output ] => { tinat/quants/hl60_dmso_2 }
# ### [ threads ] => { 10 }
# Logs will be written to tinat/quants/hl60_dmso_2/logs
# [2022-08-30 21:59:11.453] [jointLog] [info] setting maxHashResizeThreads to 10
# [2022-08-30 21:59:11.453] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2022-08-30 21:59:11.453] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2022-08-30 21:59:11.453] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2022-08-30 21:59:11.453] [jointLog] [info] parsing read library format
# ...
# | Loading contig boundaries | Time = 177.15 ms
# -----------------------------------------
# size = 119911194
# -----------------------------------------
# | Loading sequence | Time = 15.62 ms
# -----------------------------------------
# size = 101039334
# -----------------------------------------
# | Loading positions | Time = 163.23 ms
# -----------------------------------------
# size = 203602945
# -----------------------------------------
# | Loading reference sequence | Time = 25.144 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 578.11 us
# -----------------------------------------
# [2022-08-30 22:00:25.220] [jointLog] [info] done
# [2022-08-30 22:00:25.220] [jointLog] [info] Index contained 84,038 targets
# [2022-08-30 22:00:25.242] [jointLog] [info] Number of decoys : 0
#
#
#
#
# [2022-08-30 22:00:25.557] [jointLog] [info] Automatically detected most likely library type as SF
# processed 500,005 fragments
# processed 1,000,001 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,001 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# processed 5,000,001 fragments
# processed 5,500,000 fragments
# processed 6,000,000 fragments
# processed 6,500,000 fragments
# processed 7,000,000 fragments
# processed 7,500,000 fragments
# processed 8,000,000 fragments
# processed 8,500,000 fragments
# processed 9,000,000 fragments
# processed 9,500,000 fragments
# processed 10,000,000 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,001 fragments
# processed 13,000,000 fragments
# processed 13,500,000 fragments
# processed 14,000,000 fragments
# processed 14,500,000 fragments
# processed 15,000,000 fragments
# processed 15,500,000 fragments
# processed 16,000,000 fragments
# processed 16,500,000 fragments
# processed 17,000,000 fragments
# processed 17,500,001 fragments
# processed 18,000,000 fragments
# processed 18,500,000 fragments
# processed 19,000,000 fragments
# processed 19,500,000 fragments
# processed 20,000,001 fragments
# processed 20,500,000 fragments
# processed 21,000,000 fragments
# processed 21,500,000 fragments
# processed 22,000,000 fragments
# processed 22,500,000 fragments
# processed 23,000,000 fragments
# processed 23,500,001 fragments
# processed 24,000,000 fragments
# processed 24,500,000 fragments
# processed 25,000,000 fragments
# processed 25,500,000 fragments
# processed 26,000,000 fragments
# processed 26,500,000 fragments
# processed 27,000,000 fragments
# hits: 63,515,265; hits per frag:  2.35331[2022-08-30 22:01:14.500] [jointLog] [info] Thread saw mini-batch with a maximum of 0.82% zero probability fragments
# [2022-08-30 22:01:14.504] [jointLog] [info] Thread saw mini-batch with a maximum of 0.82% zero probability fragments
# [2022-08-30 22:01:14.513] [jointLog] [info] Thread saw mini-batch with a maximum of 0.90% zero probability fragments
# [2022-08-30 22:01:14.520] [jointLog] [info] Thread saw mini-batch with a maximum of 0.88% zero probability fragments
# [2022-08-30 22:01:14.524] [jointLog] [info] Thread saw mini-batch with a maximum of 0.80% zero probability fragments
# [2022-08-30 22:01:14.527] [jointLog] [info] Thread saw mini-batch with a maximum of 0.92% zero probability fragments
# [2022-08-30 22:01:14.550] [jointLog] [info] Thread saw mini-batch with a maximum of 0.90% zero probability fragments
# [2022-08-30 22:01:14.556] [jointLog] [info] Thread saw mini-batch with a maximum of 0.90% zero probability fragments
# [2022-08-30 22:01:14.561] [jointLog] [info] Thread saw mini-batch with a maximum of 0.86% zero probability fragments
# [2022-08-30 22:01:14.586] [jointLog] [info] Thread saw mini-batch with a maximum of 0.80% zero probability fragments
#
#
#
#
#
#
#
#
# [2022-08-30 22:01:14.863] [jointLog] [info] Computed 191,705 rich equivalence classes for further processing
# [2022-08-30 22:01:14.863] [jointLog] [info] Counted 18,829,169 total reads in the equivalence classes
# [2022-08-30 22:01:14.872] [jointLog] [info] Number of mappings discarded because of alignment score : 44,091,539
# [2022-08-30 22:01:14.872] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 464,133
# [2022-08-30 22:01:14.872] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2022-08-30 22:01:14.872] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 0
# [2022-08-30 22:01:14.872] [jointLog] [info] Mapping rate = 68.8313%
#
# [2022-08-30 22:01:14.872] [jointLog] [info] finished quantifyLibrary()
# [2022-08-30 22:01:14.874] [jointLog] [info] Starting optimizer
# [2022-08-30 22:01:14.959] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2022-08-30 22:01:14.981] [jointLog] [info] iteration = 0 | max rel diff. = 13852.9
# [2022-08-30 22:01:16.593] [jointLog] [info] iteration = 100 | max rel diff. = 14.084
# [2022-08-30 22:01:18.120] [jointLog] [info] iteration = 200 | max rel diff. = 7.66061
# [2022-08-30 22:01:19.647] [jointLog] [info] iteration = 300 | max rel diff. = 2.44935
# [2022-08-30 22:01:21.175] [jointLog] [info] iteration = 400 | max rel diff. = 1.74303
# [2022-08-30 22:01:22.701] [jointLog] [info] iteration = 500 | max rel diff. = 0.697441
# [2022-08-30 22:01:24.228] [jointLog] [info] iteration = 600 | max rel diff. = 0.150882
# [2022-08-30 22:01:25.751] [jointLog] [info] iteration = 700 | max rel diff. = 0.681876
# [2022-08-30 22:01:27.274] [jointLog] [info] iteration = 800 | max rel diff. = 0.0613758
# [2022-08-30 22:01:28.798] [jointLog] [info] iteration = 900 | max rel diff. = 3.42991
# [2022-08-30 22:01:30.329] [jointLog] [info] iteration = 1,000 | max rel diff. = 0.135199
# [2022-08-30 22:01:31.851] [jointLog] [info] iteration = 1,100 | max rel diff. = 0.117132
# [2022-08-30 22:01:33.378] [jointLog] [info] iteration = 1,200 | max rel diff. = 0.110345
# [2022-08-30 22:01:34.902] [jointLog] [info] iteration = 1,300 | max rel diff. = 0.0849547
# [2022-08-30 22:01:36.425] [jointLog] [info] iteration = 1,400 | max rel diff. = 0.126577
# [2022-08-30 22:01:37.946] [jointLog] [info] iteration = 1,500 | max rel diff. = 0.0552869
# [2022-08-30 22:01:38.631] [jointLog] [info] iteration = 1,546 | max rel diff. = 0.00638624
# [2022-08-30 22:01:38.633] [jointLog] [info] Finished optimizer
# [2022-08-30 22:01:38.633] [jointLog] [info] writing output
#
# Version Info: Could not resolve upgrade information in the alotted time.
# Check for upgrades manually at https://combine-lab.github.io/salmon
# ### salmon (mapping-based) v1.2.1
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { ../../scallop-genome/salmon.index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { fastq/hl60_rg3039_2.fastq.gz }
# ### [ output ] => { tinat/quants/hl60_rg3039_2 }
# ### [ threads ] => { 10 }
# Logs will be written to tinat/quants/hl60_rg3039_2/logs
# [2022-08-30 22:01:40.440] [jointLog] [info] setting maxHashResizeThreads to 10
# [2022-08-30 22:01:40.440] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2022-08-30 22:01:40.440] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2022-08-30 22:01:40.440] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2022-08-30 22:01:40.440] [jointLog] [info] parsing read library format
# [2022-08-30 22:01:40.440] [jointLog] [info] There is 1 library.
# [2022-08-30 22:01:40.518] [jointLog] [info] Loading pufferfish index
# [2022-08-30 22:01:40.518] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 213.05 ms
# -----------------------------------------
# size = 629063
# -----------------------------------------
# | Loading contig offsets | Time = 1.6982 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 507.68 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 35.079 ms
# -----------------------------------------
# size = 119911194
# Number of ones: 629062
# Number of ones per inventory item: 512
# Inventory entries filled: 1229
# -----------------------------------------
# | Loading contig boundaries | Time = 211.47 ms
# -----------------------------------------
# size = 119911194
# -----------------------------------------
# | Loading sequence | Time = 18.788 ms
# -----------------------------------------
# size = 101039334
# -----------------------------------------
# | Loading positions | Time = 180.97 ms
# -----------------------------------------
# size = 203602945
# -----------------------------------------
# | Loading reference sequence | Time = 28.105 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 1.1181 ms
# -----------------------------------------
# [2022-08-30 22:01:41.211] [jointLog] [info] done
# [2022-08-30 22:01:41.211] [jointLog] [info] Index contained 84,038 targets
# [2022-08-30 22:01:41.242] [jointLog] [info] Number of decoys : 0
#
#
#
#
# [2022-08-30 22:01:41.612] [jointLog] [info] Automatically detected most likely library type as SF
# processed 500,005 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,001 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# processed 5,000,001 fragments
# processed 5,500,000 fragments
# processed 6,000,001 fragments
# processed 6,500,001 fragments
# processed 7,000,000 fragments
# processed 7,500,000 fragments
# processed 8,000,000 fragments
# processed 8,500,000 fragments
# processed 9,000,000 fragments
# processed 9,500,000 fragments
# processed 10,000,000 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,001 fragments
# processed 13,000,001 fragments
# processed 13,500,000 fragments
# processed 14,000,000 fragments
# processed 14,500,000 fragments
# processed 15,000,000 fragments
# processed 15,500,000 fragments
# processed 16,000,000 fragments
# processed 16,500,001 fragments
# processed 17,000,000 fragments
# processed 17,500,000 fragments
# processed 18,000,000 fragments
# processed 18,500,000 fragments
# processed 19,000,001 fragments
# processed 19,500,000 fragments
# processed 20,000,000 fragments
# processed 20,500,000 fragments
# processed 21,000,002 fragments
# processed 21,500,000 fragments
# processed 22,000,000 fragments
# processed 22,500,000 fragments
# processed 23,000,000 fragments
# processed 23,500,000 fragments
# processed 24,000,000 fragments
# processed 24,500,001 fragments
# processed 25,000,000 fragments
# processed 25,500,000 fragments
# processed 26,000,001 fragments
# processed 26,500,000 fragments
# processed 27,000,000 fragments
# processed 27,500,000 fragments
# processed 28,000,000 fragments
# processed 28,000,020 fragments
# processed 28,500,002 fragments
# processed 29,000,001 fragments
# processed 29,500,000 fragments
# processed 30,000,000 fragments
# processed 30,500,000 fragments
# processed 31,000,001 fragments
# processed 31,500,000 fragments
# processed 32,000,000 fragments
# processed 33,000,000 fragments
# processed 33,500,001 fragments
# processed 34,000,001 fragments
# processed 34,500,000 fragments
# processed 35,000,001 fragments
# processed 35,500,000 fragments
# processed 36,000,000 fragments
# processed 36,500,000 fragments
# processed 37,000,000 fragments
# processed 37,500,000 fragments
# processed 38,000,000 fragments
# processed 38,500,000 fragments
# processed 39,000,000 fragments
# processed 39,500,000 fragments
# processed 40,000,000 fragments
# processed 40,500,000 fragments
# processed 41,000,000 fragments
# processed 41,500,001 fragments
# processed 42,000,000 fragments
# processed 42,500,000 fragments
# processed 43,000,000 fragments
# processed 43,500,002 fragments
# processed 44,000,000 fragments
# processed 44,500,000 fragments
# processed 45,000,001 fragments
# hits: 108,080,208; hits per frag:  2.40316[2022-08-30 22:03:03.635] [jointLog] [info] Thread saw mini-batch with a maximum of 0.94% zero probability fragments
# [2022-08-30 22:03:03.639] [jointLog] [info] Thread saw mini-batch with a maximum of 0.86% zero probability fragments
# [2022-08-30 22:03:03.647] [jointLog] [info] Thread saw mini-batch with a maximum of 0.86% zero probability fragments
# [2022-08-30 22:03:03.664] [jointLog] [info] Thread saw mini-batch with a maximum of 0.94% zero probability fragments
# [2022-08-30 22:03:03.664] [jointLog] [info] Thread saw mini-batch with a maximum of 0.90% zero probability fragments
# [2022-08-30 22:03:03.686] [jointLog] [info] Thread saw mini-batch with a maximum of 1.04% zero probability fragments
# [2022-08-30 22:03:03.691] [jointLog] [info] Thread saw mini-batch with a maximum of 0.92% zero probability fragments
# [2022-08-30 22:03:03.694] [jointLog] [info] Thread saw mini-batch with a maximum of 0.96% zero probability fragments
# [2022-08-30 22:03:03.709] [jointLog] [info] Thread saw mini-batch with a maximum of 0.82% zero probability fragments
# [2022-08-30 22:03:03.717] [jointLog] [info] Thread saw mini-batch with a maximum of 0.90% zero probability fragments
#
#
#
#
#
#
#
#
# [2022-08-30 22:03:04.093] [jointLog] [info] Computed 265,270 rich equivalence classes for further processing
# [2022-08-30 22:03:04.093] [jointLog] [info] Counted 31,684,094 total reads in the equivalence classes
# [2022-08-30 22:03:04.102] [jointLog] [info] Number of mappings discarded because of alignment score : 68,768,612
# [2022-08-30 22:03:04.102] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 847,177
# [2022-08-30 22:03:04.102] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2022-08-30 22:03:04.102] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 0
# [2022-08-30 22:03:04.102] [jointLog] [info] Mapping rate = 69.8184%
#
# [2022-08-30 22:03:04.102] [jointLog] [info] finished quantifyLibrary()
# [2022-08-30 22:03:04.104] [jointLog] [info] Starting optimizer
# [2022-08-30 22:03:04.190] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2022-08-30 22:03:04.221] [jointLog] [info] iteration = 0 | max rel diff. = 13753
# [2022-08-30 22:03:06.577] [jointLog] [info] iteration = 100 | max rel diff. = 15.5329
# [2022-08-30 22:03:08.871] [jointLog] [info] iteration = 200 | max rel diff. = 7.04903
# [2022-08-30 22:03:11.146] [jointLog] [info] iteration = 300 | max rel diff. = 1.92961
# [2022-08-30 22:03:13.433] [jointLog] [info] iteration = 400 | max rel diff. = 0.67512
# [2022-08-30 22:03:15.709] [jointLog] [info] iteration = 500 | max rel diff. = 3.04704
# [2022-08-30 22:03:17.984] [jointLog] [info] iteration = 600 | max rel diff. = 0.101568
# [2022-08-30 22:03:20.260] [jointLog] [info] iteration = 700 | max rel diff. = 16.7744
# [2022-08-30 22:03:22.537] [jointLog] [info] iteration = 800 | max rel diff. = 0.101852
# [2022-08-30 22:03:24.820] [jointLog] [info] iteration = 900 | max rel diff. = 0.130905
# [2022-08-30 22:03:27.095] [jointLog] [info] iteration = 1,000 | max rel diff. = 0.367272
# [2022-08-30 22:03:29.370] [jointLog] [info] iteration = 1,100 | max rel diff. = 2.2915
# [2022-08-30 22:03:31.637] [jointLog] [info] iteration = 1,200 | max rel diff. = 0.0134993
# [2022-08-30 22:03:33.902] [jointLog] [info] iteration = 1,300 | max rel diff. = 0.0375254
# [2022-08-30 22:03:36.169] [jointLog] [info] iteration = 1,400 | max rel diff. = 0.0262443
# [2022-08-30 22:03:38.436] [jointLog] [info] iteration = 1,500 | max rel diff. = 0.263154
# [2022-08-30 22:03:39.455] [jointLog] [info] iteration = 1,546 | max rel diff. = 0.00704925
# [2022-08-30 22:03:39.457] [jointLog] [info] Finished optimizer
# [2022-08-30 22:03:39.457] [jointLog] [info] writing output

# %%
ls tinat/quants
# Out:
# hl60_combination_1/  hl60_decitabine_1/  hl60_dmso_1/  hl60_rg3039_1/
# hl60_combination_2/  hl60_decitabine_2/  hl60_dmso_2/  hl60_rg3039_2/

# %%
# !date
# Out:
# Tue Aug 30 22:03:40 PDT 2022

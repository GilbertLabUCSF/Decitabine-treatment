# %% [markdown]
# here I'm using a custom [scallop](https://github.com/Kingsford-Group/scallop) + [gtfmerge](https://github.com/Kingsford-Group/rnaseqtools#gtfmerge) pipeline to create merged gtf annotation of hg19 and tinat transcripts introduced in this
#
# Alex
# > I was curious myself so I decided to align our RNA-seq data to their chimeric transcripts... it looks promising, but let me know if there's anything in my analysis I need to change. Still working on seeing if we can identify alternative TSS without CAGE-seq.
# I'm guessing we can look for novel transcripts using [StringTie](https://ccb.jhu.edu/software/stringtie/) or cufflinks?
#
# Ray
# > I'm asking because in [this paper](https://www.nature.com/articles/ng.3889) they treated lung cancer cells with decitabine and performed Cage-seq to map and identify cryptic transcription start sites. They found cryptic TSSs that generated spliced variants, half of which were in-frame isoforms (and some of which resulted in chimeric transcripts, others original or truncated). This got me thinking about our project and whether we could see these chimeric/fusion transcripts (that are skewed toward the 5'end due Cage-seq and being TSS-induced) in HL60s.
#
#
# Luke
# > Hi Ray, Alex and Abe
# This is an interesting paper which claims genetic alterations to DNA methylation core genes drive dysregulated hematopoietic development due to CpG changes that regulate transcription factor binding (figure 4 and 5). How many TFs are methylation sensitive has been controversial in my understanding but is an interesting idea with lots of data within mylomonocytic cells. https://www.nature.com/articles/s41588-020-0595-4
# I am not suggesting a specific plan but this is an interesting idea.
#
# ___
# last update
#
#     Thu Oct 21 01:06:19 UTC 2021

# %%
cat ../../scallop-genome/gtf-list.txt
# Out:
# gencode.v34lift37.basic.annotation.gtf
# tinat/DAC_TINATs.gtf

# %%
# cat scallop/tinat/tinat-gtf-list.txt
# !wc -l ../../scallop-genome/tinat/DAC+SB_TINATs.gtf
# !wc -l ../../scallop-genome/tinat/DAC_TINATs.gtf
# !wc -l ../../scallop-genome/tinat/SB939_TINATs.gtf
# Out:
# 12172 ../../scallop-genome/tinat/DAC+SB_TINATs.gtf
# 1403 ../../scallop-genome/tinat/DAC_TINATs.gtf
# 2059 ../../scallop-genome/tinat/SB939_TINATs.gtf

# %%
cat ../../scallop-genome/tinat.sh
# Out:
# # https://github.com/Kingsford-Group/scallop
# mkdir -p scallop/tinat/compare
#
# # export PATH='/sadra/goodarzilab/abe/Workflows/rnaseqtools-1.0.3/bin/':$PATH
#
# conda activate alignment
# cd scallop-genome/
#
# ### 0. download genomes
# # # mkdir -p hg19
# # # wget https://hgdownload.soe.ucsc.edu/goldenPath/hg19/bigZips/genes/hg19.knownGene.gtf.gz
# wget https://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_human/release_34/GRCh37_mapping/gencode.v34lift37.basic.annotation.gtf.gz
# gunzip gencode.v34lift37.basic.annotation.gtf.gz
# # # mv hg19.knownGene.gtf.gz hg19/hg19.knownGene.gtf.gz
# # # gunzip hg19/hg19.knownGene.gtf.gz
#
# ### 1. merge
# gtfmerge union gtf-list.txt DAC_GRCh37_merged.gtf -t 2
#
# # ### 2. compare
# # gffcompare -o hg19_tinat/gffall -r /rumi/shams/genomes/hg19/hg19_genes.gtf tinat/hg19.tinat.gtf
#
# # ### 3. subset
# # gtfcuff puniq \
# #     tinat/gffall.hg19.tinat.gtf.tmap \
# #     tinat/hg19.tinat.gtf \
# #     /rumi/shams/genomes/hg19/hg19_genes.gtf \
# #     tinat/unique.gtf
#
# ### 4. gtf2fasta
# # gffread tinat/unique.gtf -g /rumi/shams/genomes/hg19/hg19.fa -w tinat/unique.fa
# gffread DAC_GRCh37_merged.gtf -g /rumi/shams/genomes/hg19/hg19.fa -w DAC_GRCh37_merged.fa
#
# # # 5.concatenate with hg19 fasta
# # gffread hg19/hg19.knownGene.gtf -g /rumi/shams/genomes/hg19/hg19.fa -w hg19/hg19.knownGene.fa
# # cat hg19/hg19.knownGene.fa tinat/unique.fa > tinat/hg19.tinat.fa
#
# ### aligner index
# wget https://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_human/release_34/GRCh37_mapping/GRCh37.primary_assembly.genome.fa.gz
# gunzip GRCh37.primary_assembly.genome.fa.gz
#
# mkdir STAR.index
#
# STAR --runThreadN 6 \
#     --runMode genomeGenerate \
#     --genomeDir STAR.index \
#     --genomeFastaFiles GRCh37.primary_assembly.genome.fa \
#     --sjdbGTFfile DAC_GRCh37_merged.gtf \
#     --sjdbOverhang 99
#
# rm GRCh37.primary_assembly.genome.fa.gz

# %%
# %%bash
# mkdir -p tinat/quants
#
# for f in fastq/*; do
# 	f=`basename $f`;
# 	o=${f/.fastq.gz/};
# 	echo $o
# 	echo `date`
#     salmon quant \
#         -i ../../scallop-genome/salmon.index -l A \
#         -r fastq/$f -o tinat/quants/$o -p 20;
# 	echo `date`
# done
# Out:
# hl60_120h_t_1
# Mon Sep 4 00:20:28 PDT 2023
# Mon Sep 4 00:21:18 PDT 2023
# hl60_120h_t_2
# Mon Sep 4 00:21:18 PDT 2023
# Mon Sep 4 00:22:10 PDT 2023
# hl60_120h_u_1
# Mon Sep 4 00:22:10 PDT 2023
# Mon Sep 4 00:22:59 PDT 2023
# hl60_120h_u_2
# Mon Sep 4 00:22:59 PDT 2023
# Mon Sep 4 00:23:53 PDT 2023
# hl60_6h_t_1
# Mon Sep 4 00:23:53 PDT 2023
# Mon Sep 4 00:24:32 PDT 2023
# hl60_6h_t_2
# Mon Sep 4 00:24:32 PDT 2023
# Mon Sep 4 00:25:41 PDT 2023
# hl60_6h_u_1
# Mon Sep 4 00:25:41 PDT 2023
# Mon Sep 4 00:26:19 PDT 2023
# hl60_6h_u_2
# Mon Sep 4 00:26:19 PDT 2023
# Mon Sep 4 00:27:08 PDT 2023
# hl60_72h_t_1
# Mon Sep 4 00:27:08 PDT 2023
# Mon Sep 4 00:27:59 PDT 2023
# hl60_72h_t_2
# Mon Sep 4 00:27:59 PDT 2023
# Mon Sep 4 00:28:49 PDT 2023
# hl60_72h_u_1
# Mon Sep 4 00:28:49 PDT 2023
# Mon Sep 4 00:29:49 PDT 2023
# hl60_72h_u_2
# Mon Sep 4 00:29:49 PDT 2023
# Mon Sep 4 00:31:10 PDT 2023
# kg1_t_1
# Mon Sep 4 00:31:10 PDT 2023
# Mon Sep 4 00:32:10 PDT 2023
# kg1_t_2
# Mon Sep 4 00:32:10 PDT 2023
# Mon Sep 4 00:32:26 PDT 2023
# kg1_t_3
# Mon Sep 4 00:32:26 PDT 2023
# Mon Sep 4 00:33:24 PDT 2023
# kg1_u_1
# Mon Sep 4 00:33:24 PDT 2023
# Mon Sep 4 00:34:13 PDT 2023
# kg1_u_2
# Mon Sep 4 00:34:13 PDT 2023
# Mon Sep 4 00:34:26 PDT 2023
# kg1_u_3
# Mon Sep 4 00:34:26 PDT 2023
# Mon Sep 4 00:35:49 PDT 2023
# molm13_t_1
# Mon Sep 4 00:35:49 PDT 2023
# Mon Sep 4 00:39:17 PDT 2023
# molm13_t_2
# Mon Sep 4 00:39:17 PDT 2023
# Mon Sep 4 00:43:22 PDT 2023
# molm13_t_3
# Mon Sep 4 00:43:22 PDT 2023
# Mon Sep 4 00:47:31 PDT 2023
# molm13_u_1
# Mon Sep 4 00:47:31 PDT 2023
# Mon Sep 4 00:51:02 PDT 2023
# molm13_u_2
# Mon Sep 4 00:51:02 PDT 2023
# Mon Sep 4 00:55:18 PDT 2023
# molm13_u_3
# Mon Sep 4 00:55:18 PDT 2023
# Mon Sep 4 01:00:20 PDT 2023
# molm14_t_1
# Mon Sep 4 01:00:20 PDT 2023
# Mon Sep 4 01:01:02 PDT 2023
# molm14_t_2
# Mon Sep 4 01:01:02 PDT 2023
# Mon Sep 4 01:01:14 PDT 2023
# molm14_t_3
# Mon Sep 4 01:01:14 PDT 2023
# Mon Sep 4 01:01:58 PDT 2023
# molm14_u_1
# Mon Sep 4 01:01:58 PDT 2023
# Mon Sep 4 01:02:41 PDT 2023
# molm14_u_2
# Mon Sep 4 01:02:41 PDT 2023
# Mon Sep 4 01:02:53 PDT 2023
# molm14_u_3
# Mon Sep 4 01:02:53 PDT 2023
# Mon Sep 4 01:03:41 PDT 2023
# ociaml2_t_1
# Mon Sep 4 01:03:41 PDT 2023
# Mon Sep 4 01:04:33 PDT 2023
# ociaml2_t_2
# Mon Sep 4 01:04:33 PDT 2023
# Mon Sep 4 01:04:46 PDT 2023
# ociaml2_t_3
# Mon Sep 4 01:04:46 PDT 2023
# Mon Sep 4 01:05:58 PDT 2023
# ociaml2_u_1
# Mon Sep 4 01:05:58 PDT 2023
# Mon Sep 4 01:06:40 PDT 2023
# ociaml2_u_2
# Mon Sep 4 01:06:40 PDT 2023
# Mon Sep 4 01:06:51 PDT 2023
# ociaml2_u_3
# Mon Sep 4 01:06:51 PDT 2023
# Mon Sep 4 01:07:47 PDT 2023
# ociaml3_t_1
# Mon Sep 4 01:07:47 PDT 2023
# Mon Sep 4 01:09:01 PDT 2023
# ociaml3_t_2
# Mon Sep 4 01:09:01 PDT 2023
# Mon Sep 4 01:09:13 PDT 2023
# ociaml3_t_3
# Mon Sep 4 01:09:13 PDT 2023
# Mon Sep 4 01:10:05 PDT 2023
# ociaml3_u_1
# Mon Sep 4 01:10:05 PDT 2023
# Mon Sep 4 01:10:44 PDT 2023
# ociaml3_u_2
# Mon Sep 4 01:10:44 PDT 2023
# Mon Sep 4 01:10:56 PDT 2023
# ociaml3_u_3
# Mon Sep 4 01:10:56 PDT 2023
# Mon Sep 4 01:11:50 PDT 2023
# skm1_t_1
# Mon Sep 4 01:11:50 PDT 2023
# Mon Sep 4 01:15:44 PDT 2023
# skm1_t_2
# Mon Sep 4 01:15:44 PDT 2023
# Mon Sep 4 01:19:22 PDT 2023
# skm1_t_3
# Mon Sep 4 01:19:22 PDT 2023
# Mon Sep 4 01:23:47 PDT 2023
# skm1_u_1
# Mon Sep 4 01:23:47 PDT 2023
# Mon Sep 4 01:28:29 PDT 2023
# skm1_u_2
# Mon Sep 4 01:28:29 PDT 2023
# Mon Sep 4 01:33:04 PDT 2023
# skm1_u_3
# Mon Sep 4 01:33:04 PDT 2023
# Mon Sep 4 01:38:23 PDT 2023
# thp1_t_1
# Mon Sep 4 01:38:23 PDT 2023
# Mon Sep 4 01:39:23 PDT 2023
# thp1_t_2
# Mon Sep 4 01:39:23 PDT 2023
# Mon Sep 4 01:39:41 PDT 2023
# thp1_t_3
# Mon Sep 4 01:39:41 PDT 2023
# Mon Sep 4 01:40:35 PDT 2023
# thp1_u_1
# Mon Sep 4 01:40:35 PDT 2023
# Mon Sep 4 01:41:18 PDT 2023
# thp1_u_2
# Mon Sep 4 01:41:18 PDT 2023
# Mon Sep 4 01:41:30 PDT 2023
# thp1_u_3
# Mon Sep 4 01:41:30 PDT 2023
# Mon Sep 4 01:42:26 PDT 2023
# Version Info: Could not resolve upgrade information in the alotted time.
# Check for upgrades manually at https://combine-lab.github.io/salmon
# ### salmon (mapping-based) v1.2.1
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { ../../scallop-genome/salmon.index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { fastq/hl60_120h_t_1.fastq.gz }
# ### [ output ] => { tinat/quants/hl60_120h_t_1 }
# ### [ threads ] => { 20 }
# Logs will be written to tinat/quants/hl60_120h_t_1/logs
# [2023-09-04 00:20:29.348] [jointLog] [info] setting maxHashResizeThreads to 20
# [2023-09-04 00:20:29.348] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2023-09-04 00:20:29.348] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2023-09-04 00:20:29.348] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2023-09-04 00:20:29.348] [jointLog] [info] parsing read library format
# [2023-09-04 00:20:29.348] [jointLog] [info] There is 1 library.
# [2023-09-04 00:20:29.490] [jointLog] [info] Loading pufferfish index
# [2023-09-04 00:20:29.531] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 322.16 ms
# -----------------------------------------
# size = 629063
# -----------------------------------------
# | Loading contig offsets | Time = 40.989 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 17.153 ms
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 173.62 ms
# -----------------------------------------
# size = 119911194
# Number of ones: 629062
# Number of ones per inventory item: 512
# Inventory entries filled: 1229
# -----------------------------------------
# | Loading contig boundaries | Time = 362.74 ms
# -----------------------------------------
# size = 119911194
# -----------------------------------------
# | Loading sequence | Time = 123.68 ms
# -----------------------------------------
# size = 101039334
# -----------------------------------------
# | Loading positions | Time = 574.67 ms
# -----------------------------------------
# size = 203602945
# -----------------------------------------
# | Loading reference sequence | Time = 133.2 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 33.456 ms
# -----------------------------------------
#
#
#
#
# [2023-09-04 00:20:31.349] [jointLog] [info] done
# [2023-09-04 00:20:31.349] [jointLog] [info] Index contained 84,038 targets
# [2023-09-04 00:20:31.397] [jointLog] [info] Number of decoys : 0
# [2023-09-04 00:20:31.915] [jointLog] [info] Automatically detected most likely library type as SF
# processed 500,007 fragments
# processed 1,000,001 fragments
# processed 1,500,000 fragments
# processed 2,000,001 fragments
# processed 2,500,001 fragments
# processed 3,000,000 fragments
# processed 3,500,001 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# processed 5,000,002 fragments
# processed 5,500,002 fragments
# processed 6,000,001 fragments
# processed 6,500,002 fragments
# processed 7,000,001 fragments
# processed 7,500,000 fragments
# processed 8,000,000 fragments
# processed 8,500,001 fragments
# processed 8,500,039 fragments
# processed 9,000,000 fragments
# processed 9,500,001 fragments
# processed 10,000,000 fragments
# processed 10,500,001 fragments
# processed 11,000,001 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,001 fragments
# processed 13,000,000 fragments
# processed 13,500,000 fragments
# processed 14,000,001 fragments
# processed 14,500,000 fragments
# processed 15,000,002 fragments
# processed 15,500,000 fragments
# processed 16,000,000 fragments
# processed 16,500,001 fragments
# processed 17,000,000 fragments
# processed 17,500,002 fragments
# processed 18,000,001 fragments
# processed 18,500,002 fragments
# processed 19,000,002 fragments
# processed 19,500,001 fragments
# processed 20,000,000 fragments
# processed 20,500,001 fragments
# processed 21,000,001 fragments
# processed 21,500,001 fragments
# processed 22,000,000 fragments
# processed 22,500,000 fragments
# processed 23,000,000 fragments
# processed 23,500,001 fragments
# processed 24,000,001 fragments
# processed 24,500,000 fragments
# processed 25,000,001 fragments
# processed 25,500,001 fragments
# processed 26,000,001 fragments
# processed 26,500,000 fragments
# processed 27,000,002 fragments
# processed 27,500,000 fragments
# processed 28,000,000 fragments
# processed 28,500,002 fragments
# processed 29,000,000 fragments
# processed 29,500,001 fragments
# processed 30,000,001 fragments
# processed 30,500,003 fragments
# processed 31,000,000 fragments
# processed 31,500,001 fragments
# processed 32,000,000 fragments
# processed 32,500,001 fragments
# processed 33,000,000 fragments
# processed 33,500,001 fragments
# processed 34,000,002 fragments
# processed 34,500,002 fragments
# processed 35,000,001 fragments
# processed 35,500,000 fragments
# processed 36,000,000 fragments
# processed 36,500,002 fragments
# hits: 51,780,968; hits per frag:  1.42085[2023-09-04 00:21:04.010] [jointLog] [info] Thread saw mini-batch with a maximum of 2.60% zero probability fragments
# [2023-09-04 00:21:04.014] [jointLog] [info] Thread saw mini-batch with a maximum of 2.66% zero probability fragments
# [2023-09-04 00:21:04.015] [jointLog] [info] Thread saw mini-batch with a maximum of 2.56% zero probability fragments
# [2023-09-04 00:21:04.029] [jointLog] [info] Thread saw mini-batch with a maximum of 2.52% zero probability fragments
# [2023-09-04 00:21:04.035] [jointLog] [info] Thread saw mini-batch with a maximum of 2.46% zero probability fragments
# [2023-09-04 00:21:04.035] [jointLog] [info] Thread saw mini-batch with a maximum of 2.50% zero probability fragments
# [2023-09-04 00:21:04.039] [jointLog] [info] Thread saw mini-batch with a maximum of 2.52% zero probability fragments
# [2023-09-04 00:21:04.041] [jointLog] [info] Thread saw mini-batch with a maximum of 2.66% zero probability fragments
# [2023-09-04 00:21:04.059] [jointLog] [info] Thread saw mini-batch with a maximum of 2.48% zero probability fragments
# [2023-09-04 00:21:04.060] [jointLog] [info] Thread saw mini-batch with a maximum of 2.44% zero probability fragments
# [2023-09-04 00:21:04.064] [jointLog] [info] Thread saw mini-batch with a maximum of 2.46% zero probability fragments
# [2023-09-04 00:21:04.079] [jointLog] [info] Thread saw mini-batch with a maximum of 2.84% zero probability fragments
# [2023-09-04 00:21:04.086] [jointLog] [info] Thread saw mini-batch with a maximum of 2.58% zero probability fragments
# [2023-09-04 00:21:04.092] [jointLog] [info] Thread saw mini-batch with a maximum of 2.50% zero probability fragments
# [2023-09-04 00:21:04.093] [jointLog] [info] Thread saw mini-batch with a maximum of 2.76% zero probability fragments
# [2023-09-04 00:21:04.094] [jointLog] [info] Thread saw mini-batch with a maximum of 2.60% zero probability fragments
# [2023-09-04 00:21:04.095] [jointLog] [info] Thread saw mini-batch with a maximum of 2.64% zero probability fragments
# [2023-09-04 00:21:04.097] [jointLog] [info] Thread saw mini-batch with a maximum of 2.76% zero probability fragments
# [2023-09-04 00:21:04.101] [jointLog] [info] Thread saw mini-batch with a maximum of 2.54% zero probability fragments
# [2023-09-04 00:21:04.106] [jointLog] [info] Thread saw mini-batch with a maximum of 2.58% zero probability fragments
#
#
#
#
#
#
#
#
# [2023-09-04 00:21:04.424] [jointLog] [info] Computed 238,649 rich equivalence classes for further processing
# [2023-09-04 00:21:04.424] [jointLog] [info] Counted 15,331,240 total reads in the equivalence classes
# [2023-09-04 00:21:04.441] [jointLog] [info] Number of mappings discarded because of alignment score : 28,132,001
# [2023-09-04 00:21:04.441] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 273,537
# [2023-09-04 00:21:04.441] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2023-09-04 00:21:04.441] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 0
# [2023-09-04 00:21:04.441] [jointLog] [info] Mapping rate = 41.6109%
#
# [2023-09-04 00:21:04.441] [jointLog] [info] finished quantifyLibrary()
# [2023-09-04 00:21:04.442] [jointLog] [info] Starting optimizer
# [2023-09-04 00:21:04.540] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2023-09-04 00:21:04.552] [jointLog] [info] iteration = 0 | max rel diff. = 12601.9
# [2023-09-04 00:21:05.528] [jointLog] [info] iteration = 100 | max rel diff. = 15.3249
# [2023-09-04 00:21:06.467] [jointLog] [info] iteration = 200 | max rel diff. = 3.92224
# [2023-09-04 00:21:07.412] [jointLog] [info] iteration = 300 | max rel diff. = 1.02121
# [2023-09-04 00:21:08.366] [jointLog] [info] iteration = 400 | max rel diff. = 6.40737
# [2023-09-04 00:21:09.319] [jointLog] [info] iteration = 500 | max rel diff. = 12.771
# [2023-09-04 00:21:10.275] [jointLog] [info] iteration = 600 | max rel diff. = 0.317012
# [2023-09-04 00:21:11.229] [jointLog] [info] iteration = 700 | max rel diff. = 0.36508
# [2023-09-04 00:21:12.188] [jointLog] [info] iteration = 800 | max rel diff. = 0.0722468
# [2023-09-04 00:21:13.138] [jointLog] [info] iteration = 900 | max rel diff. = 0.212878
# [2023-09-04 00:21:14.091] [jointLog] [info] iteration = 1,000 | max rel diff. = 1.64131
# [2023-09-04 00:21:15.061] [jointLog] [info] iteration = 1,100 | max rel diff. = 0.201962
# [2023-09-04 00:21:16.028] [jointLog] [info] iteration = 1,200 | max rel diff. = 0.111724
# [2023-09-04 00:21:16.948] [jointLog] [info] iteration = 1,296 | max rel diff. = 0.00943286
# [2023-09-04 00:21:16.959] [jointLog] [info] Finished optimizer
# [2023-09-04 00:21:16.959] [jointLog] [info] writing output
#
# Version Info: Could not resolve upgrade information in the alotted time.
# Check for upgrades manually at https://combine-lab.github.io/salmon
# ### salmon (mapping-based) v1.2.1
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { ../../scallop-genome/salmon.index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { fastq/hl60_120h_t_2.fastq.gz }
# ### [ output ] => { tinat/quants/hl60_120h_t_2 }
# ### [ threads ] => { 20 }
# Logs will be written to tinat/quants/hl60_120h_t_2/logs
# [2023-09-04 00:21:19.154] [jointLog] [info] setting maxHashResizeThreads to 20
# [2023-09-04 00:21:19.154] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2023-09-04 00:21:19.154] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2023-09-04 00:21:19.154] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2023-09-04 00:21:19.154] [jointLog] [info] parsing read library format
# [2023-09-04 00:21:19.154] [jointLog] [info] There is 1 library.
# [2023-09-04 00:21:19.303] [jointLog] [info] Loading pufferfish index
# [2023-09-04 00:21:19.303] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 260.8 ms
# -----------------------------------------
# size = 629063
# -----------------------------------------
# | Loading contig offsets | Time = 2.2335 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 433.39 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 61.532 ms
# -----------------------------------------
# size = 119911194
# Number of ones: 629062
# Number of ones per inventory item: 512
# Inventory entries filled: 1229
# -----------------------------------------
# | Loading contig boundaries | Time = 298.6 ms
# -----------------------------------------
# size = 119911194
# -----------------------------------------
# | Loading sequence | Time = 26.884 ms
# -----------------------------------------
# size = 101039334
# -----------------------------------------
# | Loading positions | Time = 263.25 ms
# -----------------------------------------
# size = 203602945
# -----------------------------------------
# | Loading reference sequence | Time = 36.181 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 845.28 us
# -----------------------------------------
#
#
#
#
# [2023-09-04 00:21:20.256] [jointLog] [info] done
# [2023-09-04 00:21:20.256] [jointLog] [info] Index contained 84,038 targets
# [2023-09-04 00:21:20.288] [jointLog] [info] Number of decoys : 0
# [2023-09-04 00:21:20.630] [jointLog] [info] Automatically detected most likely library type as SF
# processed 500,008 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,001 fragments
# processed 5,000,000 fragments
# processed 5,500,000 fragments
# processed 6,000,000 fragments
# processed 6,500,001 fragments
# processed 7,000,000 fragments
# processed 7,500,000 fragments
# processed 8,000,001 fragments
# processed 8,500,000 fragments
# processed 9,000,000 fragments
# processed 9,500,000 fragments
# processed 10,000,000 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,000 fragments
# processed 13,000,000 fragments
# processed 13,500,000 fragments
# processed 14,000,001 fragments
# processed 14,500,001 fragments
# processed 15,000,000 fragments
# processed 15,500,000 fragments
# processed 16,000,000 fragments
# processed 16,500,000 fragments
# processed 17,000,000 fragments
# processed 17,500,001 fragments
# processed 18,000,001 fragments
# processed 18,500,000 fragments
# processed 19,000,001 fragments
# processed 19,500,001 fragments
# processed 20,000,000 fragments
# processed 20,500,000 fragments
# processed 21,000,000 fragments
# processed 21,500,000 fragments
# processed 22,000,000 fragments
# processed 22,500,000 fragments
# processed 23,000,001 fragments
# processed 23,500,000 fragments
# processed 24,000,002 fragments
# processed 24,500,000 fragments
# processed 25,000,000 fragments
# processed 25,500,000 fragments
# processed 26,000,000 fragments
# processed 26,500,000 fragments
# processed 27,000,000 fragments
# processed 27,500,000 fragments
# processed 28,000,002 fragments
# processed 28,500,000 fragments
# processed 29,000,000 fragments
# processed 29,500,000 fragments
# processed 30,000,001 fragments
# processed 30,500,000 fragments
# processed 31,000,001 fragments
# hits: 54,415,148; hits per frag:  1.7594[2023-09-04 00:21:51.539] [jointLog] [info] Thread saw mini-batch with a maximum of 3.05% zero probability fragments
# [2023-09-04 00:21:51.541] [jointLog] [info] Thread saw mini-batch with a maximum of 2.42% zero probability fragments
# [2023-09-04 00:21:51.543] [jointLog] [info] Thread saw mini-batch with a maximum of 2.40% zero probability fragments
# [2023-09-04 00:21:51.545] [jointLog] [info] Thread saw mini-batch with a maximum of 2.46% zero probability fragments
# [2023-09-04 00:21:51.557] [jointLog] [info] Thread saw mini-batch with a maximum of 2.72% zero probability fragments
# [2023-09-04 00:21:51.564] [jointLog] [info] Thread saw mini-batch with a maximum of 2.38% zero probability fragments
# [2023-09-04 00:21:51.564] [jointLog] [info] Thread saw mini-batch with a maximum of 2.58% zero probability fragments
# [2023-09-04 00:21:51.577] [jointLog] [info] Thread saw mini-batch with a maximum of 2.56% zero probability fragments
# [2023-09-04 00:21:51.585] [jointLog] [info] Thread saw mini-batch with a maximum of 2.52% zero probability fragments
# [2023-09-04 00:21:51.590] [jointLog] [info] Thread saw mini-batch with a maximum of 2.54% zero probability fragments
# [2023-09-04 00:21:51.590] [jointLog] [info] Thread saw mini-batch with a maximum of 2.42% zero probability fragments
# [2023-09-04 00:21:51.593] [jointLog] [info] Thread saw mini-batch with a maximum of 2.40% zero probability fragments
# [2023-09-04 00:21:51.598] [jointLog] [info] Thread saw mini-batch with a maximum of 2.46% zero probability fragments
# [2023-09-04 00:21:51.601] [jointLog] [info] Thread saw mini-batch with a maximum of 2.44% zero probability fragments
# [2023-09-04 00:21:51.601] [jointLog] [info] Thread saw mini-batch with a maximum of 2.46% zero probability fragments
# [2023-09-04 00:21:51.612] [jointLog] [info] Thread saw mini-batch with a maximum of 2.64% zero probability fragments
# [2023-09-04 00:21:51.618] [jointLog] [info] Thread saw mini-batch with a maximum of 2.60% zero probability fragments
# [2023-09-04 00:21:51.623] [jointLog] [info] Thread saw mini-batch with a maximum of 2.52% zero probability fragments
# [2023-09-04 00:21:51.626] [jointLog] [info] Thread saw mini-batch with a maximum of 2.38% zero probability fragments
# [2023-09-04 00:21:51.641] [jointLog] [info] Thread saw mini-batch with a maximum of 2.42% zero probability fragments
#
#
#
#
# [2023-09-04 00:21:51.937] [jointLog] [info] Computed 242,794 rich equivalence classes for further processing
# [2023-09-04 00:21:51.937] [jointLog] [info] Counted 16,152,078 total reads in the equivalence classes
#
#
#
#
# [2023-09-04 00:21:51.953] [jointLog] [info] Number of mappings discarded because of alignment score : 28,892,024
# [2023-09-04 00:21:51.953] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 257,532
# [2023-09-04 00:21:51.953] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2023-09-04 00:21:51.953] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 0
# [2023-09-04 00:21:51.953] [jointLog] [info] Mapping rate = 51.6609%
#
# [2023-09-04 00:21:51.953] [jointLog] [info] finished quantifyLibrary()
# [2023-09-04 00:21:51.955] [jointLog] [info] Starting optimizer
# [2023-09-04 00:21:52.043] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2023-09-04 00:21:52.056] [jointLog] [info] iteration = 0 | max rel diff. = 12892.1
# [2023-09-04 00:21:53.075] [jointLog] [info] iteration = 100 | max rel diff. = 17.411
# [2023-09-04 00:21:54.048] [jointLog] [info] iteration = 200 | max rel diff. = 17.7292
# [2023-09-04 00:21:55.012] [jointLog] [info] iteration = 300 | max rel diff. = 0.346869
# [2023-09-04 00:21:55.988] [jointLog] [info] iteration = 400 | max rel diff. = 4.99849
# [2023-09-04 00:21:56.966] [jointLog] [info] iteration = 500 | max rel diff. = 14.4335
# [2023-09-04 00:21:57.938] [jointLog] [info] iteration = 600 | max rel diff. = 0.202722
# [2023-09-04 00:21:58.913] [jointLog] [info] iteration = 700 | max rel diff. = 2.39028
# [2023-09-04 00:21:59.876] [jointLog] [info] iteration = 800 | max rel diff. = 0.0459956
# [2023-09-04 00:22:00.840] [jointLog] [info] iteration = 900 | max rel diff. = 0.995094
# [2023-09-04 00:22:01.808] [jointLog] [info] iteration = 1,000 | max rel diff. = 0.238951
# [2023-09-04 00:22:02.782] [jointLog] [info] iteration = 1,100 | max rel diff. = 0.275219
# [2023-09-04 00:22:03.756] [jointLog] [info] iteration = 1,200 | max rel diff. = 0.756574
# [2023-09-04 00:22:04.723] [jointLog] [info] iteration = 1,300 | max rel diff. = 0.278459
# [2023-09-04 00:22:05.684] [jointLog] [info] iteration = 1,400 | max rel diff. = 0.0376023
# [2023-09-04 00:22:06.657] [jointLog] [info] iteration = 1,500 | max rel diff. = 1.70122
# [2023-09-04 00:22:07.607] [jointLog] [info] iteration = 1,600 | max rel diff. = 0.385616
# [2023-09-04 00:22:08.548] [jointLog] [info] iteration = 1,700 | max rel diff. = 0.0379144
# [2023-09-04 00:22:08.815] [jointLog] [info] iteration = 1,729 | max rel diff. = 0.00542443
# [2023-09-04 00:22:08.826] [jointLog] [info] Finished optimizer
# [2023-09-04 00:22:08.826] [jointLog] [info] writing output
#
# Version Info: Could not resolve upgrade information in the alotted time.
# Check for upgrades manually at https://combine-lab.github.io/salmon
# ### salmon (mapping-based) v1.2.1
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { ../../scallop-genome/salmon.index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { fastq/hl60_120h_u_1.fastq.gz }
# ### [ output ] => { tinat/quants/hl60_120h_u_1 }
# ### [ threads ] => { 20 }
# Logs will be written to tinat/quants/hl60_120h_u_1/logs
# [2023-09-04 00:22:11.448] [jointLog] [info] setting maxHashResizeThreads to 20
# [2023-09-04 00:22:11.448] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2023-09-04 00:22:11.448] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2023-09-04 00:22:11.448] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2023-09-04 00:22:11.448] [jointLog] [info] parsing read library format
# [2023-09-04 00:22:11.448] [jointLog] [info] There is 1 library.
# [2023-09-04 00:22:11.617] [jointLog] [info] Loading pufferfish index
# [2023-09-04 00:22:11.618] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 263.63 ms
# -----------------------------------------
# size = 629063
# -----------------------------------------
# | Loading contig offsets | Time = 2.2199 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 405.17 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 57.869 ms
# -----------------------------------------
# size = 119911194
# Number of ones: 629062
# Number of ones per inventory item: 512
# Inventory entries filled: 1229
# -----------------------------------------
# | Loading contig boundaries | Time = 297.85 ms
# -----------------------------------------
# size = 119911194
# -----------------------------------------
# | Loading sequence | Time = 25.165 ms
# -----------------------------------------
# size = 101039334
# -----------------------------------------
# | Loading positions | Time = 317.02 ms
# -----------------------------------------
# size = 203602945
# -----------------------------------------
# | Loading reference sequence | Time = 43.197 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 986.37 us
# -----------------------------------------
#
#
#
#
# [2023-09-04 00:22:12.628] [jointLog] [info] done
# [2023-09-04 00:22:12.628] [jointLog] [info] Index contained 84,038 targets
# [2023-09-04 00:22:12.676] [jointLog] [info] Number of decoys : 0
# [2023-09-04 00:22:13.043] [jointLog] [info] Automatically detected most likely library type as SF
# processed 500,004 fragments
# processed 1,000,002 fragments
# processed 1,500,001 fragments
# processed 2,000,000 fragments
# processed 2,500,002 fragments
# processed 3,000,000 fragments
# processed 3,500,001 fragments
# processed 4,000,001 fragments
# processed 4,500,000 fragments
# processed 5,500,000 fragments
# processed 6,000,002 fragments
# processed 6,500,000 fragments
# processed 7,000,000 fragments
# processed 7,500,000 fragments
# processed 8,000,001 fragments
# processed 8,500,000 fragments
# processed 9,000,000 fragments
# processed 9,500,000 fragments
# processed 10,500,000 fragments
# processed 11,000,002 fragments
# processed 11,500,002 fragments
# processed 12,000,000 fragments
# processed 12,500,000 fragments
# processed 13,000,000 fragments
# processed 13,500,001 fragments
# processed 14,000,000 fragments
# processed 14,500,000 fragments
# processed 15,000,000 fragments
# processed 15,500,000 fragments
# processed 16,000,003 fragments
# processed 16,500,000 fragments
# processed 17,000,001 fragments
# processed 17,500,000 fragments
# processed 18,000,001 fragments
# processed 18,500,001 fragments
# processed 19,000,000 fragments
# processed 19,500,000 fragments
# processed 20,000,000 fragments
# processed 20,500,000 fragments
# processed 21,000,000 fragments
# processed 21,500,000 fragments
# processed 22,000,000 fragments
# processed 22,500,000 fragments
# processed 23,000,000 fragments
# processed 23,500,001 fragments
# processed 24,000,002 fragments
# processed 24,500,002 fragments
# processed 25,000,001 fragments
# processed 25,500,000 fragments
# processed 26,000,001 fragments
# processed 26,500,000 fragments
# processed 27,000,000 fragments
# processed 27,500,000 fragments
# processed 28,000,001 fragments
# processed 28,500,000 fragments
# processed 29,000,000 fragments
# processed 29,500,002 fragments
# processed 30,000,000 fragments
# processed 30,500,000 fragments
# processed 31,000,001 fragments
# processed 31,500,001 fragments
# processed 32,000,000 fragments
# processed 32,500,000 fragments
# processed 33,000,001 fragments
# processed 33,500,000 fragments
# processed 34,000,000 fragments
# processed 34,500,000 fragments
# processed 35,000,000 fragments
# processed 35,500,000 fragments
# hits: 48,280,582; hits per frag:  1.36225
#
#
#
#
#
#
#
# [2023-09-04 00:22:44.848] [jointLog] [info] Thread saw mini-batch with a maximum of 2.64% zero probability fragments
# [2023-09-04 00:22:44.850] [jointLog] [info] Thread saw mini-batch with a maximum of 2.56% zero probability fragments
# [2023-09-04 00:22:44.850] [jointLog] [info] Thread saw mini-batch with a maximum of 2.88% zero probability fragments
# [2023-09-04 00:22:44.857] [jointLog] [info] Thread saw mini-batch with a maximum of 2.50% zero probability fragments
# [2023-09-04 00:22:44.859] [jointLog] [info] Thread saw mini-batch with a maximum of 2.42% zero probability fragments
# [2023-09-04 00:22:44.877] [jointLog] [info] Thread saw mini-batch with a maximum of 2.58% zero probability fragments
# [2023-09-04 00:22:44.881] [jointLog] [info] Thread saw mini-batch with a maximum of 2.52% zero probability fragments
# [2023-09-04 00:22:44.884] [jointLog] [info] Thread saw mini-batch with a maximum of 2.56% zero probability fragments
# [2023-09-04 00:22:44.885] [jointLog] [info] Thread saw mini-batch with a maximum of 2.50% zero probability fragments
# [2023-09-04 00:22:44.886] [jointLog] [info] Thread saw mini-batch with a maximum of 2.46% zero probability fragments
# [2023-09-04 00:22:44.889] [jointLog] [info] Thread saw mini-batch with a maximum of 2.50% zero probability fragments
# [2023-09-04 00:22:44.891] [jointLog] [info] Thread saw mini-batch with a maximum of 2.50% zero probability fragments
# [2023-09-04 00:22:44.900] [jointLog] [info] Thread saw mini-batch with a maximum of 2.52% zero probability fragments
# [2023-09-04 00:22:44.902] [jointLog] [info] Thread saw mini-batch with a maximum of 2.62% zero probability fragments
# [2023-09-04 00:22:44.907] [jointLog] [info] Thread saw mini-batch with a maximum of 2.64% zero probability fragments
# [2023-09-04 00:22:44.908] [jointLog] [info] Thread saw mini-batch with a maximum of 2.88% zero probability fragments
# [2023-09-04 00:22:44.908] [jointLog] [info] Thread saw mini-batch with a maximum of 2.56% zero probability fragments
# [2023-09-04 00:22:44.911] [jointLog] [info] Thread saw mini-batch with a maximum of 2.52% zero probability fragments
# [2023-09-04 00:22:44.917] [jointLog] [info] Thread saw mini-batch with a maximum of 2.52% zero probability fragments
# [2023-09-04 00:22:44.924] [jointLog] [info] Thread saw mini-batch with a maximum of 2.52% zero probability fragments
# [2023-09-04 00:22:45.191] [jointLog] [info] Computed 212,314 rich equivalence classes for further processing
# [2023-09-04 00:22:45.191] [jointLog] [info] Counted 15,009,145 total reads in the equivalence classes
# [2023-09-04 00:22:45.205] [jointLog] [info] Number of mappings discarded because of alignment score : 23,812,021
# [2023-09-04 00:22:45.205] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 321,873
# [2023-09-04 00:22:45.205] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2023-09-04 00:22:45.205] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 0
# [2023-09-04 00:22:45.205] [jointLog] [info] Mapping rate = 40.6675%
#
# [2023-09-04 00:22:45.205] [jointLog] [info] finished quantifyLibrary()
# [2023-09-04 00:22:45.207] [jointLog] [info] Starting optimizer
# [2023-09-04 00:22:45.284] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2023-09-04 00:22:45.295] [jointLog] [info] iteration = 0 | max rel diff. = 12435.7
# [2023-09-04 00:22:46.163] [jointLog] [info] iteration = 100 | max rel diff. = 17.4986
# [2023-09-04 00:22:47.007] [jointLog] [info] iteration = 200 | max rel diff. = 2.85214
# [2023-09-04 00:22:47.858] [jointLog] [info] iteration = 300 | max rel diff. = 0.193255
# [2023-09-04 00:22:48.703] [jointLog] [info] iteration = 400 | max rel diff. = 5.35973
# [2023-09-04 00:22:49.542] [jointLog] [info] iteration = 500 | max rel diff. = 0.48606
# [2023-09-04 00:22:50.384] [jointLog] [info] iteration = 600 | max rel diff. = 8.20741
# [2023-09-04 00:22:51.223] [jointLog] [info] iteration = 700 | max rel diff. = 2.02445
# [2023-09-04 00:22:52.069] [jointLog] [info] iteration = 800 | max rel diff. = 0.129066
# [2023-09-04 00:22:52.910] [jointLog] [info] iteration = 900 | max rel diff. = 0.0924624
# [2023-09-04 00:22:53.756] [jointLog] [info] iteration = 1,000 | max rel diff. = 0.0701035
# [2023-09-04 00:22:54.591] [jointLog] [info] iteration = 1,100 | max rel diff. = 0.13537
# [2023-09-04 00:22:55.426] [jointLog] [info] iteration = 1,200 | max rel diff. = 0.0957643
# [2023-09-04 00:22:56.263] [jointLog] [info] iteration = 1,300 | max rel diff. = 0.0341766
# [2023-09-04 00:22:57.103] [jointLog] [info] iteration = 1,400 | max rel diff. = 0.10958
# [2023-09-04 00:22:57.612] [jointLog] [info] iteration = 1,462 | max rel diff. = 0.00438034
# [2023-09-04 00:22:57.623] [jointLog] [info] Finished optimizer
# [2023-09-04 00:22:57.623] [jointLog] [info] writing output
#
# Version Info: Could not resolve upgrade information in the alotted time.
# Check for upgrades manually at https://combine-lab.github.io/salmon
# ### salmon (mapping-based) v1.2.1
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { ../../scallop-genome/salmon.index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { fastq/hl60_120h_u_2.fastq.gz }
# ### [ output ] => { tinat/quants/hl60_120h_u_2 }
# ### [ threads ] => { 20 }
# Logs will be written to tinat/quants/hl60_120h_u_2/logs
# [2023-09-04 00:23:00.240] [jointLog] [info] setting maxHashResizeThreads to 20
# [2023-09-04 00:23:00.240] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2023-09-04 00:23:00.240] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2023-09-04 00:23:00.240] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2023-09-04 00:23:00.240] [jointLog] [info] parsing read library format
# [2023-09-04 00:23:00.240] [jointLog] [info] There is 1 library.
# [2023-09-04 00:23:00.346] [jointLog] [info] Loading pufferfish index
# [2023-09-04 00:23:00.346] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 162.4 ms
# -----------------------------------------
# size = 629063
# -----------------------------------------
# | Loading contig offsets | Time = 1.777 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 301.7 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 45.425 ms
# -----------------------------------------
# size = 119911194
# Number of ones: 629062
# Number of ones per inventory item: 512
# Inventory entries filled: 1229
# -----------------------------------------
# | Loading contig boundaries | Time = 181.77 ms
# -----------------------------------------
# size = 119911194
# -----------------------------------------
# | Loading sequence | Time = 20.465 ms
# -----------------------------------------
# size = 101039334
# -----------------------------------------
# | Loading positions | Time = 238.64 ms
# -----------------------------------------
# size = 203602945
# -----------------------------------------
# | Loading reference sequence | Time = 33.881 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 701.29 us
# -----------------------------------------
# [2023-09-04 00:23:01.033] [jointLog] [info] done
# [2023-09-04 00:23:01.033] [jointLog] [info] Index contained 84,038 targets
# [2023-09-04 00:23:01.065] [jointLog] [info] Number of decoys : 0
#
#
#
#
# [2023-09-04 00:23:01.395] [jointLog] [info] Automatically detected most likely library type as SF
# processed 500,004 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,001 fragments
# processed 3,500,002 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# processed 5,000,003 fragments
# processed 5,500,000 fragments
# processed 6,000,000 fragments
# processed 6,500,001 fragments
# processed 7,000,000 fragments
# processed 7,500,000 fragments
# processed 8,500,000 fragments
# processed 9,000,002 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,000 fragments
# processed 13,000,002 fragments
# processed 14,000,001 fragments
# processed 14,500,001 fragments
# processed 15,000,002 fragments
# processed 15,500,000 fragments
# processed 16,000,001 fragments
# processed 16,500,000 fragments
# processed 17,000,000 fragments
# processed 17,500,001 fragments
# processed 18,000,001 fragments
# processed 18,500,000 fragments
# processed 19,000,001 fragments
# processed 19,500,000 fragments
# processed 20,000,000 fragments
# processed 20,500,000 fragments
# processed 21,000,000 fragments
# processed 21,500,000 fragments
# processed 22,000,000 fragments
# processed 22,500,002 fragments
# processed 23,000,001 fragments
# processed 23,500,000 fragments
# processed 24,000,002 fragments
# processed 24,500,000 fragments
# processed 24,500,045 fragments
# processed 25,000,001 fragments
# processed 25,500,001 fragments
# processed 26,000,000 fragments
# processed 26,500,000 fragments
# processed 27,000,000 fragments
# processed 27,500,000 fragments
# processed 28,000,000 fragments
# processed 28,500,000 fragments
# processed 29,000,001 fragments
# processed 29,500,000 fragments
# processed 30,000,000 fragments
# processed 30,500,000 fragments
# processed 31,000,001 fragments
# processed 31,500,000 fragments
# processed 32,000,000 fragments
# processed 32,500,000 fragments
# processed 33,000,000 fragments
# processed 33,500,000 fragments
# processed 34,000,000 fragments
# processed 34,500,000 fragments
# processed 35,000,000 fragments
# processed 35,500,000 fragments
# processed 36,000,000 fragments
# processed 36,500,001 fragments
# processed 37,000,001 fragments
# processed 37,500,000 fragments
# processed 38,000,000 fragments
# processed 38,500,000 fragments
# processed 39,000,001 fragments
# processed 39,500,000 fragments
# processed 40,000,000 fragments
# processed 40,500,002 fragments
# processed 41,000,000 fragments
# processed 41,500,000 fragments
# hits: 50,520,188; hits per frag:  1.21841[2023-09-04 00:23:38.378] [jointLog] [info] Thread saw mini-batch with a maximum of 2.88% zero probability fragments
# [2023-09-04 00:23:38.384] [jointLog] [info] Thread saw mini-batch with a maximum of 2.84% zero probability fragments
# [2023-09-04 00:23:38.388] [jointLog] [info] Thread saw mini-batch with a maximum of 2.88% zero probability fragments
# [2023-09-04 00:23:38.390] [jointLog] [info] Thread saw mini-batch with a maximum of 2.94% zero probability fragments
# [2023-09-04 00:23:38.391] [jointLog] [info] Thread saw mini-batch with a maximum of 2.94% zero probability fragments
# [2023-09-04 00:23:38.398] [jointLog] [info] Thread saw mini-batch with a maximum of 2.88% zero probability fragments
# [2023-09-04 00:23:38.400] [jointLog] [info] Thread saw mini-batch with a maximum of 2.92% zero probability fragments
# [2023-09-04 00:23:38.411] [jointLog] [info] Thread saw mini-batch with a maximum of 2.98% zero probability fragments
# [2023-09-04 00:23:38.411] [jointLog] [info] Thread saw mini-batch with a maximum of 2.84% zero probability fragments
# [2023-09-04 00:23:38.415] [jointLog] [info] Thread saw mini-batch with a maximum of 2.92% zero probability fragments
# [2023-09-04 00:23:38.418] [jointLog] [info] Thread saw mini-batch with a maximum of 2.82% zero probability fragments
# [2023-09-04 00:23:38.422] [jointLog] [info] Thread saw mini-batch with a maximum of 2.86% zero probability fragments
# [2023-09-04 00:23:38.427] [jointLog] [info] Thread saw mini-batch with a maximum of 3.28% zero probability fragments
# [2023-09-04 00:23:38.429] [jointLog] [info] Thread saw mini-batch with a maximum of 2.88% zero probability fragments
# [2023-09-04 00:23:38.430] [jointLog] [info] Thread saw mini-batch with a maximum of 2.84% zero probability fragments
# [2023-09-04 00:23:38.434] [jointLog] [info] Thread saw mini-batch with a maximum of 2.86% zero probability fragments
# [2023-09-04 00:23:38.437] [jointLog] [info] Thread saw mini-batch with a maximum of 2.70% zero probability fragments
# [2023-09-04 00:23:38.440] [jointLog] [info] Thread saw mini-batch with a maximum of 2.94% zero probability fragments
# [2023-09-04 00:23:38.444] [jointLog] [info] Thread saw mini-batch with a maximum of 3.00% zero probability fragments
# [2023-09-04 00:23:38.454] [jointLog] [info] Thread saw mini-batch with a maximum of 2.82% zero probability fragments
#
#
#
#
#
#
#
#
# [2023-09-04 00:23:38.697] [jointLog] [info] Computed 204,773 rich equivalence classes for further processing
# [2023-09-04 00:23:38.697] [jointLog] [info] Counted 15,004,026 total reads in the equivalence classes
# [2023-09-04 00:23:38.710] [jointLog] [info] Number of mappings discarded because of alignment score : 26,825,329
# [2023-09-04 00:23:38.710] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 326,345
# [2023-09-04 00:23:38.710] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2023-09-04 00:23:38.710] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 0
# [2023-09-04 00:23:38.710] [jointLog] [info] Mapping rate = 35.7496%
#
# [2023-09-04 00:23:38.710] [jointLog] [info] finished quantifyLibrary()
# [2023-09-04 00:23:38.712] [jointLog] [info] Starting optimizer
# [2023-09-04 00:23:38.791] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2023-09-04 00:23:38.801] [jointLog] [info] iteration = 0 | max rel diff. = 12320.9
# [2023-09-04 00:23:39.635] [jointLog] [info] iteration = 100 | max rel diff. = 7.85447
# [2023-09-04 00:23:40.441] [jointLog] [info] iteration = 200 | max rel diff. = 19.1395
# [2023-09-04 00:23:41.259] [jointLog] [info] iteration = 300 | max rel diff. = 4.24877
# [2023-09-04 00:23:42.081] [jointLog] [info] iteration = 400 | max rel diff. = 3.96208
# [2023-09-04 00:23:42.900] [jointLog] [info] iteration = 500 | max rel diff. = 0.316964
# [2023-09-04 00:23:43.715] [jointLog] [info] iteration = 600 | max rel diff. = 0.583465
# [2023-09-04 00:23:44.540] [jointLog] [info] iteration = 700 | max rel diff. = 0.147184
# [2023-09-04 00:23:45.354] [jointLog] [info] iteration = 800 | max rel diff. = 0.389537
# [2023-09-04 00:23:46.174] [jointLog] [info] iteration = 900 | max rel diff. = 0.0390818
# [2023-09-04 00:23:46.979] [jointLog] [info] iteration = 1,000 | max rel diff. = 0.103802
# [2023-09-04 00:23:47.790] [jointLog] [info] iteration = 1,100 | max rel diff. = 0.116971
# [2023-09-04 00:23:48.604] [jointLog] [info] iteration = 1,200 | max rel diff. = 0.0318498
# [2023-09-04 00:23:49.415] [jointLog] [info] iteration = 1,300 | max rel diff. = 0.0755122
# [2023-09-04 00:23:50.237] [jointLog] [info] iteration = 1,400 | max rel diff. = 0.0290647
# [2023-09-04 00:23:51.054] [jointLog] [info] iteration = 1,500 | max rel diff. = 0.492678
# [2023-09-04 00:23:51.866] [jointLog] [info] iteration = 1,600 | max rel diff. = 0.0426921
# [2023-09-04 00:23:52.057] [jointLog] [info] iteration = 1,623 | max rel diff. = 0.00908105
# [2023-09-04 00:23:52.067] [jointLog] [info] Finished optimizer
# [2023-09-04 00:23:52.067] [jointLog] [info] writing output
#
# Version Info: Could not resolve upgrade information in the alotted time.
# Check for upgrades manually at https://combine-lab.github.io/salmon
# ### salmon (mapping-based) v1.2.1
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { ../../scallop-genome/salmon.index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { fastq/hl60_6h_t_1.fastq.gz }
# ### [ output ] => { tinat/quants/hl60_6h_t_1 }
# ### [ threads ] => { 20 }
# Logs will be written to tinat/quants/hl60_6h_t_1/logs
# [2023-09-04 00:23:54.531] [jointLog] [info] setting maxHashResizeThreads to 20
# [2023-09-04 00:23:54.531] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2023-09-04 00:23:54.531] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2023-09-04 00:23:54.531] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2023-09-04 00:23:54.531] [jointLog] [info] parsing read library format
# [2023-09-04 00:23:54.531] [jointLog] [info] There is 1 library.
# [2023-09-04 00:23:54.659] [jointLog] [info] Loading pufferfish index
# [2023-09-04 00:23:54.659] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 168.31 ms
# -----------------------------------------
# size = 629063
# -----------------------------------------
# | Loading contig offsets | Time = 1.8361 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 462.83 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 46.183 ms
# -----------------------------------------
# size = 119911194
# Number of ones: 629062
# Number of ones per inventory item: 512
# Inventory entries filled: 1229
# -----------------------------------------
# | Loading contig boundaries | Time = 185.23 ms
# -----------------------------------------
# size = 119911194
# -----------------------------------------
# | Loading sequence | Time = 20.586 ms
# -----------------------------------------
# size = 101039334
# -----------------------------------------
# | Loading positions | Time = 227.95 ms
# -----------------------------------------
# size = 203602945
# -----------------------------------------
# | Loading reference sequence | Time = 33.916 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 977.46 us
# -----------------------------------------
# [2023-09-04 00:23:55.346] [jointLog] [info] done
# [2023-09-04 00:23:55.346] [jointLog] [info] Index contained 84,038 targets
# [2023-09-04 00:23:55.378] [jointLog] [info] Number of decoys : 0
#
#
#
#
# [2023-09-04 00:23:55.720] [jointLog] [info] Automatically detected most likely library type as SF
# processed 500,007 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,002 fragments
# processed 5,000,000 fragments
# processed 5,500,000 fragments
# processed 6,000,001 fragments
# processed 6,500,000 fragments
# processed 7,000,000 fragments
# processed 7,500,000 fragments
# processed 8,000,000 fragments
# processed 8,500,000 fragments
# processed 9,000,000 fragments
# processed 9,500,000 fragments
# processed 10,000,000 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,000 fragments
# processed 13,000,000 fragments
# processed 13,500,000 fragments
# processed 14,000,000 fragments
# processed 14,500,000 fragments
# processed 15,000,000 fragments
# processed 15,500,000 fragments
# processed 16,500,000 fragments
# processed 17,000,002 fragments
# processed 17,500,000 fragments
# processed 18,000,001 fragments
# ...
# | Loading mphf table | Time = 63.386 ms
# -----------------------------------------
# size = 119911194
# Number of ones: 629062
# Number of ones per inventory item: 512
# Inventory entries filled: 1229
# -----------------------------------------
# | Loading contig boundaries | Time = 285.7 ms
# -----------------------------------------
# size = 119911194
# -----------------------------------------
# | Loading sequence | Time = 23.154 ms
# -----------------------------------------
# size = 101039334
# -----------------------------------------
# | Loading positions | Time = 251.58 ms
# -----------------------------------------
# size = 203602945
# -----------------------------------------
# | Loading reference sequence | Time = 38.925 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 930.05 us
# -----------------------------------------
#
#
#
#
# [2023-09-04 01:41:20.569] [jointLog] [info] done
# [2023-09-04 01:41:20.569] [jointLog] [info] Index contained 84,038 targets
# [2023-09-04 01:41:20.601] [jointLog] [info] Number of decoys : 0
# [2023-09-04 01:41:20.995] [jointLog] [info] Automatically detected most likely library type as SF
# processed 500,006 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,001 fragments
# processed 3,500,000 fragments
# hits: 6,309,835; hits per frag:  1.84156
#
#
#
#
#
#
#
# [2023-09-04 01:41:25.292] [jointLog] [info] Thread saw mini-batch with a maximum of 2.28% zero probability fragments
# [2023-09-04 01:41:25.302] [jointLog] [info] Thread saw mini-batch with a maximum of 2.26% zero probability fragments
# [2023-09-04 01:41:25.306] [jointLog] [info] Thread saw mini-batch with a maximum of 2.60% zero probability fragments
# [2023-09-04 01:41:25.310] [jointLog] [info] Thread saw mini-batch with a maximum of 2.32% zero probability fragments
# [2023-09-04 01:41:25.323] [jointLog] [info] Thread saw mini-batch with a maximum of 2.48% zero probability fragments
# [2023-09-04 01:41:25.325] [jointLog] [info] Thread saw mini-batch with a maximum of 2.44% zero probability fragments
# [2023-09-04 01:41:25.338] [jointLog] [info] Thread saw mini-batch with a maximum of 2.70% zero probability fragments
# [2023-09-04 01:41:25.341] [jointLog] [info] Thread saw mini-batch with a maximum of 2.22% zero probability fragments
# [2023-09-04 01:41:25.353] [jointLog] [info] Thread saw mini-batch with a maximum of 2.28% zero probability fragments
# [2023-09-04 01:41:25.363] [jointLog] [info] Thread saw mini-batch with a maximum of 2.36% zero probability fragments
# [2023-09-04 01:41:25.369] [jointLog] [info] Thread saw mini-batch with a maximum of 2.42% zero probability fragments
# [2023-09-04 01:41:25.370] [jointLog] [info] Thread saw mini-batch with a maximum of 2.22% zero probability fragments
# [2023-09-04 01:41:25.371] [jointLog] [info] Thread saw mini-batch with a maximum of 2.26% zero probability fragments
# [2023-09-04 01:41:25.378] [jointLog] [info] Thread saw mini-batch with a maximum of 2.28% zero probability fragments
# [2023-09-04 01:41:25.378] [jointLog] [info] Thread saw mini-batch with a maximum of 2.56% zero probability fragments
# [2023-09-04 01:41:25.386] [jointLog] [info] Thread saw mini-batch with a maximum of 2.44% zero probability fragments
# [2023-09-04 01:41:25.387] [jointLog] [info] Thread saw mini-batch with a maximum of 2.24% zero probability fragments
# [2023-09-04 01:41:25.390] [jointLog] [info] Thread saw mini-batch with a maximum of 2.32% zero probability fragments
# [2023-09-04 01:41:25.393] [jointLog] [info] Thread saw mini-batch with a maximum of 2.28% zero probability fragments
# [2023-09-04 01:41:25.393] [jointLog] [info] Thread saw mini-batch with a maximum of 2.32% zero probability fragments
# [2023-09-04 01:41:25.547] [jointLog] [info] Computed 97,465 rich equivalence classes for further processing
# [2023-09-04 01:41:25.547] [jointLog] [info] Counted 1,883,007 total reads in the equivalence classes
# [2023-09-04 01:41:25.564] [jointLog] [info] Number of mappings discarded because of alignment score : 5,800,597
# [2023-09-04 01:41:25.564] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 40,465
# [2023-09-04 01:41:25.564] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2023-09-04 01:41:25.564] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 0
# [2023-09-04 01:41:25.573] [jointLog] [warning] Only 1883007 fragments were mapped, but the number of burn-in fragments was set to 5000000.
# The effective lengths have been computed using the observed mappings.
#
# [2023-09-04 01:41:25.573] [jointLog] [info] Mapping rate = 52.0371%
#
# [2023-09-04 01:41:25.573] [jointLog] [info] finished quantifyLibrary()
# [2023-09-04 01:41:25.575] [jointLog] [info] Starting optimizer
# [2023-09-04 01:41:25.628] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2023-09-04 01:41:25.633] [jointLog] [info] iteration = 0 | max rel diff. = 2137.72
# [2023-09-04 01:41:26.007] [jointLog] [info] iteration = 100 | max rel diff. = 13.9549
# [2023-09-04 01:41:26.358] [jointLog] [info] iteration = 200 | max rel diff. = 3.74758
# [2023-09-04 01:41:26.702] [jointLog] [info] iteration = 300 | max rel diff. = 3.36028
# [2023-09-04 01:41:27.042] [jointLog] [info] iteration = 400 | max rel diff. = 0.391957
# [2023-09-04 01:41:27.386] [jointLog] [info] iteration = 500 | max rel diff. = 0.20196
# [2023-09-04 01:41:27.732] [jointLog] [info] iteration = 600 | max rel diff. = 0.910108
# [2023-09-04 01:41:28.077] [jointLog] [info] iteration = 700 | max rel diff. = 0.138437
# [2023-09-04 01:41:28.419] [jointLog] [info] iteration = 800 | max rel diff. = 0.0221169
# [2023-09-04 01:41:28.765] [jointLog] [info] iteration = 900 | max rel diff. = 0.0163377
# [2023-09-04 01:41:29.114] [jointLog] [info] iteration = 1,000 | max rel diff. = 0.0859458
# [2023-09-04 01:41:29.159] [jointLog] [info] iteration = 1,014 | max rel diff. = 0.0037811
# [2023-09-04 01:41:29.170] [jointLog] [info] Finished optimizer
# [2023-09-04 01:41:29.170] [jointLog] [info] writing output
#
# Version Info: Could not resolve upgrade information in the alotted time.
# Check for upgrades manually at https://combine-lab.github.io/salmon
# ### salmon (mapping-based) v1.2.1
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { ../../scallop-genome/salmon.index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { fastq/thp1_u_3.fastq.gz }
# ### [ output ] => { tinat/quants/thp1_u_3 }
# ### [ threads ] => { 20 }
# Logs will be written to tinat/quants/thp1_u_3/logs
# [2023-09-04 01:41:31.793] [jointLog] [info] setting maxHashResizeThreads to 20
# [2023-09-04 01:41:31.793] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2023-09-04 01:41:31.793] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2023-09-04 01:41:31.793] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2023-09-04 01:41:31.793] [jointLog] [info] parsing read library format
# [2023-09-04 01:41:31.793] [jointLog] [info] There is 1 library.
# [2023-09-04 01:41:31.929] [jointLog] [info] Loading pufferfish index
# [2023-09-04 01:41:31.929] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 262.66 ms
# -----------------------------------------
# size = 629063
# -----------------------------------------
# | Loading contig offsets | Time = 2.2489 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 355.13 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 63.84 ms
# -----------------------------------------
# size = 119911194
# Number of ones: 629062
# Number of ones per inventory item: 512
# Inventory entries filled: 1229
# -----------------------------------------
# | Loading contig boundaries | Time = 299.35 ms
# -----------------------------------------
# size = 119911194
# -----------------------------------------
# | Loading sequence | Time = 27.77 ms
# -----------------------------------------
# size = 101039334
# -----------------------------------------
# | Loading positions | Time = 334.9 ms
# -----------------------------------------
# size = 203602945
# -----------------------------------------
# | Loading reference sequence | Time = 46.728 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 1.1437 ms
# -----------------------------------------
#
#
#
#
# [2023-09-04 01:41:32.969] [jointLog] [info] done
# [2023-09-04 01:41:32.969] [jointLog] [info] Index contained 84,038 targets
# [2023-09-04 01:41:33.016] [jointLog] [info] Number of decoys : 0
# [2023-09-04 01:41:33.412] [jointLog] [info] Automatically detected most likely library type as SF
# processed 500,004 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,001 fragments
# processed 2,500,001 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,004 fragments
# processed 4,500,002 fragments
# processed 5,000,000 fragments
# processed 5,500,000 fragments
# processed 6,000,001 fragments
# processed 6,500,000 fragments
# processed 7,000,001 fragments
# processed 7,500,000 fragments
# processed 8,000,000 fragments
# processed 8,500,000 fragments
# processed 9,000,000 fragments
# processed 9,500,001 fragments
# processed 10,000,000 fragments
# processed 10,500,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,000 fragments
# processed 13,000,000 fragments
# processed 13,500,000 fragments
# processed 14,000,000 fragments
# processed 14,500,001 fragments
# processed 15,000,000 fragments
# processed 15,500,001 fragments
# processed 16,000,000 fragments
# processed 16,500,001 fragments
# processed 17,000,001 fragments
# processed 17,500,000 fragments
# processed 18,000,000 fragments
# processed 18,500,000 fragments
# processed 19,000,000 fragments
# processed 19,500,000 fragments
# processed 20,000,000 fragments
# processed 20,500,000 fragments
# processed 21,000,001 fragments
# processed 21,500,001 fragments
# processed 22,000,000 fragments
# processed 22,500,000 fragments
# processed 23,000,000 fragments
# processed 23,500,000 fragments
# processed 24,000,001 fragments
# processed 24,500,000 fragments
# processed 25,000,000 fragments
# processed 25,500,000 fragments
# processed 26,000,000 fragments
# processed 26,500,000 fragments
# processed 27,000,000 fragments
# hits: 50,809,403; hits per frag:  1.88373
#
#
#
#
#
#
#
# [2023-09-04 01:42:04.105] [jointLog] [info] Thread saw mini-batch with a maximum of 2.66% zero probability fragments
# [2023-09-04 01:42:04.106] [jointLog] [info] Thread saw mini-batch with a maximum of 2.82% zero probability fragments
# [2023-09-04 01:42:04.107] [jointLog] [info] Thread saw mini-batch with a maximum of 2.78% zero probability fragments
# [2023-09-04 01:42:04.118] [jointLog] [info] Thread saw mini-batch with a maximum of 2.68% zero probability fragments
# [2023-09-04 01:42:04.123] [jointLog] [info] Thread saw mini-batch with a maximum of 2.68% zero probability fragments
# [2023-09-04 01:42:04.125] [jointLog] [info] Thread saw mini-batch with a maximum of 2.78% zero probability fragments
# [2023-09-04 01:42:04.126] [jointLog] [info] Thread saw mini-batch with a maximum of 2.88% zero probability fragments
# [2023-09-04 01:42:04.132] [jointLog] [info] Thread saw mini-batch with a maximum of 2.74% zero probability fragments
# [2023-09-04 01:42:04.140] [jointLog] [info] Thread saw mini-batch with a maximum of 2.84% zero probability fragments
# [2023-09-04 01:42:04.142] [jointLog] [info] Thread saw mini-batch with a maximum of 2.74% zero probability fragments
# [2023-09-04 01:42:04.151] [jointLog] [info] Thread saw mini-batch with a maximum of 2.92% zero probability fragments
# [2023-09-04 01:42:04.154] [jointLog] [info] Thread saw mini-batch with a maximum of 2.90% zero probability fragments
# [2023-09-04 01:42:04.158] [jointLog] [info] Thread saw mini-batch with a maximum of 2.74% zero probability fragments
# [2023-09-04 01:42:04.177] [jointLog] [info] Thread saw mini-batch with a maximum of 2.78% zero probability fragments
# [2023-09-04 01:42:04.180] [jointLog] [info] Thread saw mini-batch with a maximum of 2.68% zero probability fragments
# [2023-09-04 01:42:04.184] [jointLog] [info] Thread saw mini-batch with a maximum of 2.76% zero probability fragments
# [2023-09-04 01:42:04.188] [jointLog] [info] Thread saw mini-batch with a maximum of 2.66% zero probability fragments
# [2023-09-04 01:42:04.207] [jointLog] [info] Thread saw mini-batch with a maximum of 2.64% zero probability fragments
# [2023-09-04 01:42:04.222] [jointLog] [info] Thread saw mini-batch with a maximum of 2.74% zero probability fragments
# [2023-09-04 01:42:04.225] [jointLog] [info] Thread saw mini-batch with a maximum of 2.76% zero probability fragments
# [2023-09-04 01:42:04.527] [jointLog] [info] Computed 260,004 rich equivalence classes for further processing
# [2023-09-04 01:42:04.527] [jointLog] [info] Counted 14,969,801 total reads in the equivalence classes
# [2023-09-04 01:42:04.542] [jointLog] [info] Number of mappings discarded because of alignment score : 42,557,824
# [2023-09-04 01:42:04.542] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 304,327
# [2023-09-04 01:42:04.542] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2023-09-04 01:42:04.542] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 0
# [2023-09-04 01:42:04.542] [jointLog] [info] Mapping rate = 54.4565%
#
# [2023-09-04 01:42:04.542] [jointLog] [info] finished quantifyLibrary()
# [2023-09-04 01:42:04.544] [jointLog] [info] Starting optimizer
# [2023-09-04 01:42:04.671] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2023-09-04 01:42:04.686] [jointLog] [info] iteration = 0 | max rel diff. = 12417.3
# [2023-09-04 01:42:05.821] [jointLog] [info] iteration = 100 | max rel diff. = 15.0646
# [2023-09-04 01:42:06.912] [jointLog] [info] iteration = 200 | max rel diff. = 14.7925
# [2023-09-04 01:42:07.998] [jointLog] [info] iteration = 300 | max rel diff. = 17.502
# [2023-09-04 01:42:09.087] [jointLog] [info] iteration = 400 | max rel diff. = 0.871454
# [2023-09-04 01:42:10.175] [jointLog] [info] iteration = 500 | max rel diff. = 19.0376
# [2023-09-04 01:42:11.264] [jointLog] [info] iteration = 600 | max rel diff. = 0.550517
# [2023-09-04 01:42:12.347] [jointLog] [info] iteration = 700 | max rel diff. = 0.245979
# [2023-09-04 01:42:13.442] [jointLog] [info] iteration = 800 | max rel diff. = 0.838973
# [2023-09-04 01:42:14.524] [jointLog] [info] iteration = 900 | max rel diff. = 0.0807292
# [2023-09-04 01:42:15.614] [jointLog] [info] iteration = 1,000 | max rel diff. = 0.501766
# [2023-09-04 01:42:16.698] [jointLog] [info] iteration = 1,100 | max rel diff. = 0.0455476
# [2023-09-04 01:42:17.781] [jointLog] [info] iteration = 1,200 | max rel diff. = 0.278287
# [2023-09-04 01:42:18.869] [jointLog] [info] iteration = 1,300 | max rel diff. = 0.209349
# [2023-09-04 01:42:19.953] [jointLog] [info] iteration = 1,400 | max rel diff. = 0.68887
# [2023-09-04 01:42:21.045] [jointLog] [info] iteration = 1,500 | max rel diff. = 0.025491
# [2023-09-04 01:42:22.128] [jointLog] [info] iteration = 1,600 | max rel diff. = 0.120103
# [2023-09-04 01:42:23.206] [jointLog] [info] iteration = 1,700 | max rel diff. = 0.0221867
# [2023-09-04 01:42:24.282] [jointLog] [info] iteration = 1,800 | max rel diff. = 0.0691912
# [2023-09-04 01:42:24.716] [jointLog] [info] iteration = 1,841 | max rel diff. = 0.0021432
# [2023-09-04 01:42:24.726] [jointLog] [info] Finished optimizer
# [2023-09-04 01:42:24.726] [jointLog] [info] writing output

# %%
rm -r tinat/quants/ociaml2*
rm -r tinat/quants/thp1*

# %%
# !date
# Out:
# Mon Sep  4 01:42:27 PDT 2023

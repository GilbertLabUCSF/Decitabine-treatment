# %% [markdown]
# here I'm using a custom [scallop](https://github.com/Kingsford-Group/scallop) + [gtfmerge](https://github.com/Kingsford-Group/rnaseqtools#gtfmerge) pipeline to create merged gtf annotation of hg19 and tinat transcripts introduced in this
#
# Alex
# > I was curious myself so I decided to align our RNA-seq data to their chimeric transcripts... it looks promising, but let me know if there's anything in my analysis I need to change. Still working on seeing if we can identify alternative TSS without CAGE-seq.
# I'm guessing we can look for novel transcripts using [StringTie](https://ccb.jhu.edu/software/stringtie/) or cufflinks?
#
# Ray
# > I'm asking because in [this paper](https://www.nature.com/articles/ng.3889) they treated lung cancer cells with decitabine and performed Cage-seq to map and identify cryptic transcription start sites. They found cryptic TSSs that generated spliced variants, half of which were in-frame isoforms (and some of which resulted in chimeric transcripts, others original or truncated). This got me thinking about our project and whether we could see these chimeric/fusion transcripts (that are skewed toward the 5'end due Cage-seq and being TSS-induced) in HL60s.
#
#
# Luke
# > Hi Ray, Alex and Abe
# This is an interesting paper which claims genetic alterations to DNA methylation core genes drive dysregulated hematopoietic development due to CpG changes that regulate transcription factor binding (figure 4 and 5). How many TFs are methylation sensitive has been controversial in my understanding but is an interesting idea with lots of data within mylomonocytic cells. https://www.nature.com/articles/s41588-020-0595-4
# I am not suggesting a specific plan but this is an interesting idea.
#
# ___
# last update
#
#     Thu Oct 21 01:06:19 UTC 2021

# %%
cat ../scallop-genome/gtf-list.txt
# Out:
# gencode.v34lift37.basic.annotation.gtf
# tinat/DAC_TINATs.gtf

# %%
# cat scallop/tinat/tinat-gtf-list.txt
# !wc -l ../scallop-genome/tinat/DAC+SB_TINATs.gtf
# !wc -l ../scallop-genome/tinat/DAC_TINATs.gtf
# !wc -l ../scallop-genome/tinat/SB939_TINATs.gtf
# Out:
# 12172 ../scallop-genome/tinat/DAC+SB_TINATs.gtf
# 1403 ../scallop-genome/tinat/DAC_TINATs.gtf
# 2059 ../scallop-genome/tinat/SB939_TINATs.gtf

# %%
cat ../scallop-genome/tinat.sh
# Out:
# # https://github.com/Kingsford-Group/scallop
# mkdir -p scallop/tinat/compare
#
# # export PATH='/sadra/goodarzilab/abe/Workflows/rnaseqtools-1.0.3/bin/':$PATH
#
# conda activate alignment
# cd scallop-genome/
#
# ### 0. download genomes
# # # mkdir -p hg19
# # # wget https://hgdownload.soe.ucsc.edu/goldenPath/hg19/bigZips/genes/hg19.knownGene.gtf.gz
# wget https://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_human/release_34/GRCh37_mapping/gencode.v34lift37.basic.annotation.gtf.gz
# gunzip gencode.v34lift37.basic.annotation.gtf.gz
# # # mv hg19.knownGene.gtf.gz hg19/hg19.knownGene.gtf.gz
# # # gunzip hg19/hg19.knownGene.gtf.gz
#
# ### 1. merge
# gtfmerge union gtf-list.txt DAC_GRCh37_merged.gtf -t 2
#
# # ### 2. compare
# # gffcompare -o hg19_tinat/gffall -r /rumi/shams/genomes/hg19/hg19_genes.gtf tinat/hg19.tinat.gtf
#
# # ### 3. subset
# # gtfcuff puniq \
# #     tinat/gffall.hg19.tinat.gtf.tmap \
# #     tinat/hg19.tinat.gtf \
# #     /rumi/shams/genomes/hg19/hg19_genes.gtf \
# #     tinat/unique.gtf
#
# ### 4. gtf2fasta
# # gffread tinat/unique.gtf -g /rumi/shams/genomes/hg19/hg19.fa -w tinat/unique.fa
# gffread DAC_GRCh37_merged.gtf -g /rumi/shams/genomes/hg19/hg19.fa -w DAC_GRCh37_merged.fa
#
# # # 5.concatenate with hg19 fasta
# # gffread hg19/hg19.knownGene.gtf -g /rumi/shams/genomes/hg19/hg19.fa -w hg19/hg19.knownGene.fa
# # cat hg19/hg19.knownGene.fa tinat/unique.fa > tinat/hg19.tinat.fa

# %%
# %%bash
# mkdir -p tinat/quants
#
# for f in fastq/*; do
# 	f=`basename $f`;
# 	o=${f/.fastq.gz/};
# 	echo $o
# 	echo `date`
#     salmon quant \
#         -i ../scallop-genome/salmon.index -l A \
#         -r fastq/$f -o tinat/quants/$o -p 10;
# 	echo `date`
# done
# Out:
# hl60_120h_t_1
# Tue Aug 30 17:54:05 PDT 2022
# Tue Aug 30 17:55:17 PDT 2022
# hl60_120h_t_2
# Tue Aug 30 17:55:17 PDT 2022
# Tue Aug 30 17:56:30 PDT 2022
# hl60_120h_u_1
# Tue Aug 30 17:56:30 PDT 2022
# Tue Aug 30 17:57:37 PDT 2022
# hl60_120h_u_2
# Tue Aug 30 17:57:37 PDT 2022
# Tue Aug 30 17:58:51 PDT 2022
# hl60_6h_t_1
# Tue Aug 30 17:58:51 PDT 2022
# Tue Aug 30 17:59:49 PDT 2022
# hl60_6h_t_2
# Tue Aug 30 17:59:49 PDT 2022
# Tue Aug 30 18:01:33 PDT 2022
# hl60_6h_u_1
# Tue Aug 30 18:01:33 PDT 2022
# Tue Aug 30 18:02:29 PDT 2022
# hl60_6h_u_2
# Tue Aug 30 18:02:29 PDT 2022
# Tue Aug 30 18:03:42 PDT 2022
# hl60_72h_t_1
# Tue Aug 30 18:03:42 PDT 2022
# Tue Aug 30 18:04:50 PDT 2022
# hl60_72h_t_2
# Tue Aug 30 18:04:50 PDT 2022
# Tue Aug 30 18:06:04 PDT 2022
# hl60_72h_u_1
# Tue Aug 30 18:06:04 PDT 2022
# Tue Aug 30 18:07:32 PDT 2022
# hl60_72h_u_2
# Tue Aug 30 18:07:32 PDT 2022
# Tue Aug 30 18:09:28 PDT 2022
# kg1_t_1
# Tue Aug 30 18:09:28 PDT 2022
# Tue Aug 30 18:11:00 PDT 2022
# kg1_t_2
# Tue Aug 30 18:11:00 PDT 2022
# Tue Aug 30 18:11:23 PDT 2022
# kg1_t_3
# Tue Aug 30 18:11:23 PDT 2022
# Tue Aug 30 18:13:01 PDT 2022
# kg1_u_1
# Tue Aug 30 18:13:01 PDT 2022
# Tue Aug 30 18:14:16 PDT 2022
# kg1_u_2
# Tue Aug 30 18:14:16 PDT 2022
# Tue Aug 30 18:14:35 PDT 2022
# kg1_u_3
# Tue Aug 30 18:14:35 PDT 2022
# Tue Aug 30 18:16:44 PDT 2022
# molm14_t_1
# Tue Aug 30 18:16:44 PDT 2022
# Tue Aug 30 18:17:47 PDT 2022
# molm14_t_2
# Tue Aug 30 18:17:47 PDT 2022
# Tue Aug 30 18:18:00 PDT 2022
# molm14_t_3
# Tue Aug 30 18:18:00 PDT 2022
# Tue Aug 30 18:19:05 PDT 2022
# molm14_u_1
# Tue Aug 30 18:19:05 PDT 2022
# Tue Aug 30 18:20:09 PDT 2022
# molm14_u_2
# Tue Aug 30 18:20:09 PDT 2022
# Tue Aug 30 18:20:21 PDT 2022
# molm14_u_3
# Tue Aug 30 18:20:21 PDT 2022
# Tue Aug 30 18:21:28 PDT 2022
# ociaml2_t_1
# Tue Aug 30 18:21:28 PDT 2022
# Tue Aug 30 18:22:47 PDT 2022
# ociaml2_t_2
# Tue Aug 30 18:22:47 PDT 2022
# Tue Aug 30 18:23:02 PDT 2022
# ociaml2_t_3
# Tue Aug 30 18:23:02 PDT 2022
# Tue Aug 30 18:24:52 PDT 2022
# ociaml2_u_1
# Tue Aug 30 18:24:52 PDT 2022
# Tue Aug 30 18:25:53 PDT 2022
# ociaml2_u_2
# Tue Aug 30 18:25:53 PDT 2022
# Tue Aug 30 18:26:07 PDT 2022
# ociaml2_u_3
# Tue Aug 30 18:26:07 PDT 2022
# Tue Aug 30 18:27:34 PDT 2022
# ociaml3_t_1
# Tue Aug 30 18:27:34 PDT 2022
# Tue Aug 30 18:29:17 PDT 2022
# ociaml3_t_2
# Tue Aug 30 18:29:17 PDT 2022
# Tue Aug 30 18:29:33 PDT 2022
# ociaml3_t_3
# Tue Aug 30 18:29:33 PDT 2022
# Tue Aug 30 18:30:52 PDT 2022
# ociaml3_u_1
# Tue Aug 30 18:30:52 PDT 2022
# Tue Aug 30 18:31:50 PDT 2022
# ociaml3_u_2
# Tue Aug 30 18:31:50 PDT 2022
# Tue Aug 30 18:32:06 PDT 2022
# ociaml3_u_3
# Tue Aug 30 18:32:06 PDT 2022
# Tue Aug 30 18:33:27 PDT 2022
# thp1_t_1
# Tue Aug 30 18:33:27 PDT 2022
# Tue Aug 30 18:35:00 PDT 2022
# thp1_t_2
# Tue Aug 30 18:35:00 PDT 2022
# Tue Aug 30 18:35:25 PDT 2022
# thp1_t_3
# Tue Aug 30 18:35:25 PDT 2022
# Tue Aug 30 18:36:46 PDT 2022
# thp1_u_1
# Tue Aug 30 18:36:46 PDT 2022
# Tue Aug 30 18:37:51 PDT 2022
# thp1_u_2
# Tue Aug 30 18:37:51 PDT 2022
# Tue Aug 30 18:38:05 PDT 2022
# thp1_u_3
# Tue Aug 30 18:38:05 PDT 2022
# Tue Aug 30 18:39:30 PDT 2022
# Version Info: Could not resolve upgrade information in the alotted time.
# Check for upgrades manually at https://combine-lab.github.io/salmon
# ### salmon (mapping-based) v1.2.1
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { ../scallop-genome/salmon.index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { fastq/hl60_120h_t_1.fastq.gz }
# ### [ output ] => { tinat/quants/hl60_120h_t_1 }
# ### [ threads ] => { 10 }
# Logs will be written to tinat/quants/hl60_120h_t_1/logs
# [2022-08-30 17:54:06.912] [jointLog] [info] setting maxHashResizeThreads to 10
# [2022-08-30 17:54:06.912] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2022-08-30 17:54:06.912] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2022-08-30 17:54:06.912] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2022-08-30 17:54:06.912] [jointLog] [info] parsing read library format
# [2022-08-30 17:54:06.912] [jointLog] [info] There is 1 library.
# [2022-08-30 17:54:06.990] [jointLog] [info] Loading pufferfish index
# [2022-08-30 17:54:06.991] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 293.04 ms
# -----------------------------------------
# size = 629063
# -----------------------------------------
# | Loading contig offsets | Time = 5.0084 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 1.5029 ms
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 88.131 ms
# -----------------------------------------
# size = 119911194
# Number of ones: 629062
# Number of ones per inventory item: 512
# Inventory entries filled: 1229
# -----------------------------------------
# | Loading contig boundaries | Time = 303.47 ms
# -----------------------------------------
# size = 119911194
# -----------------------------------------
# | Loading sequence | Time = 33.307 ms
# -----------------------------------------
# size = 101039334
# -----------------------------------------
# | Loading positions | Time = 415.38 ms
# -----------------------------------------
# size = 203602945
# -----------------------------------------
# | Loading reference sequence | Time = 66.633 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 2.659 ms
# -----------------------------------------
#
#
#
#
# [2022-08-30 17:54:08.203] [jointLog] [info] done
# [2022-08-30 17:54:08.203] [jointLog] [info] Index contained 84,038 targets
# [2022-08-30 17:54:08.259] [jointLog] [info] Number of decoys : 0
# [2022-08-30 17:54:08.634] [jointLog] [info] Automatically detected most likely library type as SF
# processed 500,005 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,001 fragments
# processed 4,500,000 fragments
# processed 5,000,000 fragments
# processed 5,500,000 fragments
# processed 6,000,000 fragments
# processed 6,500,000 fragments
# processed 7,000,000 fragments
# processed 7,500,000 fragments
# processed 8,000,000 fragments
# processed 8,500,000 fragments
# processed 9,000,000 fragments
# processed 9,500,000 fragments
# processed 10,000,000 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,001 fragments
# processed 12,500,000 fragments
# processed 13,000,000 fragments
# processed 13,500,000 fragments
# processed 14,000,000 fragments
# processed 14,500,001 fragments
# processed 15,000,000 fragments
# processed 15,500,001 fragments
# processed 16,000,001 fragments
# processed 16,500,000 fragments
# processed 17,000,000 fragments
# processed 17,500,000 fragments
# processed 18,000,000 fragments
# processed 18,500,000 fragments
# processed 19,000,000 fragments
# processed 19,500,000 fragments
# processed 20,000,000 fragments
# processed 20,500,000 fragments
# processed 21,000,000 fragments
# processed 21,500,000 fragments
# processed 22,000,000 fragments
# processed 22,500,000 fragments
# processed 23,000,000 fragments
# processed 23,500,000 fragments
# processed 24,000,000 fragments
# processed 24,500,001 fragments
# processed 25,000,000 fragments
# processed 25,500,000 fragments
# processed 26,000,000 fragments
# processed 26,500,003 fragments
# processed 27,000,000 fragments
# processed 27,500,000 fragments
# processed 28,000,000 fragments
# processed 28,500,000 fragments
# processed 29,000,000 fragments
# processed 29,500,001 fragments
# processed 30,000,000 fragments
# processed 30,500,001 fragments
# processed 31,000,000 fragments
# processed 31,500,000 fragments
# processed 32,000,000 fragments
# processed 32,500,000 fragments
# processed 33,000,000 fragments
# processed 33,500,000 fragments
# processed 34,000,000 fragments
# processed 34,500,000 fragments
# processed 35,000,000 fragments
# processed 35,500,000 fragments
# processed 36,000,001 fragments
# processed 36,500,000 fragments
# hits: 51,781,351; hits per frag:  1.42028[2022-08-30 17:54:55.840] [jointLog] [info] Thread saw mini-batch with a maximum of 2.66% zero probability fragments
# [2022-08-30 17:54:55.851] [jointLog] [info] Thread saw mini-batch with a maximum of 2.84% zero probability fragments
# [2022-08-30 17:54:55.854] [jointLog] [info] Thread saw mini-batch with a maximum of 2.56% zero probability fragments
# [2022-08-30 17:54:55.870] [jointLog] [info] Thread saw mini-batch with a maximum of 2.50% zero probability fragments
# [2022-08-30 17:54:55.870] [jointLog] [info] Thread saw mini-batch with a maximum of 2.60% zero probability fragments
# [2022-08-30 17:54:55.874] [jointLog] [info] Thread saw mini-batch with a maximum of 2.66% zero probability fragments
# [2022-08-30 17:54:55.880] [jointLog] [info] Thread saw mini-batch with a maximum of 2.58% zero probability fragments
# [2022-08-30 17:54:55.880] [jointLog] [info] Thread saw mini-batch with a maximum of 2.76% zero probability fragments
# [2022-08-30 17:54:55.895] [jointLog] [info] Thread saw mini-batch with a maximum of 2.50% zero probability fragments
# [2022-08-30 17:54:55.906] [jointLog] [info] Thread saw mini-batch with a maximum of 2.56% zero probability fragments
#
#
#
#
#
#
#
#
# [2022-08-30 17:54:56.096] [jointLog] [info] Computed 238,644 rich equivalence classes for further processing
# [2022-08-30 17:54:56.096] [jointLog] [info] Counted 15,331,230 total reads in the equivalence classes
# [2022-08-30 17:54:56.103] [jointLog] [info] Number of mappings discarded because of alignment score : 28,132,001
# [2022-08-30 17:54:56.103] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 273,537
# [2022-08-30 17:54:56.103] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2022-08-30 17:54:56.103] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 0
# [2022-08-30 17:54:56.103] [jointLog] [info] Mapping rate = 41.6109%
#
# [2022-08-30 17:54:56.103] [jointLog] [info] finished quantifyLibrary()
# [2022-08-30 17:54:56.121] [jointLog] [info] Starting optimizer
# [2022-08-30 17:54:56.198] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2022-08-30 17:54:56.220] [jointLog] [info] iteration = 0 | max rel diff. = 12601.9
# [2022-08-30 17:54:57.885] [jointLog] [info] iteration = 100 | max rel diff. = 16.8508
# [2022-08-30 17:54:59.480] [jointLog] [info] iteration = 200 | max rel diff. = 2.97932
# [2022-08-30 17:55:01.075] [jointLog] [info] iteration = 300 | max rel diff. = 1.1027
# [2022-08-30 17:55:02.722] [jointLog] [info] iteration = 400 | max rel diff. = 4.20262
# [2022-08-30 17:55:04.334] [jointLog] [info] iteration = 500 | max rel diff. = 0.474394
# [2022-08-30 17:55:05.926] [jointLog] [info] iteration = 600 | max rel diff. = 0.317902
# [2022-08-30 17:55:07.524] [jointLog] [info] iteration = 700 | max rel diff. = 0.373465
# [2022-08-30 17:55:09.118] [jointLog] [info] iteration = 800 | max rel diff. = 0.0638788
# [2022-08-30 17:55:10.708] [jointLog] [info] iteration = 900 | max rel diff. = 0.238229
# [2022-08-30 17:55:12.303] [jointLog] [info] iteration = 1,000 | max rel diff. = 1.35429
# [2022-08-30 17:55:13.895] [jointLog] [info] iteration = 1,100 | max rel diff. = 0.87254
# [2022-08-30 17:55:15.487] [jointLog] [info] iteration = 1,200 | max rel diff. = 0.123407
# [2022-08-30 17:55:17.077] [jointLog] [info] iteration = 1,300 | max rel diff. = 0.00907603
# [2022-08-30 17:55:17.077] [jointLog] [info] iteration = 1,301 | max rel diff. = 0.00907603
# [2022-08-30 17:55:17.079] [jointLog] [info] Finished optimizer
# [2022-08-30 17:55:17.079] [jointLog] [info] writing output
#
# Version Info: Could not resolve upgrade information in the alotted time.
# Check for upgrades manually at https://combine-lab.github.io/salmon
# ### salmon (mapping-based) v1.2.1
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { ../scallop-genome/salmon.index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { fastq/hl60_120h_t_2.fastq.gz }
# ### [ output ] => { tinat/quants/hl60_120h_t_2 }
# ### [ threads ] => { 10 }
# Logs will be written to tinat/quants/hl60_120h_t_2/logs
# [2022-08-30 17:55:18.955] [jointLog] [info] setting maxHashResizeThreads to 10
# [2022-08-30 17:55:18.955] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2022-08-30 17:55:18.955] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2022-08-30 17:55:18.955] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2022-08-30 17:55:18.955] [jointLog] [info] parsing read library format
# [2022-08-30 17:55:18.955] [jointLog] [info] There is 1 library.
# [2022-08-30 17:55:19.030] [jointLog] [info] Loading pufferfish index
# [2022-08-30 17:55:19.030] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 268.55 ms
# -----------------------------------------
# size = 629063
# -----------------------------------------
# | Loading contig offsets | Time = 1.8334 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 509.17 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 43.817 ms
# -----------------------------------------
# size = 119911194
# Number of ones: 629062
# Number of ones per inventory item: 512
# Inventory entries filled: 1229
# -----------------------------------------
# | Loading contig boundaries | Time = 292.25 ms
# -----------------------------------------
# size = 119911194
# -----------------------------------------
# | Loading sequence | Time = 19.776 ms
# -----------------------------------------
# size = 101039334
# -----------------------------------------
# | Loading positions | Time = 170.82 ms
# -----------------------------------------
# size = 203602945
# -----------------------------------------
# | Loading reference sequence | Time = 25.035 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 1.0209 ms
# -----------------------------------------
#
#
#
#
# [2022-08-30 17:55:19.856] [jointLog] [info] done
# [2022-08-30 17:55:19.856] [jointLog] [info] Index contained 84,038 targets
# [2022-08-30 17:55:19.877] [jointLog] [info] Number of decoys : 0
# [2022-08-30 17:55:20.173] [jointLog] [info] Automatically detected most likely library type as SF
# processed 500,003 fragments
# processed 1,000,000 fragments
# processed 1,500,001 fragments
# processed 2,000,001 fragments
# processed 2,500,001 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# processed 5,000,000 fragments
# processed 5,500,001 fragments
# processed 6,000,000 fragments
# processed 6,500,000 fragments
# processed 7,000,000 fragments
# processed 7,500,000 fragments
# processed 8,000,000 fragments
# processed 8,500,001 fragments
# processed 9,000,000 fragments
# processed 9,500,000 fragments
# processed 10,000,000 fragments
# processed 10,500,001 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,000 fragments
# processed 13,000,000 fragments
# processed 13,500,001 fragments
# processed 14,000,001 fragments
# processed 14,500,000 fragments
# processed 15,000,000 fragments
# processed 15,500,000 fragments
# processed 16,000,000 fragments
# processed 16,500,000 fragments
# processed 17,000,000 fragments
# processed 17,500,000 fragments
# processed 18,000,000 fragments
# processed 18,500,001 fragments
# processed 19,000,000 fragments
# processed 19,500,000 fragments
# processed 20,000,001 fragments
# processed 20,500,000 fragments
# processed 21,000,000 fragments
# processed 21,500,000 fragments
# processed 22,000,001 fragments
# processed 22,500,000 fragments
# processed 23,000,000 fragments
# processed 23,500,000 fragments
# processed 24,000,000 fragments
# processed 24,500,000 fragments
# processed 25,000,000 fragments
# processed 25,500,000 fragments
# processed 26,000,000 fragments
# processed 26,500,000 fragments
# processed 27,000,000 fragments
# processed 27,500,000 fragments
# processed 28,000,000 fragments
# processed 28,500,000 fragments
# processed 29,000,000 fragments
# processed 29,500,000 fragments
# processed 30,000,000 fragments
# processed 30,500,000 fragments
# processed 31,000,000 fragments
# hits: 54,415,151; hits per frag:  1.75572[2022-08-30 17:56:05.628] [jointLog] [info] Thread saw mini-batch with a maximum of 2.48% zero probability fragments
# [2022-08-30 17:56:05.632] [jointLog] [info] Thread saw mini-batch with a maximum of 3.05% zero probability fragments
# [2022-08-30 17:56:05.635] [jointLog] [info] Thread saw mini-batch with a maximum of 2.46% zero probability fragments
# [2022-08-30 17:56:05.650] [jointLog] [info] Thread saw mini-batch with a maximum of 2.52% zero probability fragments
# [2022-08-30 17:56:05.661] [jointLog] [info] Thread saw mini-batch with a maximum of 2.72% zero probability fragments
# [2022-08-30 17:56:05.666] [jointLog] [info] Thread saw mini-batch with a maximum of 2.60% zero probability fragments
# [2022-08-30 17:56:05.667] [jointLog] [info] Thread saw mini-batch with a maximum of 2.46% zero probability fragments
# [2022-08-30 17:56:05.680] [jointLog] [info] Thread saw mini-batch with a maximum of 2.64% zero probability fragments
# [2022-08-30 17:56:05.684] [jointLog] [info] Thread saw mini-batch with a maximum of 2.52% zero probability fragments
# [2022-08-30 17:56:05.701] [jointLog] [info] Thread saw mini-batch with a maximum of 2.58% zero probability fragments
# [2022-08-30 17:56:05.949] [jointLog] [info] Computed 242,774 rich equivalence classes for further processing
# [2022-08-30 17:56:05.949] [jointLog] [info] Counted 16,152,068 total reads in the equivalence classes
#
#
#
#
#
#
#
#
# [2022-08-30 17:56:05.958] [jointLog] [info] Number of mappings discarded because of alignment score : 28,892,024
# [2022-08-30 17:56:05.958] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 257,532
# [2022-08-30 17:56:05.958] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2022-08-30 17:56:05.958] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 0
# [2022-08-30 17:56:05.958] [jointLog] [info] Mapping rate = 51.6609%
#
# [2022-08-30 17:56:05.958] [jointLog] [info] finished quantifyLibrary()
# [2022-08-30 17:56:05.980] [jointLog] [info] Starting optimizer
# [2022-08-30 17:56:06.074] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2022-08-30 17:56:06.095] [jointLog] [info] iteration = 0 | max rel diff. = 12890.7
# [2022-08-30 17:56:07.780] [jointLog] [info] iteration = 100 | max rel diff. = 17.9753
# [2022-08-30 17:56:09.416] [jointLog] [info] iteration = 200 | max rel diff. = 14.1204
# [2022-08-30 17:56:11.053] [jointLog] [info] iteration = 300 | max rel diff. = 0.658121
# [2022-08-30 17:56:12.696] [jointLog] [info] iteration = 400 | max rel diff. = 8.05211
# [2022-08-30 17:56:14.349] [jointLog] [info] iteration = 500 | max rel diff. = 1.27596
# [2022-08-30 17:56:16.008] [jointLog] [info] iteration = 600 | max rel diff. = 7.59175
# [2022-08-30 17:56:17.667] [jointLog] [info] iteration = 700 | max rel diff. = 1.13499
# [2022-08-30 17:56:19.328] [jointLog] [info] iteration = 800 | max rel diff. = 0.0445559
# [2022-08-30 17:56:20.991] [jointLog] [info] iteration = 900 | max rel diff. = 0.95432
# [2022-08-30 17:56:22.654] [jointLog] [info] iteration = 1,000 | max rel diff. = 0.225384
# [2022-08-30 17:56:24.312] [jointLog] [info] iteration = 1,100 | max rel diff. = 0.342935
# [2022-08-30 17:56:25.972] [jointLog] [info] iteration = 1,200 | max rel diff. = 4.77572
# [2022-08-30 17:56:27.634] [jointLog] [info] iteration = 1,300 | max rel diff. = 1.24336
# [2022-08-30 17:56:29.300] [jointLog] [info] iteration = 1,400 | max rel diff. = 0.0393962
# [2022-08-30 17:56:29.699] [jointLog] [info] iteration = 1,425 | max rel diff. = 0.00892658
# [2022-08-30 17:56:29.701] [jointLog] [info] Finished optimizer
# [2022-08-30 17:56:29.701] [jointLog] [info] writing output
#
# Version Info: Could not resolve upgrade information in the alotted time.
# Check for upgrades manually at https://combine-lab.github.io/salmon
# ### salmon (mapping-based) v1.2.1
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { ../scallop-genome/salmon.index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { fastq/hl60_120h_u_1.fastq.gz }
# ### [ output ] => { tinat/quants/hl60_120h_u_1 }
# ### [ threads ] => { 10 }
# Logs will be written to tinat/quants/hl60_120h_u_1/logs
# [2022-08-30 17:56:31.501] [jointLog] [info] setting maxHashResizeThreads to 10
# [2022-08-30 17:56:31.501] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2022-08-30 17:56:31.501] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2022-08-30 17:56:31.501] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2022-08-30 17:56:31.501] [jointLog] [info] parsing read library format
# [2022-08-30 17:56:31.501] [jointLog] [info] There is 1 library.
# [2022-08-30 17:56:31.573] [jointLog] [info] Loading pufferfish index
# [2022-08-30 17:56:31.573] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 263.22 ms
# -----------------------------------------
# size = 629063
# -----------------------------------------
# | Loading contig offsets | Time = 1.992 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 443.16 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 43.57 ms
# -----------------------------------------
# size = 119911194
# Number of ones: 629062
# Number of ones per inventory item: 512
# Inventory entries filled: 1229
# -----------------------------------------
# | Loading contig boundaries | Time = 291.84 ms
# -----------------------------------------
# size = 119911194
# -----------------------------------------
# | Loading sequence | Time = 18.697 ms
# -----------------------------------------
# size = 101039334
# -----------------------------------------
# | Loading positions | Time = 157.59 ms
# -----------------------------------------
# size = 203602945
# -----------------------------------------
# | Loading reference sequence | Time = 23.212 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 558.58 us
# -----------------------------------------
#
#
#
#
# [2022-08-30 17:56:32.377] [jointLog] [info] done
# [2022-08-30 17:56:32.377] [jointLog] [info] Index contained 84,038 targets
# [2022-08-30 17:56:32.399] [jointLog] [info] Number of decoys : 0
# [2022-08-30 17:56:32.698] [jointLog] [info] Automatically detected most likely library type as SF
# processed 500,003 fragments
# processed 1,000,000 fragments
# processed 1,500,001 fragments
# processed 2,000,001 fragments
# processed 2,500,001 fragments
# processed 3,000,001 fragments
# processed 3,500,000 fragments
# processed 4,000,001 fragments
# processed 4,500,001 fragments
# processed 5,000,000 fragments
# processed 5,500,001 fragments
# processed 6,000,001 fragments
# processed 6,500,000 fragments
# processed 7,000,000 fragments
# processed 7,500,000 fragments
# processed 8,000,000 fragments
# processed 8,500,001 fragments
# processed 9,000,000 fragments
# processed 9,500,000 fragments
# processed 10,000,000 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,000 fragments
# processed 13,000,000 fragments
# processed 13,500,001 fragments
# processed 14,000,000 fragments
# processed 14,500,001 fragments
# processed 15,000,001 fragments
# processed 15,500,000 fragments
# processed 16,000,000 fragments
# processed 16,500,000 fragments
# processed 17,000,000 fragments
# processed 17,500,000 fragments
# processed 18,000,001 fragments
# processed 18,500,000 fragments
# processed 19,000,000 fragments
# processed 19,500,000 fragments
# processed 20,000,000 fragments
# processed 20,500,000 fragments
# processed 21,000,000 fragments
# processed 21,500,000 fragments
# processed 22,000,000 fragments
# processed 22,500,000 fragments
# processed 23,000,000 fragments
# processed 23,500,000 fragments
# processed 24,000,000 fragments
# processed 24,500,001 fragments
# processed 25,000,001 fragments
# processed 25,500,000 fragments
# processed 26,000,001 fragments
# processed 26,500,001 fragments
# processed 27,000,000 fragments
# processed 27,500,000 fragments
# processed 28,000,000 fragments
# processed 28,500,000 fragments
# processed 29,000,000 fragments
# processed 29,500,000 fragments
# processed 30,000,000 fragments
# processed 30,500,000 fragments
# processed 31,000,000 fragments
# processed 31,500,002 fragments
# processed 32,000,000 fragments
# processed 32,500,001 fragments
# processed 33,000,000 fragments
# processed 33,500,000 fragments
# processed 34,000,000 fragments
# processed 34,500,001 fragments
# processed 35,000,000 fragments
# processed 35,500,001 fragments
# processed 36,000,000 fragments
# processed 36,500,000 fragments
# hits: 49,641,387; hits per frag:  1.36159
#
#
#
#
#
#
#
# [2022-08-30 17:57:15.019] [jointLog] [info] Thread saw mini-batch with a maximum of 2.62% zero probability fragments
# [2022-08-30 17:57:15.026] [jointLog] [info] Thread saw mini-batch with a maximum of 2.64% zero probability fragments
# [2022-08-30 17:57:15.031] [jointLog] [info] Thread saw mini-batch with a maximum of 2.88% zero probability fragments
# [2022-08-30 17:57:15.039] [jointLog] [info] Thread saw mini-batch with a maximum of 2.60% zero probability fragments
# [2022-08-30 17:57:15.039] [jointLog] [info] Thread saw mini-batch with a maximum of 2.68% zero probability fragments
# [2022-08-30 17:57:15.053] [jointLog] [info] Thread saw mini-batch with a maximum of 2.64% zero probability fragments
# [2022-08-30 17:57:15.065] [jointLog] [info] Thread saw mini-batch with a maximum of 2.62% zero probability fragments
# [2022-08-30 17:57:15.071] [jointLog] [info] Thread saw mini-batch with a maximum of 2.56% zero probability fragments
# [2022-08-30 17:57:15.074] [jointLog] [info] Thread saw mini-batch with a maximum of 2.56% zero probability fragments
# [2022-08-30 17:57:15.074] [jointLog] [info] Thread saw mini-batch with a maximum of 2.88% zero probability fragments
# [2022-08-30 17:57:15.352] [jointLog] [info] Computed 212,329 rich equivalence classes for further processing
# [2022-08-30 17:57:15.352] [jointLog] [info] Counted 15,009,170 total reads in the equivalence classes
# [2022-08-30 17:57:15.360] [jointLog] [info] Number of mappings discarded because of alignment score : 23,812,021
# [2022-08-30 17:57:15.360] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 321,873
# [2022-08-30 17:57:15.360] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2022-08-30 17:57:15.360] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 0
# [2022-08-30 17:57:15.360] [jointLog] [info] Mapping rate = 40.6676%
#
# [2022-08-30 17:57:15.360] [jointLog] [info] finished quantifyLibrary()
# [2022-08-30 17:57:15.362] [jointLog] [info] Starting optimizer
# [2022-08-30 17:57:15.447] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2022-08-30 17:57:15.466] [jointLog] [info] iteration = 0 | max rel diff. = 12436.4
# [2022-08-30 17:57:16.927] [jointLog] [info] iteration = 100 | max rel diff. = 19.2152
# [2022-08-30 17:57:18.329] [jointLog] [info] iteration = 200 | max rel diff. = 4.34902
# [2022-08-30 17:57:19.741] [jointLog] [info] iteration = 300 | max rel diff. = 6.21998
# [2022-08-30 17:57:21.142] [jointLog] [info] iteration = 400 | max rel diff. = 5.04799
# [2022-08-30 17:57:22.536] [jointLog] [info] iteration = 500 | max rel diff. = 0.461925
# [2022-08-30 17:57:23.933] [jointLog] [info] iteration = 600 | max rel diff. = 4.5018
# [2022-08-30 17:57:25.329] [jointLog] [info] iteration = 700 | max rel diff. = 8.4277
# [2022-08-30 17:57:26.721] [jointLog] [info] iteration = 800 | max rel diff. = 0.127771
# [2022-08-30 17:57:28.114] [jointLog] [info] iteration = 900 | max rel diff. = 0.111774
# [2022-08-30 17:57:29.512] [jointLog] [info] iteration = 1,000 | max rel diff. = 0.0425325
# [2022-08-30 17:57:30.914] [jointLog] [info] iteration = 1,100 | max rel diff. = 0.158789
# [2022-08-30 17:57:32.319] [jointLog] [info] iteration = 1,200 | max rel diff. = 0.0207192
# [2022-08-30 17:57:33.718] [jointLog] [info] iteration = 1,300 | max rel diff. = 0.0356391
# [2022-08-30 17:57:35.118] [jointLog] [info] iteration = 1,400 | max rel diff. = 0.127762
# [2022-08-30 17:57:35.982] [jointLog] [info] iteration = 1,463 | max rel diff. = 0.00441868
# [2022-08-30 17:57:35.985] [jointLog] [info] Finished optimizer
# [2022-08-30 17:57:35.985] [jointLog] [info] writing output
#
# Version Info: Could not resolve upgrade information in the alotted time.
# Check for upgrades manually at https://combine-lab.github.io/salmon
# ### salmon (mapping-based) v1.2.1
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { ../scallop-genome/salmon.index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { fastq/hl60_120h_u_2.fastq.gz }
# ### [ output ] => { tinat/quants/hl60_120h_u_2 }
# ### [ threads ] => { 10 }
# Logs will be written to tinat/quants/hl60_120h_u_2/logs
# [2022-08-30 17:57:38.552] [jointLog] [info] setting maxHashResizeThreads to 10
# [2022-08-30 17:57:38.552] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2022-08-30 17:57:38.552] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2022-08-30 17:57:38.552] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2022-08-30 17:57:38.552] [jointLog] [info] parsing read library format
# [2022-08-30 17:57:38.552] [jointLog] [info] There is 1 library.
# [2022-08-30 17:57:38.620] [jointLog] [info] Loading pufferfish index
# [2022-08-30 17:57:38.621] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 254.76 ms
# -----------------------------------------
# size = 629063
# -----------------------------------------
# | Loading contig offsets | Time = 1.6816 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 403.98 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 37.374 ms
# -----------------------------------------
# size = 119911194
# Number of ones: 629062
# Number of ones per inventory item: 512
# Inventory entries filled: 1229
# -----------------------------------------
# | Loading contig boundaries | Time = 175.01 ms
# -----------------------------------------
# size = 119911194
# -----------------------------------------
# | Loading sequence | Time = 13.579 ms
# -----------------------------------------
# size = 101039334
# -----------------------------------------
# | Loading positions | Time = 146.27 ms
# -----------------------------------------
# size = 203602945
# -----------------------------------------
# | Loading reference sequence | Time = 22.471 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 602.91 us
# -----------------------------------------
# [2022-08-30 17:57:39.275] [jointLog] [info] done
# [2022-08-30 17:57:39.275] [jointLog] [info] Index contained 84,038 targets
# [2022-08-30 17:57:39.297] [jointLog] [info] Number of decoys : 0
#
#
#
#
# [2022-08-30 17:57:39.568] [jointLog] [info] Automatically detected most likely library type as SF
# processed 500,002 fragments
# processed 1,000,001 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,001 fragments
# processed 3,000,000 fragments
# processed 3,500,002 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# processed 5,000,000 fragments
# processed 5,500,000 fragments
# processed 6,000,000 fragments
# processed 6,500,000 fragments
# processed 7,000,000 fragments
# processed 7,500,000 fragments
# processed 8,000,000 fragments
# processed 8,500,000 fragments
# processed 9,000,000 fragments
# processed 9,500,000 fragments
# processed 10,000,000 fragments
# processed 10,500,001 fragments
# processed 11,000,001 fragments
# processed 11,500,001 fragments
# processed 12,000,001 fragments
# processed 12,500,000 fragments
# processed 13,000,001 fragments
# processed 13,500,000 fragments
# processed 14,000,001 fragments
# processed 14,500,000 fragments
# processed 15,000,000 fragments
# processed 15,500,000 fragments
# processed 16,000,000 fragments
# processed 16,500,000 fragments
# processed 17,000,001 fragments
# processed 17,500,001 fragments
# processed 18,000,001 fragments
# processed 18,500,000 fragments
# processed 19,000,001 fragments
# processed 19,500,000 fragments
# processed 20,000,000 fragments
# processed 20,500,002 fragments
# processed 21,000,000 fragments
# processed 21,500,001 fragments
# processed 22,000,001 fragments
# processed 22,500,000 fragments
# processed 23,000,001 fragments
# processed 23,500,001 fragments
# processed 24,000,000 fragments
# processed 24,500,000 fragments
# processed 25,000,000 fragments
# processed 25,500,000 fragments
# processed 26,000,002 fragments
# processed 26,500,000 fragments
# processed 27,000,000 fragments
# processed 27,500,001 fragments
# processed 28,000,000 fragments
# processed 28,500,000 fragments
# processed 29,000,000 fragments
# processed 29,500,000 fragments
# processed 30,000,000 fragments
# processed 30,500,000 fragments
# processed 31,000,000 fragments
# processed 31,500,000 fragments
# processed 32,000,000 fragments
# processed 32,500,001 fragments
# processed 33,000,000 fragments
# processed 33,500,001 fragments
# processed 34,000,000 fragments
# processed 34,500,000 fragments
# processed 35,000,001 fragments
# processed 35,500,000 fragments
# processed 36,000,000 fragments
# processed 36,500,000 fragments
# processed 37,000,000 fragments
# processed 37,500,000 fragments
# processed 38,000,001 fragments
# processed 38,500,000 fragments
# processed 39,000,000 fragments
# processed 39,500,000 fragments
# processed 40,000,002 fragments
# processed 40,500,000 fragments
# processed 40,500,038 fragments
# processed 41,000,001 fragments
# processed 41,500,000 fragments
# hits: 50,520,399; hits per frag:  1.21874
#
#
#
#
#
#
#
# [2022-08-30 17:58:26.865] [jointLog] [info] Thread saw mini-batch with a maximum of 2.94% zero probability fragments
# [2022-08-30 17:58:26.873] [jointLog] [info] Thread saw mini-batch with a maximum of 2.98% zero probability fragments
# [2022-08-30 17:58:26.876] [jointLog] [info] Thread saw mini-batch with a maximum of 2.92% zero probability fragments
# [2022-08-30 17:58:26.880] [jointLog] [info] Thread saw mini-batch with a maximum of 2.92% zero probability fragments
# [2022-08-30 17:58:26.890] [jointLog] [info] Thread saw mini-batch with a maximum of 2.92% zero probability fragments
# [2022-08-30 17:58:26.891] [jointLog] [info] Thread saw mini-batch with a maximum of 2.88% zero probability fragments
# [2022-08-30 17:58:26.893] [jointLog] [info] Thread saw mini-batch with a maximum of 2.86% zero probability fragments
# [2022-08-30 17:58:26.903] [jointLog] [info] Thread saw mini-batch with a maximum of 2.84% zero probability fragments
# [2022-08-30 17:58:26.904] [jointLog] [info] Thread saw mini-batch with a maximum of 3.00% zero probability fragments
# [2022-08-30 17:58:26.915] [jointLog] [info] Thread saw mini-batch with a maximum of 3.28% zero probability fragments
# [2022-08-30 17:58:27.185] [jointLog] [info] Computed 204,763 rich equivalence classes for further processing
# [2022-08-30 17:58:27.185] [jointLog] [info] Counted 15,004,021 total reads in the equivalence classes
# [2022-08-30 17:58:27.192] [jointLog] [info] Number of mappings discarded because of alignment score : 26,825,329
# [2022-08-30 17:58:27.192] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 326,345
# [2022-08-30 17:58:27.192] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2022-08-30 17:58:27.192] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 0
# [2022-08-30 17:58:27.192] [jointLog] [info] Mapping rate = 35.7496%
#
# [2022-08-30 17:58:27.192] [jointLog] [info] finished quantifyLibrary()
# [2022-08-30 17:58:27.194] [jointLog] [info] Starting optimizer
# [2022-08-30 17:58:27.275] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2022-08-30 17:58:27.292] [jointLog] [info] iteration = 0 | max rel diff. = 12319.1
# [2022-08-30 17:58:28.686] [jointLog] [info] iteration = 100 | max rel diff. = 16.5358
# [2022-08-30 17:58:30.017] [jointLog] [info] iteration = 200 | max rel diff. = 1.01239
# [2022-08-30 17:58:31.362] [jointLog] [info] iteration = 300 | max rel diff. = 0.939937
# [2022-08-30 17:58:32.701] [jointLog] [info] iteration = 400 | max rel diff. = 4.27988
# [2022-08-30 17:58:34.042] [jointLog] [info] iteration = 500 | max rel diff. = 0.284991
# [2022-08-30 17:58:35.379] [jointLog] [info] iteration = 600 | max rel diff. = 0.254987
# [2022-08-30 17:58:36.716] [jointLog] [info] iteration = 700 | max rel diff. = 0.77991
# [2022-08-30 17:58:38.042] [jointLog] [info] iteration = 800 | max rel diff. = 0.746705
# [2022-08-30 17:58:39.368] [jointLog] [info] iteration = 900 | max rel diff. = 0.0396093
# [2022-08-30 17:58:40.693] [jointLog] [info] iteration = 1,000 | max rel diff. = 0.116817
# [2022-08-30 17:58:42.016] [jointLog] [info] iteration = 1,100 | max rel diff. = 0.1479
# [2022-08-30 17:58:43.341] [jointLog] [info] iteration = 1,200 | max rel diff. = 0.0135082
# [2022-08-30 17:58:44.671] [jointLog] [info] iteration = 1,300 | max rel diff. = 0.0765933
# [2022-08-30 17:58:45.998] [jointLog] [info] iteration = 1,400 | max rel diff. = 0.0360614
# [2022-08-30 17:58:47.321] [jointLog] [info] iteration = 1,500 | max rel diff. = 0.5083
# [2022-08-30 17:58:48.646] [jointLog] [info] iteration = 1,600 | max rel diff. = 0.0420273
# [2022-08-30 17:58:49.967] [jointLog] [info] iteration = 1,700 | max rel diff. = 0.0569464
# [2022-08-30 17:58:50.885] [jointLog] [info] iteration = 1,771 | max rel diff. = 0.00690487
# [2022-08-30 17:58:50.888] [jointLog] [info] Finished optimizer
# [2022-08-30 17:58:50.888] [jointLog] [info] writing output
#
# Version Info: Could not resolve upgrade information in the alotted time.
# Check for upgrades manually at https://combine-lab.github.io/salmon
# ### salmon (mapping-based) v1.2.1
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { ../scallop-genome/salmon.index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { fastq/hl60_6h_t_1.fastq.gz }
# ### [ output ] => { tinat/quants/hl60_6h_t_1 }
# ### [ threads ] => { 10 }
# Logs will be written to tinat/quants/hl60_6h_t_1/logs
# [2022-08-30 17:58:53.117] [jointLog] [info] setting maxHashResizeThreads to 10
# [2022-08-30 17:58:53.117] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2022-08-30 17:58:53.117] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2022-08-30 17:58:53.117] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2022-08-30 17:58:53.117] [jointLog] [info] parsing read library format
# [2022-08-30 17:58:53.117] [jointLog] [info] There is 1 library.
# [2022-08-30 17:58:53.194] [jointLog] [info] Loading pufferfish index
# [2022-08-30 17:58:53.195] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 273.63 ms
# -----------------------------------------
# size = 629063
# -----------------------------------------
# | Loading contig offsets | Time = 1.8805 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 475.83 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 43.512 ms
# -----------------------------------------
# size = 119911194
# Number of ones: 629062
# Number of ones per inventory item: 512
# Inventory entries filled: 1229
# -----------------------------------------
# | Loading contig boundaries | Time = 292.9 ms
# -----------------------------------------
# size = 119911194
# -----------------------------------------
# | Loading sequence | Time = 20.329 ms
# -----------------------------------------
# size = 101039334
# -----------------------------------------
# | Loading positions | Time = 170.81 ms
# -----------------------------------------
# size = 203602945
# -----------------------------------------
# | Loading reference sequence | Time = 23.089 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 1.1341 ms
# -----------------------------------------
#
#
#
#
# [2022-08-30 17:58:54.025] [jointLog] [info] done
# [2022-08-30 17:58:54.025] [jointLog] [info] Index contained 84,038 targets
# [2022-08-30 17:58:54.046] [jointLog] [info] Number of decoys : 0
# [2022-08-30 17:58:54.332] [jointLog] [info] Automatically detected most likely library type as SF
# processed 500,000 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# processed 5,000,000 fragments
# processed 5,500,000 fragments
# processed 6,000,000 fragments
# processed 6,500,000 fragments
# processed 7,000,000 fragments
# processed 7,500,000 fragments
# processed 8,000,000 fragments
# processed 8,500,000 fragments
# processed 9,000,000 fragments
# processed 9,500,001 fragments
# processed 10,000,000 fragments
# processed 10,500,000 fragments
# processed 11,000,001 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,000 fragments
# processed 13,000,000 fragments
# processed 13,500,000 fragments
# processed 14,000,000 fragments
# processed 14,500,000 fragments
# processed 15,000,000 fragments
# processed 15,500,001 fragments
# processed 16,000,002 fragments
# processed 16,500,000 fragments
# processed 17,000,000 fragments
# processed 17,500,000 fragments
# processed 18,000,000 fragments
# processed 18,500,000 fragments
# hits: 46,941,213; hits per frag:  2.54288[2022-08-30 17:59:30.066] [jointLog] [info] Thread saw mini-batch with a maximum of 2.40% zero probability fragments
# [2022-08-30 17:59:30.067] [jointLog] [info] Thread saw mini-batch with a maximum of 2.34% zero probability fragments
# [2022-08-30 17:59:30.109] [jointLog] [info] Thread saw mini-batch with a maximum of 2.36% zero probability fragments
# [2022-08-30 17:59:30.117] [jointLog] [info] Thread saw mini-batch with a maximum of 2.48% zero probability fragments
# [2022-08-30 17:59:30.126] [jointLog] [info] Thread saw mini-batch with a maximum of 2.42% zero probability fragments
# [2022-08-30 17:59:30.126] [jointLog] [info] Thread saw mini-batch with a maximum of 2.42% zero probability fragments
# [2022-08-30 17:59:30.140] [jointLog] [info] Thread saw mini-batch with a maximum of 2.34% zero probability fragments
# [2022-08-30 17:59:30.140] [jointLog] [info] Thread saw mini-batch with a maximum of 2.38% zero probability fragments
# [2022-08-30 17:59:30.146] [jointLog] [info] Thread saw mini-batch with a maximum of 2.42% zero probability fragments
# [2022-08-30 17:59:30.153] [jointLog] [info] Thread saw mini-batch with a maximum of 2.64% zero probability fragments
#
#
#
#
#
#
#
#
# [2022-08-30 17:59:30.433] [jointLog] [info] Computed 201,862 rich equivalence classes for further processing
# [2022-08-30 17:59:30.433] [jointLog] [info] Counted 14,332,161 total reads in the equivalence classes
# [2022-08-30 17:59:30.443] [jointLog] [info] Number of mappings discarded because of alignment score : 27,794,478
# [2022-08-30 17:59:30.443] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 201,137
# [2022-08-30 17:59:30.443] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2022-08-30 17:59:30.443] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 0
# [2022-08-30 17:59:30.443] [jointLog] [info] Mapping rate = 76.1971%
#
# [2022-08-30 17:59:30.443] [jointLog] [info] finished quantifyLibrary()
# [2022-08-30 17:59:30.458] [jointLog] [info] Starting optimizer
# [2022-08-30 17:59:30.536] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2022-08-30 17:59:30.554] [jointLog] [info] iteration = 0 | max rel diff. = 12125.4
# [2022-08-30 17:59:31.915] [jointLog] [info] iteration = 100 | max rel diff. = 15.4526
# [2022-08-30 17:59:33.221] [jointLog] [info] iteration = 200 | max rel diff. = 15.6922
# [2022-08-30 17:59:34.538] [jointLog] [info] iteration = 300 | max rel diff. = 15.3174
# [2022-08-30 17:59:35.849] [jointLog] [info] iteration = 400 | max rel diff. = 0.665522
# [2022-08-30 17:59:37.115] [jointLog] [info] iteration = 500 | max rel diff. = 0.1929
# [2022-08-30 17:59:38.380] [jointLog] [info] iteration = 600 | max rel diff. = 2.583
# [2022-08-30 17:59:39.672] [jointLog] [info] iteration = 700 | max rel diff. = 0.599975
# [2022-08-30 17:59:41.000] [jointLog] [info] iteration = 800 | max rel diff. = 0.906396
# [2022-08-30 17:59:42.310] [jointLog] [info] iteration = 900 | max rel diff. = 0.44308
# [2022-08-30 17:59:43.617] [jointLog] [info] iteration = 1,000 | max rel diff. = 0.458412
# [2022-08-30 17:59:44.924] [jointLog] [info] iteration = 1,100 | max rel diff. = 0.0488843
# [2022-08-30 17:59:46.230] [jointLog] [info] iteration = 1,200 | max rel diff. = 0.245259
# [2022-08-30 17:59:47.535] [jointLog] [info] iteration = 1,300 | max rel diff. = 0.0701022
# [2022-08-30 17:59:48.836] [jointLog] [info] iteration = 1,400 | max rel diff. = 0.0871919
# [2022-08-30 17:59:49.047] [jointLog] [info] iteration = 1,417 | max rel diff. = 0.00820302
# [2022-08-30 17:59:49.049] [jointLog] [info] Finished optimizer
# [2022-08-30 17:59:49.049] [jointLog] [info] writing output
#
# Version Info: Could not resolve upgrade information in the alotted time.
# Check for upgrades manually at https://combine-lab.github.io/salmon
# ### salmon (mapping-based) v1.2.1
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { ../scallop-genome/salmon.index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { fastq/hl60_6h_t_2.fastq.gz }
# ### [ output ] => { tinat/quants/hl60_6h_t_2 }
# ### [ threads ] => { 10 }
# Logs will be written to tinat/quants/hl60_6h_t_2/logs
# [2022-08-30 17:59:50.662] [jointLog] [info] setting maxHashResizeThreads to 10
# [2022-08-30 17:59:50.662] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2022-08-30 17:59:50.663] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2022-08-30 17:59:50.663] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2022-08-30 17:59:50.663] [jointLog] [info] parsing read library format
# [2022-08-30 17:59:50.663] [jointLog] [info] There is 1 library.
# [2022-08-30 17:59:50.740] [jointLog] [info] Loading pufferfish index
# [2022-08-30 17:59:50.740] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 276.22 ms
# -----------------------------------------
# size = 629063
# -----------------------------------------
# ...
# [2022-08-30 18:37:43.323] [jointLog] [info] iteration = 900 | max rel diff. = 12.9397
# [2022-08-30 18:37:45.018] [jointLog] [info] iteration = 1,000 | max rel diff. = 1.08901
# [2022-08-30 18:37:46.718] [jointLog] [info] iteration = 1,100 | max rel diff. = 0.0350655
# [2022-08-30 18:37:48.413] [jointLog] [info] iteration = 1,200 | max rel diff. = 0.034607
# [2022-08-30 18:37:50.092] [jointLog] [info] iteration = 1,300 | max rel diff. = 0.0096478
# [2022-08-30 18:37:50.096] [jointLog] [info] Finished optimizer
# [2022-08-30 18:37:50.096] [jointLog] [info] writing output
#
# Version Info: Could not resolve upgrade information in the alotted time.
# Check for upgrades manually at https://combine-lab.github.io/salmon
# ### salmon (mapping-based) v1.2.1
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { ../scallop-genome/salmon.index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { fastq/thp1_u_2.fastq.gz }
# ### [ output ] => { tinat/quants/thp1_u_2 }
# ### [ threads ] => { 10 }
# Logs will be written to tinat/quants/thp1_u_2/logs
# [2022-08-30 18:37:52.218] [jointLog] [info] setting maxHashResizeThreads to 10
# [2022-08-30 18:37:52.218] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2022-08-30 18:37:52.218] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2022-08-30 18:37:52.218] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2022-08-30 18:37:52.218] [jointLog] [info] parsing read library format
# [2022-08-30 18:37:52.219] [jointLog] [info] There is 1 library.
# [2022-08-30 18:37:52.279] [jointLog] [info] Loading pufferfish index
# [2022-08-30 18:37:52.280] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 222.47 ms
# -----------------------------------------
# size = 629063
# -----------------------------------------
# | Loading contig offsets | Time = 1.5513 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 404.67 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 35.48 ms
# -----------------------------------------
# size = 119911194
# Number of ones: 629062
# Number of ones per inventory item: 512
# Inventory entries filled: 1229
# -----------------------------------------
# | Loading contig boundaries | Time = 176.73 ms
# -----------------------------------------
# size = 119911194
# -----------------------------------------
# | Loading sequence | Time = 16.002 ms
# -----------------------------------------
# size = 101039334
# -----------------------------------------
# | Loading positions | Time = 167.57 ms
# -----------------------------------------
# size = 203602945
# -----------------------------------------
# | Loading reference sequence | Time = 26.375 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 624.03 us
# -----------------------------------------
# [2022-08-30 18:37:52.929] [jointLog] [info] done
# [2022-08-30 18:37:52.929] [jointLog] [info] Index contained 84,038 targets
# [2022-08-30 18:37:52.951] [jointLog] [info] Number of decoys : 0
#
#
#
#
# [2022-08-30 18:37:53.312] [jointLog] [info] Automatically detected most likely library type as SF
# processed 500,004 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# hits: 6,309,265; hits per frag:  1.80605
#
#
#
#
#
#
#
# [2022-08-30 18:37:59.517] [jointLog] [info] Thread saw mini-batch with a maximum of 2.42% zero probability fragments
# [2022-08-30 18:37:59.521] [jointLog] [info] Thread saw mini-batch with a maximum of 2.32% zero probability fragments
# [2022-08-30 18:37:59.525] [jointLog] [info] Thread saw mini-batch with a maximum of 2.40% zero probability fragments
# [2022-08-30 18:37:59.528] [jointLog] [info] Thread saw mini-batch with a maximum of 2.48% zero probability fragments
# [2022-08-30 18:37:59.530] [jointLog] [info] Thread saw mini-batch with a maximum of 2.30% zero probability fragments
# [2022-08-30 18:37:59.538] [jointLog] [info] Thread saw mini-batch with a maximum of 2.28% zero probability fragments
# [2022-08-30 18:37:59.554] [jointLog] [info] Thread saw mini-batch with a maximum of 2.44% zero probability fragments
# [2022-08-30 18:37:59.564] [jointLog] [info] Thread saw mini-batch with a maximum of 2.70% zero probability fragments
# [2022-08-30 18:37:59.566] [jointLog] [info] Thread saw mini-batch with a maximum of 2.32% zero probability fragments
# [2022-08-30 18:37:59.577] [jointLog] [info] Thread saw mini-batch with a maximum of 2.60% zero probability fragments
# [2022-08-30 18:37:59.717] [jointLog] [info] Computed 97,460 rich equivalence classes for further processing
# [2022-08-30 18:37:59.717] [jointLog] [info] Counted 1,882,999 total reads in the equivalence classes
# [2022-08-30 18:37:59.730] [jointLog] [info] Number of mappings discarded because of alignment score : 5,800,597
# [2022-08-30 18:37:59.730] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 40,465
# [2022-08-30 18:37:59.730] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2022-08-30 18:37:59.730] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 0
# [2022-08-30 18:37:59.740] [jointLog] [warning] Only 1882999 fragments were mapped, but the number of burn-in fragments was set to 5000000.
# The effective lengths have been computed using the observed mappings.
#
# [2022-08-30 18:37:59.740] [jointLog] [info] Mapping rate = 52.0369%
#
# [2022-08-30 18:37:59.740] [jointLog] [info] finished quantifyLibrary()
# [2022-08-30 18:37:59.742] [jointLog] [info] Starting optimizer
# [2022-08-30 18:37:59.798] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2022-08-30 18:37:59.806] [jointLog] [info] iteration = 0 | max rel diff. = 2138.53
# [2022-08-30 18:38:00.404] [jointLog] [info] iteration = 100 | max rel diff. = 14.2602
# [2022-08-30 18:38:00.940] [jointLog] [info] iteration = 200 | max rel diff. = 4.6854
# [2022-08-30 18:38:01.460] [jointLog] [info] iteration = 300 | max rel diff. = 2.71837
# [2022-08-30 18:38:01.980] [jointLog] [info] iteration = 400 | max rel diff. = 0.582685
# [2022-08-30 18:38:02.501] [jointLog] [info] iteration = 500 | max rel diff. = 0.189754
# [2022-08-30 18:38:03.019] [jointLog] [info] iteration = 600 | max rel diff. = 0.831543
# [2022-08-30 18:38:03.538] [jointLog] [info] iteration = 700 | max rel diff. = 0.105331
# [2022-08-30 18:38:04.057] [jointLog] [info] iteration = 800 | max rel diff. = 0.0243842
# [2022-08-30 18:38:04.576] [jointLog] [info] iteration = 900 | max rel diff. = 0.0163531
# [2022-08-30 18:38:05.097] [jointLog] [info] iteration = 1,000 | max rel diff. = 0.0906471
# [2022-08-30 18:38:05.159] [jointLog] [info] iteration = 1,013 | max rel diff. = 0.00358756
# [2022-08-30 18:38:05.161] [jointLog] [info] Finished optimizer
# [2022-08-30 18:38:05.161] [jointLog] [info] writing output
#
# Version Info: Could not resolve upgrade information in the alotted time.
# Check for upgrades manually at https://combine-lab.github.io/salmon
# ### salmon (mapping-based) v1.2.1
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { ../scallop-genome/salmon.index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { fastq/thp1_u_3.fastq.gz }
# ### [ output ] => { tinat/quants/thp1_u_3 }
# ### [ threads ] => { 10 }
# Logs will be written to tinat/quants/thp1_u_3/logs
# [2022-08-30 18:38:06.677] [jointLog] [info] setting maxHashResizeThreads to 10
# [2022-08-30 18:38:06.677] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2022-08-30 18:38:06.677] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2022-08-30 18:38:06.677] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2022-08-30 18:38:06.677] [jointLog] [info] parsing read library format
# [2022-08-30 18:38:06.677] [jointLog] [info] There is 1 library.
# [2022-08-30 18:38:06.747] [jointLog] [info] Loading pufferfish index
# [2022-08-30 18:38:06.747] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 266.09 ms
# -----------------------------------------
# size = 629063
# -----------------------------------------
# | Loading contig offsets | Time = 1.8484 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 432.76 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 47.014 ms
# -----------------------------------------
# size = 119911194
# Number of ones: 629062
# Number of ones per inventory item: 512
# Inventory entries filled: 1229
# -----------------------------------------
# | Loading contig boundaries | Time = 208.69 ms
# -----------------------------------------
# size = 119911194
# -----------------------------------------
# | Loading sequence | Time = 15.632 ms
# -----------------------------------------
# size = 101039334
# -----------------------------------------
# | Loading positions | Time = 171.47 ms
# -----------------------------------------
# size = 203602945
# -----------------------------------------
# | Loading reference sequence | Time = 25.442 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 626.57 us
# -----------------------------------------
#
#
#
#
# [2022-08-30 18:38:07.486] [jointLog] [info] done
# [2022-08-30 18:38:07.486] [jointLog] [info] Index contained 84,038 targets
# [2022-08-30 18:38:07.508] [jointLog] [info] Number of decoys : 0
# [2022-08-30 18:38:07.855] [jointLog] [info] Automatically detected most likely library type as SF
# processed 500,007 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,001 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# processed 5,000,000 fragments
# processed 5,500,000 fragments
# processed 6,000,000 fragments
# processed 6,500,000 fragments
# processed 7,000,001 fragments
# processed 7,500,000 fragments
# processed 8,000,000 fragments
# processed 8,500,000 fragments
# processed 9,000,001 fragments
# processed 9,500,000 fragments
# processed 10,000,000 fragments
# processed 10,500,001 fragments
# processed 11,000,001 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,001 fragments
# processed 13,000,000 fragments
# processed 13,500,000 fragments
# processed 14,000,001 fragments
# processed 14,500,000 fragments
# processed 15,000,000 fragments
# processed 15,500,000 fragments
# processed 16,000,000 fragments
# processed 16,500,000 fragments
# processed 17,000,002 fragments
# processed 17,500,000 fragments
# processed 18,000,000 fragments
# processed 18,500,000 fragments
# processed 19,000,000 fragments
# processed 19,500,000 fragments
# processed 20,000,000 fragments
# processed 20,500,000 fragments
# processed 21,000,000 fragments
# processed 21,500,002 fragments
# processed 22,000,000 fragments
# processed 22,500,000 fragments
# processed 23,000,000 fragments
# processed 23,500,000 fragments
# processed 24,000,000 fragments
# processed 24,500,000 fragments
# processed 25,000,001 fragments
# processed 25,500,001 fragments
# processed 26,000,000 fragments
# processed 26,500,000 fragments
# processed 27,000,001 fragments
# hits: 50,810,554; hits per frag:  1.88238[2022-08-30 18:38:55.123] [jointLog] [info] Thread saw mini-batch with a maximum of 2.88% zero probability fragments
# [2022-08-30 18:38:55.126] [jointLog] [info] Thread saw mini-batch with a maximum of 2.92% zero probability fragments
# [2022-08-30 18:38:55.140] [jointLog] [info] Thread saw mini-batch with a maximum of 2.82% zero probability fragments
# [2022-08-30 18:38:55.147] [jointLog] [info] Thread saw mini-batch with a maximum of 2.78% zero probability fragments
# [2022-08-30 18:38:55.164] [jointLog] [info] Thread saw mini-batch with a maximum of 2.76% zero probability fragments
# [2022-08-30 18:38:55.171] [jointLog] [info] Thread saw mini-batch with a maximum of 2.90% zero probability fragments
# [2022-08-30 18:38:55.176] [jointLog] [info] Thread saw mini-batch with a maximum of 2.78% zero probability fragments
# [2022-08-30 18:38:55.183] [jointLog] [info] Thread saw mini-batch with a maximum of 2.70% zero probability fragments
# [2022-08-30 18:38:55.197] [jointLog] [info] Thread saw mini-batch with a maximum of 2.74% zero probability fragments
# [2022-08-30 18:38:55.206] [jointLog] [info] Thread saw mini-batch with a maximum of 2.78% zero probability fragments
#
#
#
#
#
#
#
#
# [2022-08-30 18:38:55.489] [jointLog] [info] Computed 259,987 rich equivalence classes for further processing
# [2022-08-30 18:38:55.489] [jointLog] [info] Counted 14,969,815 total reads in the equivalence classes
# [2022-08-30 18:38:55.498] [jointLog] [info] Number of mappings discarded because of alignment score : 42,557,824
# [2022-08-30 18:38:55.498] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 304,327
# [2022-08-30 18:38:55.498] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2022-08-30 18:38:55.498] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 0
# [2022-08-30 18:38:55.498] [jointLog] [info] Mapping rate = 54.4566%
#
# [2022-08-30 18:38:55.498] [jointLog] [info] finished quantifyLibrary()
# [2022-08-30 18:38:55.500] [jointLog] [info] Starting optimizer
# [2022-08-30 18:38:55.597] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2022-08-30 18:38:55.619] [jointLog] [info] iteration = 0 | max rel diff. = 12417.8
# [2022-08-30 18:38:57.454] [jointLog] [info] iteration = 100 | max rel diff. = 14.2683
# [2022-08-30 18:38:59.261] [jointLog] [info] iteration = 200 | max rel diff. = 17.4989
# [2022-08-30 18:39:01.023] [jointLog] [info] iteration = 300 | max rel diff. = 4.57419
# [2022-08-30 18:39:02.777] [jointLog] [info] iteration = 400 | max rel diff. = 0.851111
# [2022-08-30 18:39:04.528] [jointLog] [info] iteration = 500 | max rel diff. = 0.480578
# [2022-08-30 18:39:06.279] [jointLog] [info] iteration = 600 | max rel diff. = 4.11699
# [2022-08-30 18:39:08.022] [jointLog] [info] iteration = 700 | max rel diff. = 0.256176
# [2022-08-30 18:39:09.771] [jointLog] [info] iteration = 800 | max rel diff. = 0.37541
# [2022-08-30 18:39:11.605] [jointLog] [info] iteration = 900 | max rel diff. = 0.0845212
# [2022-08-30 18:39:13.385] [jointLog] [info] iteration = 1,000 | max rel diff. = 0.572885
# [2022-08-30 18:39:15.196] [jointLog] [info] iteration = 1,100 | max rel diff. = 0.04401
# [2022-08-30 18:39:17.009] [jointLog] [info] iteration = 1,200 | max rel diff. = 0.271465
# [2022-08-30 18:39:18.826] [jointLog] [info] iteration = 1,300 | max rel diff. = 0.14852
# [2022-08-30 18:39:20.632] [jointLog] [info] iteration = 1,400 | max rel diff. = 0.680907
# [2022-08-30 18:39:22.441] [jointLog] [info] iteration = 1,500 | max rel diff. = 0.0245961
# [2022-08-30 18:39:24.253] [jointLog] [info] iteration = 1,600 | max rel diff. = 0.0973181
# [2022-08-30 18:39:26.066] [jointLog] [info] iteration = 1,700 | max rel diff. = 0.0219978
# [2022-08-30 18:39:27.885] [jointLog] [info] iteration = 1,800 | max rel diff. = 0.0707779
# [2022-08-30 18:39:28.648] [jointLog] [info] iteration = 1,843 | max rel diff. = 0.00752975
# [2022-08-30 18:39:28.652] [jointLog] [info] Finished optimizer
# [2022-08-30 18:39:28.652] [jointLog] [info] writing output

# %%
ls tinat/quants
# Out:
# hl60_120h_t_1/  hl60_72h_t_2/  molm14_t_1/   ociaml2_u_1/  thp1_t_1/
# hl60_120h_t_2/  hl60_72h_u_1/  molm14_t_2/   ociaml2_u_2/  thp1_t_2/
# hl60_120h_u_1/  hl60_72h_u_2/  molm14_t_3/   ociaml2_u_3/  thp1_t_3/
# hl60_120h_u_2/  kg1_t_1/       molm14_u_1/   ociaml3_t_1/  thp1_u_1/
# hl60_6h_t_1/    kg1_t_2/       molm14_u_2/   ociaml3_t_2/  thp1_u_2/
# hl60_6h_t_2/    kg1_t_3/       molm14_u_3/   ociaml3_t_3/  thp1_u_3/
# hl60_6h_u_1/    kg1_u_1/       ociaml2_t_1/  ociaml3_u_1/
# hl60_6h_u_2/    kg1_u_2/       ociaml2_t_2/  ociaml3_u_2/
# hl60_72h_t_1/   kg1_u_3/       ociaml2_t_3/  ociaml3_u_3/

# %%
# !date
# Out:
# Thu Oct 21 01:06:19 UTC 2021

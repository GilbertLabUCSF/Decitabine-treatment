# %%
#import packages
library('ggplot2')
library('RColorBrewer')
library('gridExtra')

# %% [markdown]
# ## sensitivity validation

# %% [markdown]
# ### dcp2

# %%
dcp2 <- read.table('dcp2_line_melt.txt', header = TRUE, sep = '\t',stringsAsFactors = T)
dcp2$sgrna <- relevel(dcp2$sgrna, 'non-targeting sgRNA')

head(dcp2)
# Out:
#   time sgrna               rep1 rep2 mean sd
# 1 0    DCP2 sg1            1.00 1.00 1.00 0.00
# 2 0    DCP2 sg2            1.00 1.00 1.00 0.00
# 3 0    non-targeting sgRNA 1.00 1.00 1.00 0.00
# 4 7    DCP2 sg1            0.52 0.43 0.47 0.06
# 5 7    DCP2 sg2            0.37 0.61 0.49 0.17
# 6 7    non-targeting sgRNA 1.14 1.00 1.07 0.11

# %%
p1 <- ggplot(dcp2, aes(x = time, y = mean, color = sgrna)) +
geom_line(size = 0.8) +
theme_classic() +
theme(plot.title = element_text(size = rel(1.75), color = 'black', face = 'bold', hjust = 0.5),
      axis.text.x = element_text(size = rel(1.75), color = 'black', angle = 0),
      axis.text.y = element_text(size = rel(1.75), color = 'black'),
      axis.title.x = element_text(size = rel(1.5)),
      axis.title.y = element_text(size = rel(1.5), margin = margin(r = 10)),
      legend.title = element_blank(),
      legend.text = element_text(size = rel(1), color = 'black'),
      legend.position = 'none'
      ) +
labs(title = 'DCP2', x = '', y = 'Relative fraction of\nsgRNA+ cells') + # Day
scale_x_continuous(limits = c(0,16), breaks = seq(0,15,5)) +
scale_y_continuous(limits = c(-0.05, 1.2), breaks = seq(0,1.2,0.2)) +
scale_color_manual(values = c('black', brewer.pal(4, 'Paired')[1:2])) +
geom_errorbar(aes(ymin = mean - sd, ymax = mean + sd, color = sgrna), width = 0.5) +
geom_point(size = 5)

# %% [markdown]
# ### scaf8

# %%
scaf8 <- read.table('scaf8_line_melt.txt', header = TRUE, sep = '\t',stringsAsFactors = T)
scaf8$sgrna <- relevel(scaf8$sgrna, 'non-targeting sgRNA')

head(scaf8)
# Out:
#   time sgrna               rep1 rep2 mean sd
# 1 0    SCAF8 sg1           1.00 1.00 1.00 0.00
# 2 0    SCAF8 sg2           1.00 1.00 1.00 0.00
# 3 0    non-targeting sgRNA 1.00 1.00 1.00 0.00
# 4 7    SCAF8 sg1           0.20 0.20 0.20 0.00
# 5 7    SCAF8 sg2           0.16 0.39 0.28 0.17
# 6 7    non-targeting sgRNA 1.14 1.00 1.07 0.11

# %%
p2 <- ggplot(scaf8, aes(x = time, y = mean, color = sgrna)) +
geom_line(size = 0.8) +
theme_classic() +
theme(plot.title = element_text(size = rel(1.75), color = 'black', face = 'bold', hjust = 0.5),
      axis.text.x = element_text(size = rel(1.75), color = 'black', angle = 0),
      axis.text.y = element_text(size = rel(1.75), color = 'black'),
      axis.title.x = element_text(size = rel(1.5)),
      axis.title.y = element_text(size = rel(1.5), margin = margin(r = 10)),
      legend.title = element_blank(),
      legend.text = element_text(size = rel(1.3), color = 'black'),
      legend.position = 'none'
      ) +
labs(title = 'SCAF8', x = '', y = '') + #Relative fraction of\nsgRNA+ cells #Day
scale_x_continuous(limits = c(0,16), breaks = seq(0,15,5)) +
scale_y_continuous(limits = c(-0.05, 1.2), breaks = seq(0,1.2,0.2)) +
scale_color_manual(values = c('black', brewer.pal(4, 'Paired')[1:2])) +
geom_errorbar(aes(ymin = mean - sd, ymax = mean + sd, color = sgrna), width = 0.5) +
geom_point(size = 5)

# %% [markdown]
# ### bcl2

# %%
bcl2 <- read.table('bcl2_line_melt.txt', header = TRUE, sep = '\t',stringsAsFactors = T)
bcl2$sgrna <- relevel(bcl2$sgrna, 'non-targeting sgRNA')

head(bcl2)
# Out:
#   time sgrna               mean sd
# 1 0    BCL2 sg1            1.00 0.00
# 2 0    BCL2 sg2            1.00 0.00
# 3 0    non-targeting sgRNA 1.00 0.00
# 4 7    BCL2 sg1            0.44 0.01
# 5 7    BCL2 sg2            0.30 0.00
# 6 7    non-targeting sgRNA 1.14 0.03

# %%
p3 <- ggplot(bcl2, aes(x = time, y = mean, color = sgrna)) +
geom_line(size = 0.8) +
theme_classic() +
theme(plot.title = element_text(size = rel(1.75), color = 'black', face = 'bold', hjust = 0.5),
      axis.text.x = element_text(size = rel(1.75), color = 'black', angle = 0),
      axis.text.y = element_text(size = rel(1.75), color = 'black'),
      axis.title.x = element_text(size = rel(1.5)),
      axis.title.y = element_text(size = rel(1.5), margin = margin(r = 10)),
      legend.title = element_blank(),
      legend.text = element_text(size = rel(1.3), color = 'black'),
      legend.position = 'none'
      ) +
labs(title = 'BCL2', x = 'Day', y = 'Relative fraction of\nsgRNA+ cells') +
scale_x_continuous(limits = c(0,16), breaks = seq(0,15,5)) +
scale_y_continuous(limits = c(-0.05, 1.2), breaks = seq(0,1.2,0.2)) +
scale_color_manual(values = c('black', brewer.pal(4, 'Paired')[1:2])) +
geom_errorbar(aes(ymin = mean - sd, ymax = mean + sd, color = sgrna), width = 0.5) +
geom_point(size = 5)

# %% [markdown]
# ### pten

# %%
pten <- read.table('pten_line_melt.txt', header = TRUE, sep = '\t',stringsAsFactors = T)
pten$sgrna <- relevel(pten$sgrna, 'non-targeting sgRNA')

head(pten)
# Out:
#   time sgrna               mean sd
# 1 0    PTEN sg1            1.00 0.00
# 2 0    PTEN sg2            1.00 0.00
# 3 0    non-targeting sgRNA 1.00 0.00
# 4 7    PTEN sg1            0.46 0.00
# 5 7    PTEN sg2            0.44 0.02
# 6 7    non-targeting sgRNA 1.14 0.03

# %%
p4 <- ggplot(pten, aes(x = time, y = mean, color = sgrna)) +
geom_line(size = 0.8) +
theme_classic() +
theme(plot.title = element_text(size = rel(1.75), color = 'black', face = 'bold', hjust = 0.5),
      axis.text.x = element_text(size = rel(1.75), color = 'black', angle = 0),
      axis.text.y = element_text(size = rel(1.75), color = 'black'),
      axis.title.x = element_text(size = rel(1.5)),
      axis.title.y = element_text(size = rel(1.5), margin = margin(r = 10)),
      legend.title = element_blank(),
      legend.text = element_text(size = rel(1.3), color = 'black'),
      legend.position = 'none'
      ) +
labs(title = 'PTEN', x = 'Day', y = '') + #Relative fraction of\nsgRNA+ cells
scale_x_continuous(limits = c(0,16), breaks = seq(0,15,5)) +
scale_y_continuous(limits = c(-0.05, 1.2), breaks = seq(0,1.2,0.2)) +
scale_color_manual(values = c('black', brewer.pal(4, 'Paired')[1:2])) +
geom_errorbar(aes(ymin = mean - sd, ymax = mean + sd, color = sgrna), width = 0.5) +
geom_point(size = 5)

# p4

# %% [markdown]
# ### save plots

# %%
# ggsave('sensitivity-validation-dcp2.pdf',p1, width = 4, height = 3)
# ggsave('sensitivity-validation-scaf8.pdf',p2, width = 4.5, height = 4)
# ggsave('sensitivity-validation-bcl2.pdf',p3, width = 4.5, height = 4)
# ggsave('sensitivity-validation-pten.pdf',p4, width = 4.5, height = 4)

# %%
x <- grid.arrange(p1, p2, p3, p4, nrow = 2, ncol = 2)
ggsave('sensitivity-validation-v2.pdf', plot = x, width = 8.3, height = 6.6)
# Out:
# plot without title

# %%
x <- grid.arrange(
    p1 + scale_y_continuous(limits = c(-0.05, 1.2), breaks = seq(0,1.2,0.5)) + labs(x = 'Day', y = 'Relative fraction of\nsgRNA+ cells') ,
    p2 + scale_y_continuous(limits = c(-0.05, 1.2), breaks = seq(0,1.2,0.5)) + labs(x = 'Day', y = ''),
    p3 + scale_y_continuous(limits = c(-0.05, 1.2), breaks = seq(0,1.2,0.5)) + labs(x = 'Day', y = ''),
    p4 + scale_y_continuous(limits = c(-0.05, 1.2), breaks = seq(0,1.2,0.5)) + labs(x = 'Day', y = ''),
    nrow = 1, ncol = 4)
ggsave('sensitivity-validation-v3.pdf', plot = x, width = 18, height = 3.5)
# Out:
# Scale for 'y' is already present. Adding another scale for 'y', which will
# replace the existing scale.
#
# Scale for 'y' is already present. Adding another scale for 'y', which will
# replace the existing scale.
#
# Scale for 'y' is already present. Adding another scale for 'y', which will
# replace the existing scale.
#
# Scale for 'y' is already present. Adding another scale for 'y', which will
# replace the existing scale.
# plot without title

# %% [markdown]
# ## resistance validation

# %% [markdown]
# ### dck

# %%
dck <- read.table('dck_line_melt.txt', header = TRUE, sep = '\t')
pten$sgrna <- relevel(pten$sgrna, 'non-targeting sgRNA')

head(dck)
# Out:
#   time sgrna               mean sd
# 1 0    DCK sg1             1.00 0.00
# 2 0    DCK sg2             1.00 0.00
# 3 0    non-targeting sgRNA 1.00 0.00
# 4 7    DCK sg1             3.83 0.08
# 5 7    DCK sg2             3.90 0.05
# 6 7    non-targeting sgRNA 0.87 0.02

# %%
p5 <- ggplot(dck, aes(x = time, y = mean, color = sgrna)) +
geom_line(size = 0.8) +
theme_classic() +
theme(plot.title = element_text(size = rel(1.75), color = 'black', face = 'bold', hjust = 0.5),
      axis.text.x = element_text(size = rel(1.75), color = 'black', angle = 0),
      axis.text.y = element_text(size = rel(1.75), color = 'black'),
      axis.title.x = element_text(size = rel(1.5)),
      axis.title.y = element_text(size = rel(1.5), margin = margin(r = 10)),
      legend.title = element_blank(),
      legend.text = element_text(size = rel(1.3), color = 'black'),
      legend.position = 'none'
      ) +
labs(title = 'DCK', x = 'Day', y = 'Relative fraction of\nsgRNA+ cells') +
scale_x_continuous(limits = c(0,16), breaks = seq(0,15,5)) +
scale_y_continuous(limits = c(-0.05, 15), breaks = seq(0,15,3)) +
scale_color_manual(values = c(brewer.pal(6, 'Paired')[5:6], 'black')) +
geom_errorbar(aes(ymin = mean - sd, ymax = mean + sd, color = sgrna), width = 0.5) +
geom_point(size = 5)

p5
# Out:
# plot without title

# %% [markdown]
# ### mettl3

# %%
mettl3 <- read.table('mettl3_line_melt.txt', header = TRUE, sep = '\t',stringsAsFactors = T)
mettl3$sgrna <- relevel(mettl3$sgrna, 'non-targeting sgRNA')

head(mettl3)
# Out:
#   time sgrna               rep1 rep2 mean sd
# 1 0    METTL3 sg1          1.00 1.00 1.00 0.00
# 2 0    METTL3 sg2          1.00 1.00 1.00 0.00
# 3 0    non-targeting sgRNA 1.00 1.00 1.00 0.00
# 4 3    METTL3 sg1          1.08 1.07 1.08 0.01
# 5 3    METTL3 sg2          1.06 1.04 1.05 0.01
# 6 3    non-targeting sgRNA 1.08 1.00 1.04 0.06

# %%
p6 <- ggplot(mettl3, aes(x = time, y = mean, color = sgrna)) +
geom_line(size = 0.8) +
theme_classic() +
theme(plot.title = element_text(size = rel(1.75), color = 'black', face = 'bold', hjust = 0.5),
      axis.text.x = element_text(size = rel(1.75), color = 'black', angle = 0),
      axis.text.y = element_text(size = rel(1.75), color = 'black'),
      axis.title.x = element_text(size = rel(1.5)),
      axis.title.y = element_text(size = rel(1.5), margin = margin(r = 10)),
      legend.title = element_blank(),
      legend.text = element_text(size = rel(1.3), color = 'black'),
      legend.position = 'none'
      ) +
labs(title = 'METTL3', x = 'Day', y = 'Relative fraction of\nsgRNA+ cells') +
scale_x_continuous(limits = c(0,16), breaks = seq(0,15,5)) +
scale_y_continuous(limits = c(0.7, 2), breaks = seq(0,3,0.5)) + 
scale_color_manual(values = c('black', brewer.pal(6, 'Paired')[5:6])) +
geom_errorbar(aes(ymin = mean - sd, ymax = mean + sd, color = sgrna), width = 0.5) +
geom_point(size = 5)

p6
# Out:
# plot without title

# %% [markdown]
# ### ythdf2

# %%
ythdf2 <- read.table('ythdf2_line_melt.txt', header = TRUE, sep = '\t',stringsAsFactors = T)
ythdf2$sgrna <- relevel(ythdf2$sgrna, 'non-targeting sgRNA')

head(ythdf2)
# Out:
#   time sgrna               rep1 rep2 mean sd
# 1 0    YTHDF2 sg1          1.00 1.00 1.00 0.00
# 2 0    YTHDF2 sg2          1.00 1.00 1.00 0.00
# 3 0    non-targeting sgRNA 1.00 1.00 1.00 0.00
# 4 3    YTHDF2 sg1          1.17 1.17 1.17 0.00
# 5 3    YTHDF2 sg2          1.14 1.12 1.13 0.02
# 6 3    non-targeting sgRNA 1.08 1.00 1.04 0.06

# %%
p7 <- ggplot(ythdf2, aes(x = time, y = mean, color = sgrna)) +
geom_line(size = 0.8) +
theme_classic() +
theme(plot.title = element_text(size = rel(1.75), color = 'black', face = 'bold', hjust = 0.5),
      axis.text.x = element_text(size = rel(1.75), color = 'black', angle = 0),
      axis.text.y = element_text(size = rel(1.75), color = 'black'),
      axis.title.x = element_text(size = rel(1.5)),
      axis.title.y = element_text(size = rel(1.5), margin = margin(r = 10)),
      legend.title = element_blank(),
      legend.text = element_text(size = rel(1.3), color = 'black'),
      legend.position = 'none'
      ) +
labs(title = 'YTHDF2', x = 'Day', y = 'Relative fraction of\nsgRNA+ cells') +
scale_x_continuous(limits = c(0,16), breaks = seq(0,15,5)) +
scale_y_continuous(limits = c(0.7, 3), breaks = seq(0,3,0.5)) +
scale_color_manual(values = c('black', brewer.pal(6, 'Paired')[5:6])) +
geom_errorbar(aes(ymin = mean - sd, ymax = mean + sd, color = sgrna), width = 0.5) +
geom_point(size = 5)

p7
# Out:
# plot without title

# %% [markdown]
# ### zc3h13

# %%
zc3h13 <- read.table('zc3h13_line_melt.txt', header = TRUE, sep = '\t',stringsAsFactors = T)
zc3h13$sgrna <- relevel(zc3h13$sgrna, 'non-targeting sgRNA')

head(zc3h13)
# Out:
#   time sgrna               rep1 rep2 mean sd
# 1 0    ZC3H13 sg1          1.00 1.00 1.00 0.00
# 2 0    ZC3H13 sg2          1.00 1.00 1.00 0.00
# 3 0    non-targeting sgRNA 1.00 1.00 1.00 0.00
# 4 3    ZC3H13 sg1          1.01 1.00 1.00 0.00
# 5 3    ZC3H13 sg2          0.98 0.98 0.98 0.00
# 6 3    non-targeting sgRNA 1.08 1.00 1.04 0.06

# %%
p8 <- ggplot(zc3h13, aes(x = time, y = mean, color = sgrna)) +
geom_line(size = 0.8) +
theme_classic() +
theme(plot.title = element_text(size = rel(1.75), color = 'black', face = 'bold', hjust = 0.5),
      axis.text.x = element_text(size = rel(1.75), color = 'black', angle = 0),
      axis.text.y = element_text(size = rel(1.75), color = 'black'),
      axis.title.x = element_text(size = rel(1.5)),
      axis.title.y = element_text(size = rel(1.5), margin = margin(r = 10)),
      legend.title = element_blank(),
      legend.text = element_text(size = rel(1.3), color = 'black'),
      legend.position = 'none'
      ) +
labs(title = 'ZC3H13', x = 'Day', y = 'Relative fraction of\nsgRNA+ cells') +
scale_x_continuous(limits = c(0,16), breaks = seq(0,15,5)) +
scale_y_continuous(limits = c(0.7, 2.6), breaks = seq(0,3,0.5)) +
scale_color_manual(values = c('black', brewer.pal(6, 'Paired')[5:6])) +
geom_errorbar(aes(ymin = mean - sd, ymax = mean + sd, color = sgrna), width = 0.5) +
geom_point(size = 5)

p8
# Out:
# plot without title

# %%
y <- grid.arrange(p5, p6, p7, p8, nrow = 2, ncol = 2)
ggsave('resistance_validation_dck.pdf',p5, width = 4.5, height = 4)
ggsave('resistance_validation_mettl3.pdf',p6, width = 4.5, height = 4)
ggsave('resistance_validation_ythdf2.pdf',p7, width = 4.5, height = 4)
ggsave('resistance_validation_zc3h13.pdf',p8, width = 4.5, height = 4)
# Out:
# plot without title

# %%
ggsave('resistance_validation_dck.pdf',p5, width = 4.5, height = 5)

# %%
y <- grid.arrange(
    p6 + labs(x = '', y = 'Relative fraction of\nsgRNA+ cells'), 
    p7 + labs(x = '', y = 'Relative fraction of\nsgRNA+ cells'), 
    p8 + labs(x = 'Day', y = 'Relative fraction of\nsgRNA+ cells'), 
    nrow = 3, ncol = 1)
ggsave('resistance_validation_v3.pdf', plot = y, width = 4, height = 8.6)
# Out:
# plot without title

# %%
# p9 <- ggplot(mettl3, aes(x = time, y = mean, color = sgrna)) +
# geom_line(size = 0.8) +
# theme_classic() +
# theme(plot.title = element_text(size = rel(1.75), color = 'black', face = 'bold', hjust = 0.5),
#       axis.text.x = element_text(size = rel(1.75), color = 'black', angle = 0),
#       axis.text.y = element_text(size = rel(1.75), color = 'black'),
#       axis.title.x = element_text(size = rel(1.5)),
#       axis.title.y = element_text(size = rel(1.5), margin = margin(r = 10)),
#       legend.title = element_blank(),
#       legend.text = element_text(size = rel(1.3), color = 'black'),
#       legend.position = 'none'
#       ) +
# labs(title = 'METTL3', x = 'Day', y = 'Relative fraction of\nsgRNA+ cells') +
# scale_x_continuous(limits = c(0,16), breaks = seq(0,15,5)) +
# scale_y_continuous(limits = c(0.75, 2), breaks = seq(0,2,0.5)) +
# scale_color_manual(values = c('black', brewer.pal(6, 'Paired')[5:6])) +
# geom_errorbar(aes(ymin = mean - sd, ymax = mean + sd, color = sgrna), width = 0.5) +
# geom_point(size = 5)

# p9

# %%
# z <- grid.arrange(p5, p9, nrow = 2, ncol = 1)
# ggsave('test3.pdf', plot = z, width = 4.15, height = 6.6)

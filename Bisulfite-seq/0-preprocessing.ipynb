# %% [markdown]
# https://f1000research.com/articles/6-2055/v2

# %% [markdown]
# > #### Resolution of the DNA methylation state of single CpG dyads using in silico strand annealing and WGBS data
# Nature protocol | https://www.nature.com/articles/s41596-018-0090-x
#
# > - Whole-genome bisulfite sequencing (WGBS) has been widely used to quantify cytosine DNA methylation frequency in an expanding array of cell and tissue types. Because of the denaturing conditions used, this method ultimately leads to the measurement of methylation frequencies at single cytosines.
# > - Hence, the methylation frequency of CpG dyads (two complementary CG dinucleotides) can be only indirectly inferred by overlaying the methylation frequency of two cytosines measured independently.
# > - Furthermore, hemi-methylated CpGs (hemiCpGs) have not been previously analyzed in WGBS studies. We recently developed in silico strand annealing (iSA), a bioinformatics method applicable to WGBS data, to resolve the methylation status of CpG dyads into __unmethylated__, __hemi-methylated__, and __methylated__.
# > - HemiCpGs account for 4–20% of the DNA methylome in different cell types, and some can be inherited across cell divisions, suggesting a role as a stable epigenetic mark. Therefore, it is important to resolve hemiCpGs from fully methylated CpGs in WGBS studies. This protocol describes step-by-step commands to accomplish this task, including dividing alignments by strand, pairing alignments between strands, and extracting single-fragment methylation calls.
# > - The versatility of iSA enables its application downstream of other WGBS-related methods such as nasBS-seq (nascent DNA bisulfite sequencing), ChIP-BSseq (ChIP followed by bisulfite sequencing), TAB-seq, oxBS-seq, and fCAB-seq. iSA is also tunable for analyzing the methylation status of cytosines in any sequence context.
# > - We exemplify this flexibility by uncovering the single-fragment non-CpG methylome.
# > - This protocol provides enough details for users with little experience in bioinformatic analysis and takes 2–7 h.

# %% [markdown]
# > #### Extended-representation bisulfite sequencing of gene regulatory elements in multiplexed samples and single cells
# https://www.nature.com/articles/s41587-021-00910-x
#
# <!-- > - Before alignment, primer dimers were filtered using Cutadapt version 2.7 and the following parameters: `--discard -a GCTCTTCCGATCT`. Short read pairs were trimmed using Trim Galore version 0.6.5 and the following parameters: `--paired --illumina --nextseq 20`.
# > - High-quality sequencing reads were then aligned to an in silico bisulfite-converted reference genome (hg38 and mm10) using methylCtools version 1.0.0 (https://github.com/hovestadt/methylCtools, ref. 49) and bwa mem version 0.7.17.
# > - Sorted alignments were further processed to only maintain uniquely mapped read pairs with a mapping score ≥1, that were mapping to an MspI cut site and that had an insert size between 20 bp and 600 bp. Putative PCR duplicates were removed by considering the outer mapping position of both paired-end reads (read 2 being located at the MspI cut site and read 1 being located at variable positions), as well as the random hexamer sequence that was trimmed before alignment and functions as a UMI. For library complexity analysis, alignments were downsampled before this step.
# > - We note that multiple random hexamer priming events during the second-strand synthesis step might lead to additional sequencing reads from the same original fragment that cannot be identified using this approach. DNA methylation calling was performed using methylCtools bcall and the --trimPE parameter. Detailed quality metrics for each library are provided in Supplementary Table 1. DNA methylation values were deposited in the GEO (GSE149954) for all samples reported in this study.
#
#
#  -->
#
#  This is simply called RRBS protocol :)

# %% [markdown]
# # SRA Data

# %% [markdown]
# my `sra` env

# %% [markdown]
# `fastq-dump`
#
# https://www.biostars.org/p/222122/

# %% [markdown]
# <!--     fastq-dump --outdir fastq --gzip --split-3 sra/SRR11711273.sra
#
#     Read 17522209 spots for sra/SRR11711273.sra
#     Written 17522209 spots for sra/SRR11711273.sra
#
#
# ___
#
#     parallel-fastq-dump --threads 12 --outdir fastq/ --split-files --gzip sra/SRR11711272.sra -->
#
#
# <!--     fasterq-dump --split-files --include-technical --threads 1
#     --temp . --outfile HL60_10ng_dmso.fastq --progress SRR11711272
#
#
#     fasterq-dump --split-files --include-technical --threads 1
#     --temp . --outfile HL60_10ng_decitabine.fastq --progress SRR11711273 -->
#
#
#     wget ftp.sra.ebi.ac.uk/vol1/fastq/SRR117/072/SRR11711272/SRR11711272_1.fastq.gz
#     wget ftp.sra.ebi.ac.uk/vol1/fastq/SRR117/072/SRR11711272/SRR11711272_2.fastq.gz
#
#     wget ftp.sra.ebi.ac.uk/vol1/fastq/SRR117/073/SRR11711273/SRR11711273_1.fastq.gz
#     wget ftp.sra.ebi.ac.uk/vol1/fastq/SRR117/073/SRR11711273/SRR11711273_2.fastq.gz

# %%
mkdir fastq

# %%
# !mv -v *fastq.gz fastq/
# Out:
# ‘SRR11711272_1.fastq.gz’ -> ‘fastq/SRR11711272_1.fastq.gz’
# ‘SRR11711272_2.fastq.gz’ -> ‘fastq/SRR11711272_2.fastq.gz’
# ‘SRR11711273_1.fastq.gz’ -> ‘fastq/SRR11711273_1.fastq.gz’
# ‘SRR11711273_2.fastq.gz’ -> ‘fastq/SRR11711273_2.fastq.gz’

# %% [markdown]
# # Reading and annotating the methylation counts

# %% [markdown]
# ## Trimming

# %% [markdown]
# <!-- > Before alignment, primer dimers were filtered using Cutadapt version 2.7 and the following parameters: `--discard -a GCTCTTCCGATCT`. Short read pairs were trimmed using Trim Galore version 0.6.5 and the following parameters: `--paired --illumina --nextseq 20`. -->

# %%
# !mkdir -p logs/
# !mkdir -p logs/trim_galore/

# %%
# %%bash
# for fq1 in fastq/*1.fastq.gz; do
#     fq2=${fq1/1.fastq/2.fastq}
#     b=`basename $fq1`
#     log_file=${b/_1.fastq.gz/.log}
#     cm="trim_galore --core 3 --paired --rrbs -o fastq $fq1 $fq2"
#     echo $cm
#     $cm &> logs/trim_galore/$log_file;
#     wait
# done
# Out:
# trim_galore --core 3 --paired --rrbs -o fastq fastq/SRR11711272_1.fastq.gz fastq/SRR11711272_2.fastq.gz
# trim_galore --core 3 --paired --rrbs -o fastq fastq/SRR11711273_1.fastq.gz fastq/SRR11711273_2.fastq.gz

# %%
mv -v fastq/*trimming_report.txt logs/trim_galore/
# Out:
# ‘fastq/SRR11711272_1.fastq.gz_trimming_report.txt’ -> ‘logs/trim_galore/SRR11711272_1.fastq.gz_trimming_report.txt’
# ‘fastq/SRR11711272_2.fastq.gz_trimming_report.txt’ -> ‘logs/trim_galore/SRR11711272_2.fastq.gz_trimming_report.txt’
# ‘fastq/SRR11711273_1.fastq.gz_trimming_report.txt’ -> ‘logs/trim_galore/SRR11711273_1.fastq.gz_trimming_report.txt’
# ‘fastq/SRR11711273_2.fastq.gz_trimming_report.txt’ -> ‘logs/trim_galore/SRR11711273_2.fastq.gz_trimming_report.txt’

# %%
# !multiqc logs/trim_galore/ -f -n multiqc-trim
# Out:
#   /// ]8;id=765597;https://multiqc.info\MultiQC]8;;\ 🔍 | v1.12
#
# |           multiqc | Search path : /data_gilbert/home/aarab/Projects/Decitabine-treatment/Bisulfite-seq/logs/trim_galore
# |         searching | ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 6/6  xtlogs/trim_galore/SRR11711273.log
# |          cutadapt | Found 4 reports
# |           multiqc | Compressing plot data
# |           multiqc | Deleting    : multiqc-trim.html   (-f was specified)
# |           multiqc | Deleting    : multiqc-trim_data   (-f was specified)
# |           multiqc | Report      : multiqc-trim.html
# |           multiqc | Data        : multiqc-trim_data
# |           multiqc | MultiQC complete

# %% [markdown]
# ## Processing the BS-seq FASTQ files with Bismark

# %% [markdown]
# Bismark -
# https://github.com/FelixKrueger/Bismark

# %% [markdown]
# It faild maybe because of the genome annotation - [there's no output result #34
# ](https://github.com/FelixKrueger/Bismark/issues/34)

# %% [markdown]
# I've discussed my issues here https://github.com/FelixKrueger/Bismark/issues/475

# %% [markdown]
# ### Index genome

# %% [markdown]
# __(I) Running bismark_genome_preparation__

# %%
# !bismark_genome_preparation ~/genomes/hg38/gencode.v34/

# %%
# !gzip -d /data_gilbert/home/aarab/genomes/hg38/chromosomes/*.fa.gz

# %%
# !bismark_genome_preparation --verbose ~/genomes/hg38/chromosomes/
# Out:
# Path to genome folder specified as: /data_gilbert/home/aarab/genomes/hg38/chromosomes/
# Aligner to be used: >> Bowtie 2 << (default)
# Writing bisulfite genomes out into a single MFA (multi FastA) file
#
# Bismark Genome Preparation - Step I: Preparing folders
#
# Bisulfite Genome Indexer version v0.23.1 (last modified: 27 Jan 2021)
# Created Bisulfite Genome folder /data_gilbert/home/aarab/genomes/hg38/chromosomes/Bisulfite_Genome/
# Created Bisulfite Genome folder /data_gilbert/home/aarab/genomes/hg38/chromosomes/Bisulfite_Genome/CT_conversion/
# Created Bisulfite Genome folder /data_gilbert/home/aarab/genomes/hg38/chromosomes/Bisulfite_Genome/GA_conversion/
#
# Step I - Prepare genome folders - completed
#
#
# Bismark Genome Preparation - Step II: Bisulfite converting reference genome
#
# conversions performed:
# chromosome	C->T	G->A
# chr1	48055043	48111528
# chr10	27639505	27719976
# chr11	27903257	27981801
# chr12	27092804	27182678
# chr13	18839192	18933605
# chr14	18423758	18559033
# chr15	17752941	17825903
# chr16	18172742	18299976
# chr17	18723944	18851500
# chr18	15794455	16061651
# chr19	13954580	14061132
# chr2	48318180	48450903
# chr20	13916133	14094472
# chr21	8185244	8226381
# chr22	9160652	9246186
# chr3	39233483	39344259
# chr4	36236976	36331025
# chr5	35731600	35879674
# chr6	33646690	33713330
# chr7	32317984	32378859
# chr8	29030173	29103787
# chr9	25099811	25170662
# chrM	5181	2169
# chrX	30523780	30697741
# chrY	5285789	5286894
#
# Total number of conversions performed:
# C->T:	599043897
# G->A:	601515125
#
# Step II - Genome bisulfite conversions - completed
#
#
# Bismark Genome Preparation - Step III: Launching the Bowtie 2 indexer
# Please be aware that this process can - depending on genome size - take several hours!
#
# Preparing indexing of CT converted genome in /data_gilbert/home/aarab/genomes/hg38/chromosomes/Bisulfite_Genome/CT_conversion/
# Parent process: Starting to index C->T converted genome with the following command:
#
# bowtie2-build  -f genome_mfa.CT_conversion.fa BS_CT
#
# Settings:
#   Output files: "BS_CT.*.bt2"
#   Line rate: 6 (line is 64 bytes)
#   Lines per side: 1 (side is 64 bytes)
#   Offset rate: 4 (one in 16)
#   FTable chars: 10
#   Strings: unpacked
#   Max bucket size: default
#   Max bucket size, sqrt multiplier: default
#   Max bucket size, len divisor: 4
#   Difference-cover sample period: 1024
#   Endianness: little
#   Actual local endianness: little
#   Sanity checking: disabled
#   Assertions: disabled
#   Random seed: 0
#   Sizeofs: void*:8, int:4, long:8, size_t:8
# Input files DNA, FASTA:
#   genome_mfa.CT_conversion.fa
# Building a SMALL index
# Reading reference sizes
# Preparing indexing of GA converted genome in /data_gilbert/home/aarab/genomes/hg38/chromosomes/Bisulfite_Genome/GA_conversion/
# Child process: Starting to index G->A converted genome with the following command:
#
# bowtie2-build  -f genome_mfa.GA_conversion.fa BS_GA
#
# Settings:
#   Output files: "BS_GA.*.bt2"
#   Line rate: 6 (line is 64 bytes)
#   Lines per side: 1 (side is 64 bytes)
#   Offset rate: 4 (one in 16)
#   FTable chars: 10
#   Strings: unpacked
#   Max bucket size: default
#   Max bucket size, sqrt multiplier: default
#   Max bucket size, len divisor: 4
#   Difference-cover sample period: 1024
#   Endianness: little
#   Actual local endianness: little
#   Sanity checking: disabled
#   Assertions: disabled
#   Random seed: 0
#   Sizeofs: void*:8, int:4, long:8, size_t:8
# Input files DNA, FASTA:
#   genome_mfa.GA_conversion.fa
# Building a SMALL index
# Reading reference sizes
#   Time reading reference sizes: 00:00:17
# Calculating joined length
# Writing header
# Reserving space for joined string
# Joining reference sequences
#   Time reading reference sizes: 00:00:17
# Calculating joined length
# Writing header
# Reserving space for joined string
# Joining reference sequences
#   Time to join reference sequences: 00:00:16
# bmax according to bmaxDivN setting: 734413920
# Using parameters --bmax 550810440 --dcv 1024
#   Doing ahead-of-time memory usage test
#   Time to join reference sequences: 00:00:16
# bmax according to bmaxDivN setting: 734413920
# Using parameters --bmax 550810440 --dcv 1024
#   Doing ahead-of-time memory usage test
#   Passed!  Constructing with these parameters: --bmax 550810440 --dcv 1024
# Constructing suffix-array element generator
# Building DifferenceCoverSample
#   Building sPrime
#   Building sPrimeOrder
#   V-Sorting samples
#   Passed!  Constructing with these parameters: --bmax 550810440 --dcv 1024
# Constructing suffix-array element generator
# Building DifferenceCoverSample
#   Building sPrime
#   Building sPrimeOrder
#   V-Sorting samples
#   V-Sorting samples time: 00:01:35
#   Allocating rank array
#   Ranking v-sort output
#   V-Sorting samples time: 00:01:37
#   Allocating rank array
#   Ranking v-sort output
#   Ranking v-sort output time: 00:00:28
#   Invoking Larsson-Sadakane on ranks
#   Ranking v-sort output time: 00:00:29
#   Invoking Larsson-Sadakane on ranks
#   Invoking Larsson-Sadakane on ranks time: 00:00:42
#   Sanity-checking and returning
# Building samples
# Reserving space for 12 sample suffixes
# Generating random suffixes
# QSorting 12 sample offsets, eliminating duplicates
# QSorting sample offsets, eliminating duplicates time: 00:00:00
# Multikey QSorting 12 samples
#   (Using difference cover)
#   Multikey QSorting samples time: 00:00:00
# Calculating bucket sizes
#   Invoking Larsson-Sadakane on ranks time: 00:00:42
#   Sanity-checking and returning
# Building samples
# Reserving space for 12 sample suffixes
# Generating random suffixes
# QSorting 12 sample offsets, eliminating duplicates
# QSorting sample offsets, eliminating duplicates time: 00:00:00
# Multikey QSorting 12 samples
#   (Using difference cover)
#   Multikey QSorting samples time: 00:00:00
# Calculating bucket sizes
# Splitting and merging
#   Splitting and merging time: 00:00:00
# Avg bucket size: 4.19665e+08 (target: 550810439)
# Converting suffix-array elements to index image
# Allocating ftab, absorbFtab
# Entering Ebwt loop
# Getting block 1 of 7
#   Reserving size (550810440) for bucket 1
#   Calculating Z arrays for bucket 1
#   Entering block accumulator loop for bucket 1:
#   bucket 1: 10%
# Splitting and merging
#   Splitting and merging time: 00:00:00
# Avg bucket size: 3.67207e+08 (target: 550810439)
# Converting suffix-array elements to index image
# Allocating ftab, absorbFtab
# Entering Ebwt loop
# Getting block 1 of 8
#   Reserving size (550810440) for bucket 1
#   Calculating Z arrays for bucket 1
#   Entering block accumulator loop for bucket 1:
#   bucket 1: 20%
#   bucket 1: 10%
#   bucket 1: 30%
#   bucket 1: 20%
#   bucket 1: 40%
#   bucket 1: 30%
#   bucket 1: 50%
#   bucket 1: 40%
#   bucket 1: 60%
#   bucket 1: 50%
#   bucket 1: 70%
#   bucket 1: 60%
#   bucket 1: 80%
#   bucket 1: 70%
#   bucket 1: 90%
#   bucket 1: 80%
#   bucket 1: 100%
#   Sorting block of length 506437153 for bucket 1
#   (Using difference cover)
#   bucket 1: 90%
#   bucket 1: 100%
#   Sorting block of length 265840023 for bucket 1
#   (Using difference cover)
#   Sorting block time: 00:03:32
# Returning block of 265840024 for bucket 1
# Getting block 2 of 8
#   Reserving size (550810440) for bucket 2
#   Calculating Z arrays for bucket 2
#   Entering block accumulator loop for bucket 2:
#   bucket 2: 10%
#   bucket 2: 20%
#   bucket 2: 30%
#   bucket 2: 40%
#   bucket 2: 50%
#   bucket 2: 60%
#   bucket 2: 70%
#   bucket 2: 80%
#   bucket 2: 90%
#   bucket 2: 100%
#   Sorting block of length 313712311 for bucket 2
#   (Using difference cover)
#   Sorting block time: 00:09:16
# Returning block of 506437154 for bucket 1
#   Sorting block time: 00:04:24
# Returning block of 313712312 for bucket 2
# Getting block 3 of 8
#   Reserving size (550810440) for bucket 3
#   Calculating Z arrays for bucket 3
#   Entering block accumulator loop for bucket 3:
#   bucket 3: 10%
#   bucket 3: 20%
#   bucket 3: 30%
#   bucket 3: 40%
#   bucket 3: 50%
#   bucket 3: 60%
# Getting block 2 of 7
#   Reserving size (550810440) for bucket 2
#   Calculating Z arrays for bucket 2
#   Entering block accumulator loop for bucket 2:
#   bucket 3: 70%
#   bucket 3: 80%
#   bucket 2: 10%
#   bucket 3: 90%
#   bucket 2: 20%
#   bucket 3: 100%
#   Sorting block of length 269510198 for bucket 3
#   (Using difference cover)
#   bucket 2: 30%
#   bucket 2: 40%
#   bucket 2: 50%
#   bucket 2: 60%
#   bucket 2: 70%
#   bucket 2: 80%
#   bucket 2: 90%
#   bucket 2: 100%
#   Sorting block of length 447885829 for bucket 2
#   (Using difference cover)
#   Sorting block time: 00:03:48
# Returning block of 269510199 for bucket 3
# Getting block 4 of 8
#   Reserving size (550810440) for bucket 4
#   Calculating Z arrays for bucket 4
#   Entering block accumulator loop for bucket 4:
#   bucket 4: 10%
#   bucket 4: 20%
#   bucket 4: 30%
#   bucket 4: 40%
#   bucket 4: 50%
#   bucket 4: 60%
#   bucket 4: 70%
#   bucket 4: 80%
#   bucket 4: 90%
#   bucket 4: 100%
#   Sorting block of length 416425897 for bucket 4
#   (Using difference cover)
#   Sorting block time: 00:08:18
# Returning block of 447885830 for bucket 2
# Getting block 3 of 7
#   Reserving size (550810440) for bucket 3
#   Calculating Z arrays for bucket 3
#   Entering block accumulator loop for bucket 3:
#   bucket 3: 10%
#   bucket 3: 20%
#   bucket 3: 30%
#   bucket 3: 40%
#   bucket 3: 50%
#   bucket 3: 60%
#   bucket 3: 70%
#   bucket 3: 80%
#   bucket 3: 90%
#   bucket 3: 100%
#   Sorting block of length 539608788 for bucket 3
#   (Using difference cover)
#   Sorting block time: 00:06:03
# Returning block of 416425898 for bucket 4
# Getting block 5 of 8
#   Reserving size (550810440) for bucket 5
#   Calculating Z arrays for bucket 5
#   Entering block accumulator loop for bucket 5:
#   bucket 5: 10%
#   bucket 5: 20%
#   bucket 5: 30%
#   bucket 5: 40%
#   bucket 5: 50%
#   bucket 5: 60%
#   bucket 5: 70%
#   bucket 5: 80%
#   bucket 5: 90%
#   bucket 5: 100%
#   Sorting block of length 480655197 for bucket 5
#   (Using difference cover)
#   Sorting block time: 00:07:12
# Returning block of 480655198 for bucket 5
#   Sorting block time: 00:10:41
# Returning block of 539608789 for bucket 3
# Getting block 6 of 8
#   Reserving size (550810440) for bucket 6
#   Calculating Z arrays for bucket 6
#   Entering block accumulator loop for bucket 6:
#   bucket 6: 10%
#   bucket 6: 20%
#   bucket 6: 30%
#   bucket 6: 40%
#   bucket 6: 50%
#   bucket 6: 60%
#   bucket 6: 70%
#   bucket 6: 80%
#   bucket 6: 90%
#   bucket 6: 100%
#   Sorting block of length 367604136 for bucket 6
#   (Using difference cover)
# Getting block 4 of 7
#   Reserving size (550810440) for bucket 4
#   Calculating Z arrays for bucket 4
#   Entering block accumulator loop for bucket 4:
#   bucket 4: 10%
#   bucket 4: 20%
#   bucket 4: 30%
#   bucket 4: 40%
#   bucket 4: 50%
#   bucket 4: 60%
#   bucket 4: 70%
#   bucket 4: 80%
#   bucket 4: 90%
#   bucket 4: 100%
#   Sorting block of length 384792641 for bucket 4
#   (Using difference cover)
#   Sorting block time: 00:05:38
# Returning block of 367604137 for bucket 6
# Getting block 7 of 8
#   Reserving size (550810440) for bucket 7
#   Calculating Z arrays for bucket 7
#   Entering block accumulator loop for bucket 7:
#   bucket 7: 10%
#   bucket 7: 20%
#   bucket 7: 30%
#   bucket 7: 40%
#   bucket 7: 50%
#   bucket 7: 60%
#   bucket 7: 70%
#   bucket 7: 80%
#   bucket 7: 90%
#   bucket 7: 100%
#   Sorting block of length 547961096 for bucket 7
#   (Using difference cover)
#   Sorting block time: 00:07:14
# Returning block of 384792642 for bucket 4
# Getting block 5 of 7
#   Reserving size (550810440) for bucket 5
#   Calculating Z arrays for bucket 5
#   Entering block accumulator loop for bucket 5:
#   bucket 5: 10%
#   bucket 5: 20%
#   bucket 5: 30%
#   bucket 5: 40%
#   bucket 5: 50%
#   bucket 5: 60%
#   bucket 5: 70%
#   bucket 5: 80%
#   bucket 5: 90%
#   bucket 5: 100%
#   Sorting block of length 459841719 for bucket 5
#   (Using difference cover)
#   Sorting block time: 00:08:14
# Returning block of 547961097 for bucket 7
# Getting block 8 of 8
#   Reserving size (550810440) for bucket 8
#   Calculating Z arrays for bucket 8
#   Entering block accumulator loop for bucket 8:
#   bucket 8: 10%
#   bucket 8: 20%
#   bucket 8: 30%
#   bucket 8: 40%
#   bucket 8: 50%
#   bucket 8: 60%
#   bucket 8: 70%
#   bucket 8: 80%
#   bucket 8: 90%
#   bucket 8: 100%
#   Sorting block of length 275946816 for bucket 8
#   (Using difference cover)
#   Sorting block time: 00:08:57
# Returning block of 459841720 for bucket 5
# Getting block 6 of 7
#   Reserving size (550810440) for bucket 6
#   Calculating Z arrays for bucket 6
#   Entering block accumulator loop for bucket 6:
#   bucket 6: 10%
#   bucket 6: 20%
#   bucket 6: 30%
#   bucket 6: 40%
#   bucket 6: 50%
#   bucket 6: 60%
#   bucket 6: 70%
#   bucket 6: 80%
#   bucket 6: 90%
#   bucket 6: 100%
#   Sorting block of length 328692208 for bucket 6
#   (Using difference cover)
#   Sorting block time: 00:04:02
# Returning block of 275946817 for bucket 8
# Exited Ebwt loop
# fchr[A]: 0
# fchr[C]: 1468669118
# fchr[G]: 2067713015
# fchr[T]: 2067713015
# fchr[$]: 2937655681
# Exiting Ebwt::buildToDisk()
# Returning from initFromVector
# Wrote 983425384 bytes to primary EBWT file: BS_GA.1.bt2.tmp
# Wrote 734413928 bytes to secondary EBWT file: BS_GA.2.bt2.tmp
# Re-opening _in1 and _in2 as input streams
# Returning from Ebwt constructor
# Headers:
#     len: 2937655681
#     bwtLen: 2937655682
#     sz: 734413921
#     bwtSz: 734413921
#     lineRate: 6
#     offRate: 4
#     offMask: 0xfffffff0
#     ftabChars: 10
#     eftabLen: 20
#     eftabSz: 80
#     ftabLen: 1048577
#     ftabSz: 4194308
#     offsLen: 183603481
#     offsSz: 734413924
#     lineSz: 64
#     sideSz: 64
#     sideBwtSz: 48
#     sideBwtLen: 192
#     numSides: 15300291
#     numLines: 15300291
#     ebwtTotLen: 979218624
#     ebwtTotSz: 979218624
#     color: 0
#     reverse: 0
# Total time for call to driver() for forward index: 01:03:58
# Reading reference sizes
#   Time reading reference sizes: 00:00:13
# Calculating joined length
# Writing header
# Reserving space for joined string
# Joining reference sequences
#   Time to join reference sequences: 00:00:16
#   Time to reverse reference sequence: 00:00:02
# bmax according to bmaxDivN setting: 734413920
# Using parameters --bmax 550810440 --dcv 1024
#   Doing ahead-of-time memory usage test
#   Passed!  Constructing with these parameters: --bmax 550810440 --dcv 1024
# Constructing suffix-array element generator
# Building DifferenceCoverSample
#   Building sPrime
#   Building sPrimeOrder
#   V-Sorting samples
#   V-Sorting samples time: 00:01:36
#   Allocating rank array
#   Ranking v-sort output
#   Ranking v-sort output time: 00:00:29
#   Invoking Larsson-Sadakane on ranks
#   Invoking Larsson-Sadakane on ranks time: 00:00:42
#   Sanity-checking and returning
# Building samples
# Reserving space for 12 sample suffixes
# Generating random suffixes
# QSorting 12 sample offsets, eliminating duplicates
# QSorting sample offsets, eliminating duplicates time: 00:00:00
# Multikey QSorting 12 samples
#   (Using difference cover)
#   Multikey QSorting samples time: 00:00:00
# Calculating bucket sizes
#   Sorting block time: 00:06:25
# Returning block of 328692209 for bucket 6
# Splitting and merging
#   Splitting and merging time: 00:00:00
# Avg bucket size: 3.67207e+08 (target: 550810439)
# Converting suffix-array elements to index image
# Allocating ftab, absorbFtab
# Entering Ebwt loop
# Getting block 1 of 8
#   Reserving size (550810440) for bucket 1
#   Calculating Z arrays for bucket 1
#   Entering block accumulator loop for bucket 1:
#   bucket 1: 10%
#   bucket 1: 20%
#   bucket 1: 30%
#   bucket 1: 40%
#   bucket 1: 50%
#   bucket 1: 60%
#   bucket 1: 70%
#   bucket 1: 80%
#   bucket 1: 90%
#   bucket 1: 100%
#   Sorting block of length 393309086 for bucket 1
#   (Using difference cover)
# Getting block 7 of 7
#   Reserving size (550810440) for bucket 7
#   Calculating Z arrays for bucket 7
#   Entering block accumulator loop for bucket 7:
#   bucket 7: 10%
#   bucket 7: 20%
#   bucket 7: 30%
#   bucket 7: 40%
#   bucket 7: 50%
#   bucket 7: 60%
#   bucket 7: 70%
#   bucket 7: 80%
#   bucket 7: 90%
#   bucket 7: 100%
#   Sorting block of length 270397337 for bucket 7
#   (Using difference cover)
#   Sorting block time: 00:05:32
# Returning block of 393309087 for bucket 1
#   Sorting block time: 00:05:16
# Returning block of 270397338 for bucket 7
# Getting block 2 of 8
#   Reserving size (550810440) for bucket 2
#   Calculating Z arrays for bucket 2
#   Entering block accumulator loop for bucket 2:
#   bucket 2: 10%
#   bucket 2: 20%
#   bucket 2: 30%
#   bucket 2: 40%
#   bucket 2: 50%
#   bucket 2: 60%
#   bucket 2: 70%
# Exited Ebwt loop
# fchr[A]: 0
# fchr[C]: 867153993
# fchr[G]: 867153993
# fchr[T]: 1468669118
# fchr[$]: 2937655681
# Exiting Ebwt::buildToDisk()
# Returning from initFromVector
# Wrote 983425384 bytes to primary EBWT file: BS_CT.1.bt2.tmp
# Wrote 734413928 bytes to secondary EBWT file: BS_CT.2.bt2.tmp
# Re-opening _in1 and _in2 as input streams
# Returning from Ebwt constructor
# Headers:
#     len: 2937655681
#     bwtLen: 2937655682
#     sz: 734413921
#     bwtSz: 734413921
#     lineRate: 6
#     offRate: 4
#     offMask: 0xfffffff0
#     ftabChars: 10
#     eftabLen: 20
#     eftabSz: 80
#     ftabLen: 1048577
#     ftabSz: 4194308
#     offsLen: 183603481
#     offsSz: 734413924
#     lineSz: 64
#     sideSz: 64
#     sideBwtSz: 48
#     sideBwtLen: 192
#     numSides: 15300291
#     numLines: 15300291
#     ebwtTotLen: 979218624
#     ebwtTotSz: 979218624
#     color: 0
#     reverse: 0
# Total time for call to driver() for forward index: 01:16:51
# Reading reference sizes
#   bucket 2: 80%
#   bucket 2: 90%
#   bucket 2: 100%
#   Sorting block of length 469629838 for bucket 2
#   (Using difference cover)
#   Time reading reference sizes: 00:00:14
# Calculating joined length
# Writing header
# Reserving space for joined string
# Joining reference sequences
#   Time to join reference sequences: 00:00:15
#   Time to reverse reference sequence: 00:00:02
# bmax according to bmaxDivN setting: 734413920
# Using parameters --bmax 550810440 --dcv 1024
#   Doing ahead-of-time memory usage test
#   Passed!  Constructing with these parameters: --bmax 550810440 --dcv 1024
# Constructing suffix-array element generator
# Building DifferenceCoverSample
#   Building sPrime
#   Building sPrimeOrder
#   V-Sorting samples
#   V-Sorting samples time: 00:01:38
#   Allocating rank array
#   Ranking v-sort output
#   Ranking v-sort output time: 00:00:29
#   Invoking Larsson-Sadakane on ranks
#   Invoking Larsson-Sadakane on ranks time: 00:00:39
#   Sanity-checking and returning
# Building samples
# Reserving space for 12 sample suffixes
# Generating random suffixes
# QSorting 12 sample offsets, eliminating duplicates
# QSorting sample offsets, eliminating duplicates time: 00:00:00
# Multikey QSorting 12 samples
#   (Using difference cover)
#   Multikey QSorting samples time: 00:00:00
# Calculating bucket sizes
# Splitting and merging
#   Splitting and merging time: 00:00:00
# Avg bucket size: 4.19665e+08 (target: 550810439)
# Converting suffix-array elements to index image
# Allocating ftab, absorbFtab
# Entering Ebwt loop
# Getting block 1 of 7
#   Reserving size (550810440) for bucket 1
#   Calculating Z arrays for bucket 1
#   Entering block accumulator loop for bucket 1:
#   bucket 1: 10%
#   bucket 1: 20%
#   bucket 1: 30%
#   bucket 1: 40%
#   bucket 1: 50%
#   bucket 1: 60%
#   bucket 1: 70%
#   bucket 1: 80%
#   bucket 1: 90%
#   bucket 1: 100%
#   Sorting block of length 519023662 for bucket 1
#   (Using difference cover)
#   Sorting block time: 00:06:16
# Returning block of 469629839 for bucket 2
# Getting block 3 of 8
#   Reserving size (550810440) for bucket 3
#   Calculating Z arrays for bucket 3
#   Entering block accumulator loop for bucket 3:
#   bucket 3: 10%
#   bucket 3: 20%
#   bucket 3: 30%
#   bucket 3: 40%
#   bucket 3: 50%
#   bucket 3: 60%
#   bucket 3: 70%
#   bucket 3: 80%
#   bucket 3: 90%
#   bucket 3: 100%
#   Sorting block of length 433807892 for bucket 3
#   (Using difference cover)
#   Sorting block time: 00:07:34
# Returning block of 519023663 for bucket 1
#   Sorting block time: 00:05:11
# Returning block of 433807893 for bucket 3
# Getting block 2 of 7
#   Reserving size (550810440) for bucket 2
#   Calculating Z arrays for bucket 2
#   Entering block accumulator loop for bucket 2:
#   bucket 2: 10%
#   bucket 2: 20%
#   bucket 2: 30%
#   bucket 2: 40%
#   bucket 2: 50%
#   bucket 2: 60%
#   bucket 2: 70%
#   bucket 2: 80%
#   bucket 2: 90%
#   bucket 2: 100%
#   Sorting block of length 461139791 for bucket 2
#   (Using difference cover)
# Getting block 4 of 8
#   Reserving size (550810440) for bucket 4
#   Calculating Z arrays for bucket 4
#   Entering block accumulator loop for bucket 4:
#   bucket 4: 10%
#   bucket 4: 20%
#   bucket 4: 30%
#   bucket 4: 40%
#   bucket 4: 50%
#   bucket 4: 60%
#   bucket 4: 70%
#   bucket 4: 80%
#   bucket 4: 90%
#   bucket 4: 100%
#   Sorting block of length 157321038 for bucket 4
#   (Using difference cover)
#   Sorting block time: 00:01:46
# Returning block of 157321039 for bucket 4
# Getting block 5 of 8
#   Reserving size (550810440) for bucket 5
#   Calculating Z arrays for bucket 5
#   Entering block accumulator loop for bucket 5:
#   bucket 5: 10%
#   bucket 5: 20%
#   bucket 5: 30%
#   bucket 5: 40%
#   bucket 5: 50%
#   bucket 5: 60%
#   bucket 5: 70%
#   bucket 5: 80%
#   bucket 5: 90%
#   bucket 5: 100%
#   Sorting block of length 435850394 for bucket 5
#   (Using difference cover)
#   Sorting block time: 00:09:19
# Returning block of 461139792 for bucket 2
#   Sorting block time: 00:07:26
# Returning block of 435850395 for bucket 5
# Getting block 3 of 7
#   Reserving size (550810440) for bucket 3
#   Calculating Z arrays for bucket 3
#   Entering block accumulator loop for bucket 3:
#   bucket 3: 10%
#   bucket 3: 20%
#   bucket 3: 30%
#   bucket 3: 40%
#   bucket 3: 50%
#   bucket 3: 60%
#   bucket 3: 70%
#   bucket 3: 80%
#   bucket 3: 90%
#   bucket 3: 100%
#   Sorting block of length 409562682 for bucket 3
#   (Using difference cover)
# Getting block 6 of 8
#   Reserving size (550810440) for bucket 6
#   Calculating Z arrays for bucket 6
#   Entering block accumulator loop for bucket 6:
#   bucket 6: 10%
#   bucket 6: 20%
#   bucket 6: 30%
#   bucket 6: 40%
#   bucket 6: 50%
#   bucket 6: 60%
#   bucket 6: 70%
#   bucket 6: 80%
#   bucket 6: 90%
#   bucket 6: 100%
#   Sorting block of length 374208978 for bucket 6
#   (Using difference cover)

# %%
# !bismark_genome_preparation --verbose --hisat2 ~/genomes/hg38/chromosomes/
# Out:
# Path to genome folder specified as: /data_gilbert/home/aarab/genomes/hg38/chromosomes/
# Aligner to be used: >> HISAT2 <<
# Writing bisulfite genomes out into a single MFA (multi FastA) file
#
# Bismark Genome Preparation - Step I: Preparing folders
#
# Bisulfite Genome Indexer version v0.23.1 (last modified: 27 Jan 2021)
#
# A directory called /data_gilbert/home/aarab/genomes/hg38/chromosomes/Bisulfite_Genome/ already exists. Already existing converted sequences and/or already existing Bowtie 2 or HISAT2) indices will be overwritten!
#
#
# Step I - Prepare genome folders - completed
#
#
# Bismark Genome Preparation - Step II: Bisulfite converting reference genome
#
# conversions performed:
# chromosome	C->T	G->A
# chr1	48055043	48111528
# chr10	27639505	27719976
# chr11	27903257	27981801
# chr12	27092804	27182678
# chr13	18839192	18933605
# chr14	18423758	18559033
# chr15	17752941	17825903
# chr16	18172742	18299976
# chr17	18723944	18851500
# chr18	15794455	16061651
# chr19	13954580	14061132
# chr2	48318180	48450903
# chr20	13916133	14094472
# chr21	8185244	8226381
# chr22	9160652	9246186
# chr3	39233483	39344259
# chr4	36236976	36331025
# chr5	35731600	35879674
# chr6	33646690	33713330
# chr7	32317984	32378859
# chr8	29030173	29103787
# chr9	25099811	25170662
# chrM	5181	2169
# chrX	30523780	30697741
# chrY	5285789	5286894
#
# Total number of conversions performed:
# C->T:	599043897
# G->A:	601515125
#
# Step II - Genome bisulfite conversions - completed
#
#
# Bismark Genome Preparation - Step III: Launching the HISAT2 indexer
# Please be aware that this process can - depending on genome size - take several hours!
#
# Preparing indexing of CT converted genome in /data_gilbert/home/aarab/genomes/hg38/chromosomes/Bisulfite_Genome/CT_conversion/
# Parent process: Starting to index C->T converted genome with the following command:
#
# hisat2-build  -f genome_mfa.CT_conversion.fa BS_CT
#
# Settings:
#   Output files: "BS_CT.*.ht2"
#   Line rate: 6 (line is 64 bytes)
#   Lines per side: 1 (side is 64 bytes)
#   Offset rate: 4 (one in 16)
#   FTable chars: 10
#   Strings: unpacked
#   Local offset rate: 3 (one in 8)
#   Local fTable chars: 6
#   Local sequence length: 57344
#   Local sequence overlap between two consecutive indexes: 1024
#   Endianness: little
#   Actual local endianness: little
#   Sanity checking: disabled
#   Assertions: disabled
#   Random seed: 0
#   Sizeofs: void*:8, int:4, long:8, size_t:8
# Input files DNA, FASTA:
#   genome_mfa.CT_conversion.fa
# Reading reference sizes
# Preparing indexing of GA converted genome in /data_gilbert/home/aarab/genomes/hg38/chromosomes/Bisulfite_Genome/GA_conversion/
# Child process: Starting to index G->A converted genome with the following command:
#
# hisat2-build  -f genome_mfa.GA_conversion.fa BS_GA
#
# Settings:
#   Output files: "BS_GA.*.ht2"
#   Line rate: 6 (line is 64 bytes)
#   Lines per side: 1 (side is 64 bytes)
#   Offset rate: 4 (one in 16)
#   FTable chars: 10
#   Strings: unpacked
#   Local offset rate: 3 (one in 8)
#   Local fTable chars: 6
#   Local sequence length: 57344
#   Local sequence overlap between two consecutive indexes: 1024
#   Endianness: little
#   Actual local endianness: little
#   Sanity checking: disabled
#   Assertions: disabled
#   Random seed: 0
#   Sizeofs: void*:8, int:4, long:8, size_t:8
# Input files DNA, FASTA:
#   genome_mfa.GA_conversion.fa
# Reading reference sizes
#   Time reading reference sizes: 00:00:16
# Calculating joined length
# Writing header
# Reserving space for joined string
# Joining reference sequences
#   Time reading reference sizes: 00:00:18
# Calculating joined length
# Writing header
# Reserving space for joined string
# Joining reference sequences
#   Time to join reference sequences: 00:00:13
#   Time to read SNPs and splice sites: 00:00:00
# Using parameters --bmax 550810440 --dcv 1024
#   Doing ahead-of-time memory usage test
#   Passed!  Constructing with these parameters: --bmax 550810440 --dcv 1024
# Constructing suffix-array element generator
# Building DifferenceCoverSample
#   Building sPrime
#   Time to join reference sequences: 00:00:13
#   Time to read SNPs and splice sites: 00:00:00
# Using parameters --bmax 550810440 --dcv 1024
#   Doing ahead-of-time memory usage test
#   Building sPrimeOrder
#   V-Sorting samples
#   Passed!  Constructing with these parameters: --bmax 550810440 --dcv 1024
# Constructing suffix-array element generator
# Building DifferenceCoverSample
#   Building sPrime
#   Building sPrimeOrder
#   V-Sorting samples
#   V-Sorting samples time: 00:01:19
#   Allocating rank array
#   Ranking v-sort output
#   V-Sorting samples time: 00:01:18
#   Allocating rank array
#   Ranking v-sort output
#   Ranking v-sort output time: 00:00:21
#   Invoking Larsson-Sadakane on ranks
#   Ranking v-sort output time: 00:00:21
#   Invoking Larsson-Sadakane on ranks
#   Invoking Larsson-Sadakane on ranks time: 00:00:37
#   Sanity-checking and returning
# Building samples
# Reserving space for 12 sample suffixes
# Generating random suffixes
# QSorting 12 sample offsets, eliminating duplicates
# QSorting sample offsets, eliminating duplicates time: 00:00:00
# Multikey QSorting 12 samples
#   (Using difference cover)
#   Multikey QSorting samples time: 00:00:00
# Calculating bucket sizes
#   Invoking Larsson-Sadakane on ranks time: 00:00:36
#   Sanity-checking and returning
# Building samples
# Reserving space for 12 sample suffixes
# Generating random suffixes
# QSorting 12 sample offsets, eliminating duplicates
# QSorting sample offsets, eliminating duplicates time: 00:00:00
# Multikey QSorting 12 samples
#   (Using difference cover)
#   Multikey QSorting samples time: 00:00:00
# Calculating bucket sizes
# Splitting and merging
#   Splitting and merging time: 00:00:00
# Avg bucket size: 4.19665e+08 (target: 550810439)
# Converting suffix-array elements to index image
# Allocating ftab, absorbFtab
# Entering GFM loop
# Getting block 1 of 7
#   Reserving size (550810440) for bucket 1
#   Calculating Z arrays for bucket 1
#   Entering block accumulator loop for bucket 1:
# Splitting and merging
#   Splitting and merging time: 00:00:00
# Avg bucket size: 3.67207e+08 (target: 550810439)
# Converting suffix-array elements to index image
# Allocating ftab, absorbFtab
# Entering GFM loop
# Getting block 1 of 8
#   Reserving size (550810440) for bucket 1
#   Calculating Z arrays for bucket 1
#   Entering block accumulator loop for bucket 1:
#   bucket 1: 10%
#   bucket 1: 10%
#   bucket 1: 20%
#   bucket 1: 20%
#   bucket 1: 30%
#   bucket 1: 30%
#   bucket 1: 40%
#   bucket 1: 40%
#   bucket 1: 50%
#   bucket 1: 50%
#   bucket 1: 60%
#   bucket 1: 60%
#   bucket 1: 70%
#   bucket 1: 70%
#   bucket 1: 80%
#   bucket 1: 80%
#   bucket 1: 90%
#   bucket 1: 90%
#   bucket 1: 100%
#   Sorting block of length 506437153 for bucket 1
#   (Using difference cover)
#   bucket 1: 100%
#   Sorting block of length 265840023 for bucket 1
#   (Using difference cover)
#   Sorting block time: 00:02:54
# Returning block of 265840024 for bucket 1
# Getting block 2 of 8
#   Reserving size (550810440) for bucket 2
#   Calculating Z arrays for bucket 2
#   Entering block accumulator loop for bucket 2:
#   bucket 2: 10%
#   bucket 2: 20%
#   bucket 2: 30%
#   bucket 2: 40%
#   bucket 2: 50%
#   bucket 2: 60%
#   bucket 2: 70%
#   bucket 2: 80%
#   bucket 2: 90%
#   bucket 2: 100%
#   Sorting block of length 313712311 for bucket 2
#   (Using difference cover)
#   Sorting block time: 00:07:12
# Returning block of 506437154 for bucket 1
#   Sorting block time: 00:03:38
# Returning block of 313712312 for bucket 2
# Getting block 2 of 7
#   Reserving size (550810440) for bucket 2
#   Calculating Z arrays for bucket 2
#   Entering block accumulator loop for bucket 2:
#   bucket 2: 10%
# Getting block 3 of 8
#   Reserving size (550810440) for bucket 3
#   Calculating Z arrays for bucket 3
#   Entering block accumulator loop for bucket 3:
#   bucket 2: 20%
#   bucket 3: 10%
#   bucket 2: 30%
#   bucket 3: 20%
#   bucket 2: 40%
#   bucket 3: 30%
#   bucket 2: 50%
#   bucket 3: 40%
#   bucket 2: 60%
#   bucket 3: 50%
#   bucket 3: 60%
#   bucket 2: 70%
#   bucket 3: 70%
#   bucket 2: 80%
#   bucket 3: 80%
#   bucket 2: 90%
#   bucket 3: 90%
#   bucket 2: 100%
#   Sorting block of length 447885829 for bucket 2
#   (Using difference cover)
#   bucket 3: 100%
#   Sorting block of length 269510198 for bucket 3
#   (Using difference cover)
#   Sorting block time: 00:03:07
# Returning block of 269510199 for bucket 3
# Getting block 4 of 8
#   Reserving size (550810440) for bucket 4
#   Calculating Z arrays for bucket 4
#   Entering block accumulator loop for bucket 4:
#   bucket 4: 10%
#   bucket 4: 20%
#   bucket 4: 30%
#   bucket 4: 40%
#   bucket 4: 50%
#   bucket 4: 60%
#   bucket 4: 70%
#   bucket 4: 80%
#   bucket 4: 90%
#   bucket 4: 100%
#   Sorting block of length 416425897 for bucket 4
#   (Using difference cover)
#   Sorting block time: 00:06:28
# Returning block of 447885830 for bucket 2
# Getting block 3 of 7
#   Reserving size (550810440) for bucket 3
#   Calculating Z arrays for bucket 3
#   Entering block accumulator loop for bucket 3:
#   bucket 3: 10%
#   bucket 3: 20%
#   bucket 3: 30%
#   bucket 3: 40%
#   bucket 3: 50%
#   bucket 3: 60%
#   bucket 3: 70%
#   bucket 3: 80%
#   bucket 3: 90%
#   bucket 3: 100%
#   Sorting block of length 539608788 for bucket 3
#   (Using difference cover)
#   Sorting block time: 00:04:54
# Returning block of 416425898 for bucket 4
# Getting block 5 of 8
#   Reserving size (550810440) for bucket 5
#   Calculating Z arrays for bucket 5
#   Entering block accumulator loop for bucket 5:
#   bucket 5: 10%
#   bucket 5: 20%
#   bucket 5: 30%
#   bucket 5: 40%
#   bucket 5: 50%
#   bucket 5: 60%
#   bucket 5: 70%
#   bucket 5: 80%
#   bucket 5: 90%
#   bucket 5: 100%
#   Sorting block of length 480655197 for bucket 5
#   (Using difference cover)
#   Sorting block time: 00:08:17
# Returning block of 539608789 for bucket 3
#   Sorting block time: 00:05:46
# Returning block of 480655198 for bucket 5
# Getting block 4 of 7
#   Reserving size (550810440) for bucket 4
#   Calculating Z arrays for bucket 4
#   Entering block accumulator loop for bucket 4:
#   bucket 4: 10%
#   bucket 4: 20%
# Getting block 6 of 8
#   Reserving size (550810440) for bucket 6
#   Calculating Z arrays for bucket 6
#   Entering block accumulator loop for bucket 6:
#   bucket 4: 30%
#   bucket 6: 10%
#   bucket 4: 40%
#   bucket 6: 20%
#   bucket 4: 50%
#   bucket 6: 30%
#   bucket 4: 60%
#   bucket 6: 40%
#   bucket 4: 70%
#   bucket 6: 50%
#   bucket 4: 80%
#   bucket 6: 60%
#   bucket 4: 90%
#   bucket 6: 70%
#   bucket 4: 100%
#   Sorting block of length 384792641 for bucket 4
#   (Using difference cover)
#   bucket 6: 80%
#   bucket 6: 90%
#   bucket 6: 100%
#   Sorting block of length 367604136 for bucket 6
#   (Using difference cover)
#   Sorting block time: 00:04:21
# Returning block of 367604137 for bucket 6
# Getting block 7 of 8
#   Reserving size (550810440) for bucket 7
#   Calculating Z arrays for bucket 7
#   Entering block accumulator loop for bucket 7:
#   bucket 7: 10%
#   Sorting block time: 00:05:36
# Returning block of 384792642 for bucket 4
#   bucket 7: 20%
#   bucket 7: 30%
#   bucket 7: 40%
#   bucket 7: 50%
#   bucket 7: 60%
#   bucket 7: 70%
#   bucket 7: 80%
#   bucket 7: 90%
#   bucket 7: 100%
#   Sorting block of length 547961096 for bucket 7
#   (Using difference cover)
# Getting block 5 of 7
#   Reserving size (550810440) for bucket 5
#   Calculating Z arrays for bucket 5
#   Entering block accumulator loop for bucket 5:
#   bucket 5: 10%
#   bucket 5: 20%
#   bucket 5: 30%
#   bucket 5: 40%
#   bucket 5: 50%
#   bucket 5: 60%
#   bucket 5: 70%
#   bucket 5: 80%
#   bucket 5: 90%
#   bucket 5: 100%
#   Sorting block of length 459841719 for bucket 5
#   (Using difference cover)
#   Sorting block time: 00:06:31
# Returning block of 547961097 for bucket 7
# Getting block 8 of 8
#   Reserving size (550810440) for bucket 8
#   Calculating Z arrays for bucket 8
#   Entering block accumulator loop for bucket 8:
#   bucket 8: 10%
#   bucket 8: 20%
#   Sorting block time: 00:06:57
# Returning block of 459841720 for bucket 5
#   bucket 8: 30%
#   bucket 8: 40%
#   bucket 8: 50%
#   bucket 8: 60%
#   bucket 8: 70%
#   bucket 8: 80%
#   bucket 8: 90%
#   bucket 8: 100%
#   Sorting block of length 275946816 for bucket 8
#   (Using difference cover)
# Getting block 6 of 7
#   Reserving size (550810440) for bucket 6
#   Calculating Z arrays for bucket 6
#   Entering block accumulator loop for bucket 6:
#   bucket 6: 10%
#   bucket 6: 20%
#   bucket 6: 30%
#   bucket 6: 40%
#   bucket 6: 50%
#   bucket 6: 60%
#   bucket 6: 70%
#   bucket 6: 80%
#   bucket 6: 90%
#   bucket 6: 100%
#   Sorting block of length 328692208 for bucket 6
#   (Using difference cover)
#   Sorting block time: 00:03:16
# Returning block of 275946817 for bucket 8
# Exited GFM loop
# fchr[A]: 0
# fchr[C]: 1468669118
# fchr[G]: 2067713015
# fchr[T]: 2067713015
# fchr[$]: 2937655681
# Exiting GFM::buildToDisk()
# Returning from initFromVector
# Wrote 983425404 bytes to primary GFM file: BS_GA.1.ht2
# Wrote 734413928 bytes to secondary GFM file: BS_GA.2.ht2
# Re-opening _in1 and _in2 as input streams
# Returning from GFM constructor
#   Sorting block time: 00:04:58
# Returning block of 328692209 for bucket 6
# Getting block 7 of 7
#   Reserving size (550810440) for bucket 7
#   Calculating Z arrays for bucket 7
#   Entering block accumulator loop for bucket 7:
#   bucket 7: 10%
#   bucket 7: 20%
#   bucket 7: 30%
#   bucket 7: 40%
#   bucket 7: 50%
#   bucket 7: 60%
#   bucket 7: 70%
#   bucket 7: 80%
#   bucket 7: 90%
#   bucket 7: 100%
#   Sorting block of length 270397337 for bucket 7
#   (Using difference cover)
# Returning from initFromVector
# Wrote 1290699801 bytes to primary GFM file: BS_GA.5.ht2
# Wrote 747869486 bytes to secondary GFM file: BS_GA.6.ht2
# Re-opening _in5 and _in5 as input streams
# Returning from HGFM constructor
# Headers:
#     len: 2937655681
#     gbwtLen: 2937655682
#     nodes: 2937655682
#     sz: 734413921
#     gbwtSz: 734413921
#     lineRate: 6
#     offRate: 4
#     offMask: 0xfffffff0
#     ftabChars: 10
#     eftabLen: 0
#     eftabSz: 0
#     ftabLen: 1048577
#     ftabSz: 4194308
#     offsLen: 183603481
#     offsSz: 734413924
#     lineSz: 64
#     sideSz: 64
#     sideGbwtSz: 48
#     sideGbwtLen: 192
#     numSides: 15300291
#     numLines: 15300291
#     gbwtTotLen: 979218624
#     gbwtTotSz: 979218624
#     reverse: 0
#     linearFM: Yes
# Total time for call to driver() for forward index: 00:58:15
#   Sorting block time: 00:04:26
# Returning block of 270397338 for bucket 7
# Exited GFM loop
# fchr[A]: 0
# fchr[C]: 867153993
# fchr[G]: 867153993
# fchr[T]: 1468669118
# fchr[$]: 2937655681
# Exiting GFM::buildToDisk()
# Returning from initFromVector
# Wrote 983425404 bytes to primary GFM file: BS_CT.1.ht2
# Wrote 734413928 bytes to secondary GFM file: BS_CT.2.ht2
# Re-opening _in1 and _in2 as input streams
# Returning from GFM constructor
# Returning from initFromVector
# Wrote 1290699801 bytes to primary GFM file: BS_CT.5.ht2
# Wrote 747869486 bytes to secondary GFM file: BS_CT.6.ht2
# Re-opening _in5 and _in5 as input streams
# Returning from HGFM constructor
# Headers:
#     len: 2937655681
#     gbwtLen: 2937655682
#     nodes: 2937655682
#     sz: 734413921
#     gbwtSz: 734413921
#     lineRate: 6
#     offRate: 4
#     offMask: 0xfffffff0
#     ftabChars: 10
#     eftabLen: 0
#     eftabSz: 0
#     ftabLen: 1048577
#     ftabSz: 4194308
#     offsLen: 183603481
#     offsSz: 734413924
#     lineSz: 64
#     sideSz: 64
#     sideGbwtSz: 48
#     sideGbwtLen: 192
#     numSides: 15300291
#     numLines: 15300291
#     gbwtTotLen: 979218624
#     gbwtTotSz: 979218624
#     reverse: 0
#     linearFM: Yes
# Total time for call to driver() for forward index: 01:07:19

# %% [markdown]
# ### Analyze samples

# %% [markdown]
# __(II) Running bismark__

# %%
# %%bash
# genDIR="/data_gilbert/home/aarab/genomes/hg38/chromosomes/"
#
# cd fastq
# for fq1 in *_val_1.fq.gz; do
#     fq2=${fq1/_1_val_1.fq/_2_val_2.fq}
#     b=`basename $fq1`
#     sample=${b/_1_val_1.fq.gz/}
#     cm="bismark --gzip --genome $genDIR -1 $fq1 -2 $fq2"
#     # --score_min L,0,-0.4
#     echo $cm
#     $cm &> ${sample}.log;
#     wait
# done
# cd ../
# Out:
# bismark --gzip --genome /data_gilbert/home/aarab/genomes/hg38/chromosomes/ -1 SRR11711272_1_val_1.fq.gz -2 SRR11711272_2_val_2.fq.gz

# %% [markdown]
# __(III) Running deduplicate_bismark__
# > should not be used for reduced representation libraries such as RRBS, amplicon or target enrichment libraries.

# %%
# %%bash 
# for bam in bam/*.bam; do 
#     deduplicate_bismark --bam $bam
# done

# %% [markdown]
# __(IV) Running bismark_methylation_extractor__
# extract context-dependent (CpG/CHG/CHH) methylation
#
# This will produce three methytlation output files:
#
#     CpG_context_test_dataset_bismark_bt2.txt.gz
#     CHG_context_test_dataset_bismark_bt2.txt.gz
#     CHH_context_test_dataset_bismark_bt2.txt.gz
# as well as a bedGraph and a Bismark coverage file. For more on these files and their formats please see below.

# %%
# %%bash
# cd bam/
# for bam in *.bam; do
#     bismark_methylation_extractor --multicore 30 --gzip --bedGraph $bam
# done
# cd ../
# Out:
#  *** Bismark methylation extractor version v0.23.1 ***
#
# Trying to determine the type of mapping from the SAM header line of file SRR11711272_1_val_1_bismark_bt2_pe.bam
# Treating file(s) as paired-end data (as extracted from @PG line)
#
# Setting option '--no_overlap' since this is (normally) the right thing to do for paired-end data
#
# Core usage currently set to more than 20 threads. Let's see how this goes... (set value: 30)
#
# Summarising Bismark methylation extractor parameters:
# ===============================================================
# Bismark paired-end SAM format specified (default)
# Number of cores to be used: 30
# Output will be written to the current directory ('/data_gilbert/home/aarab/Projects/Decitabine-treatment/Bisulfite-seq/bam')
#
#
# Summarising bedGraph parameters:
# ===============================================================
# Generating additional output in bedGraph and coverage format
# bedGraph format:	<Chromosome> <Start Position> <End Position> <Methylation Percentage>
# coverage format:	<Chromosome> <Start Position> <End Position> <Methylation Percentage> <count methylated> <count non-methylated>
#
# Using a cutoff of 1 read(s) to report cytosine positions
# Reporting and sorting cytosine methylation information in CpG context only (default)
# The bedGraph UNIX sort command will use the following memory setting:	'2G'. Temporary directory used for sorting is the output directory
#
# Checking file >>SRR11711272_1_val_1_bismark_bt2_pe.bam<< for signs of file truncation...
# ...passed!
# Writing result file containing methylation information for C in CpG context from the original top strand to CpG_OT_SRR11711272_1_val_1_bismark_bt2_pe.txt.gz
# Writing result file containing methylation information for C in CpG context from the complementary to original top strand to CpG_CTOT_SRR11711272_1_val_1_bismark_bt2_pe.txt.gz
# Writing result file containing methylation information for C in CpG context from the complementary to original bottom strand to CpG_CTOB_SRR11711272_1_val_1_bismark_bt2_pe.txt.gz
# Writing result file containing methylation information for C in CpG context from the original bottom strand to CpG_OB_SRR11711272_1_val_1_bismark_bt2_pe.txt.gz
#
# Writing result file containing methylation information for C in CHG context from the original top strand to CHG_OT_SRR11711272_1_val_1_bismark_bt2_pe.txt.gz
# Writing result file containing methylation information for C in CHG context from the complementary to original top strand to CHG_CTOT_SRR11711272_1_val_1_bismark_bt2_pe.txt.gz
# Writing result file containing methylation information for C in CHG context from the complementary to original bottom strand to CHG_CTOB_SRR11711272_1_val_1_bismark_bt2_pe.txt.gz
# Writing result file containing methylation information for C in CHG context from the original bottom strand to CHG_OB_SRR11711272_1_val_1_bismark_bt2_pe.txt.gz
#
# Writing result file containing methylation information for C in CHH context from the original top strand to CHH_OT_SRR11711272_1_val_1_bismark_bt2_pe.txt.gz
# Writing result file containing methylation information for C in CHH context from the complementary to original top strand to CHH_CTOT_SRR11711272_1_val_1_bismark_bt2_pe.txt.gz
# Writing result file containing methylation information for C in CHH context from the complementary to original bottom strand to CHH_CTOB_SRR11711272_1_val_1_bismark_bt2_pe.txt.gz
# Writing result file containing methylation information for C in CHH context from the original bottom strand to CHH_OB_SRR11711272_1_val_1_bismark_bt2_pe.txt.gz
#
#
# Now reading in Bismark result file SRR11711272_1_val_1_bismark_bt2_pe.bam
#
#
# Now reading in Bismark result file SRR11711272_1_val_1_bismark_bt2_pe.bam
#
#
# Now reading in Bismark result file SRR11711272_1_val_1_bismark_bt2_pe.bam
#
#
# Now reading in Bismark result file SRR11711272_1_val_1_bismark_bt2_pe.bam
#
#
# Now reading in Bismark result file SRR11711272_1_val_1_bismark_bt2_pe.bam
#
#
# Now reading in Bismark result file SRR11711272_1_val_1_bismark_bt2_pe.bam
#
#
# Now reading in Bismark result file SRR11711272_1_val_1_bismark_bt2_pe.bam
#
#
# Now reading in Bismark result file SRR11711272_1_val_1_bismark_bt2_pe.bam
#
#
# Now reading in Bismark result file SRR11711272_1_val_1_bismark_bt2_pe.bam
#
#
# Now reading in Bismark result file SRR11711272_1_val_1_bismark_bt2_pe.bam
#
#
# Now reading in Bismark result file SRR11711272_1_val_1_bismark_bt2_pe.bam
#
#
# Now reading in Bismark result file SRR11711272_1_val_1_bismark_bt2_pe.bam
#
#
# Now reading in Bismark result file SRR11711272_1_val_1_bismark_bt2_pe.bam
#
#
# Now reading in Bismark result file SRR11711272_1_val_1_bismark_bt2_pe.bam
#
#
# Now reading in Bismark result file SRR11711272_1_val_1_bismark_bt2_pe.bam
#
#
# Now reading in Bismark result file SRR11711272_1_val_1_bismark_bt2_pe.bam
#
#
# Now reading in Bismark result file SRR11711272_1_val_1_bismark_bt2_pe.bam
#
#
# Now reading in Bismark result file SRR11711272_1_val_1_bismark_bt2_pe.bam
#
#
# Now reading in Bismark result file SRR11711272_1_val_1_bismark_bt2_pe.bam
#
#
# Now reading in Bismark result file SRR11711272_1_val_1_bismark_bt2_pe.bam
#
#
# Now reading in Bismark result file SRR11711272_1_val_1_bismark_bt2_pe.bam
#
#
# Now reading in Bismark result file SRR11711272_1_val_1_bismark_bt2_pe.bam
#
#
# Now reading in Bismark result file SRR11711272_1_val_1_bismark_bt2_pe.bam
#
#
# Now reading in Bismark result file SRR11711272_1_val_1_bismark_bt2_pe.bam
#
#
# Now reading in Bismark result file SRR11711272_1_val_1_bismark_bt2_pe.bam
#
#
# Now reading in Bismark result file SRR11711272_1_val_1_bismark_bt2_pe.bam
#
#
# Now reading in Bismark result file SRR11711272_1_val_1_bismark_bt2_pe.bam
#
#
# Now reading in Bismark result file SRR11711272_1_val_1_bismark_bt2_pe.bam
#
# Now reading in Bismark result file SRR11711272_1_val_1_bismark_bt2_pe.bam
#
# Now reading in Bismark result file SRR11711272_1_val_1_bismark_bt2_pe.bam
#
# skipping SAM header line:	@HD	VN:1.0	SO:unsorted
# skipping SAM header line:	@SQ	SN:chr1	LN:248956422
# skipping SAM header line:	@SQ	SN:chr10	LN:133797422
# skipping SAM header line:	@SQ	SN:chr11	LN:135086622
# skipping SAM header line:	@SQ	SN:chr12	LN:133275309
# skipping SAM header line:	@SQ	SN:chr13	LN:114364328
# skipping SAM header line:	@SQ	SN:chr14	LN:107043718
# skipping SAM header line:	@SQ	SN:chr15	LN:101991189
# skipping SAM header line:	@SQ	SN:chr16	LN:90338345
# skipping SAM header line:	@SQ	SN:chr17	LN:83257441
# skipping SAM header line:	@SQ	SN:chr18	LN:80373285
# skipping SAM header line:	@SQ	SN:chr19	LN:58617616
# skipping SAM header line:	@SQ	SN:chr2	LN:242193529
# skipping SAM header line:	@SQ	SN:chr20	LN:64444167
# skipping SAM header line:	@SQ	SN:chr21	LN:46709983
# skipping SAM header line:	@SQ	SN:chr22	LN:50818468
# skipping SAM header line:	@SQ	SN:chr3	LN:198295559
# skipping SAM header line:	@SQ	SN:chr4	LN:190214555
# skipping SAM header line:	@SQ	SN:chr5	LN:181538259
# skipping SAM header line:	@SQ	SN:chr6	LN:170805979
# skipping SAM header line:	@SQ	SN:chr7	LN:159345973
# skipping SAM header line:	@SQ	SN:chr8	LN:145138636
# skipping SAM header line:	@SQ	SN:chr9	LN:138394717
# skipping SAM header line:	@SQ	SN:chrM	LN:16569
# skipping SAM header line:	@SQ	SN:chrX	LN:156040895
# skipping SAM header line:	@SQ	SN:chrY	LN:57227415
# skipping SAM header line:	@PG	ID:Bismark	VN:v0.23.1	CL:"bismark --gzip --genome /data_gilbert/home/aarab/genomes/hg38/chromosomes/ -1 SRR11711272_1_val_1.fq.gz -2 SRR11711272_2_val_2.fq.gz"
# skipping SAM header line:	@PG	ID:samtools	PN:samtools	PP:Bismark	VN:1.15	CL:/data_gilbert/home/aarab/anaconda3/envs/DNAme/bin/samtools view -bSh -
# skipping SAM header line:	@PG	ID:samtools.1	PN:samtools	PP:samtools	VN:1.15	CL:/data_gilbert/home/aarab/anaconda3/envs/DNAme/bin/samtools view -h SRR11711272_1_val_1_bismark_bt2_pe.bam
# Processed lines: 500000
# Processed lines: 500000
# Processed lines: 500000
# Processed lines: 500000
# Processed lines: 500000
# Processed lines: 500000
# Processed lines: 500000
# Processed lines: 500000
# Processed lines: 500000
# Processed lines: 500000
# Processed lines: 500000
# Processed lines: 500000
# Processed lines: 500000
# Processed lines: 500000
# Processed lines: 500000
# Processed lines: 500000
# Processed lines: 500000
# Processed lines: 500000
# Processed lines: 500000
# Processed lines: 500000
# Processed lines: 500000
# Processed lines: 500000
# Processed lines: 500000
# Processed lines: 500000
# Processed lines: 500000
# Processed lines: 500000
# Processed lines: 500000
# Processed lines: 500000
# Processed lines: 500000
# Processed lines: 500000
# Processed lines: 1000000
# Processed lines: 1000000
# Processed lines: 1000000
# Processed lines: 1000000
# Processed lines: 1000000
# Processed lines: 1000000
# Processed lines: 1000000
# Processed lines: 1000000
# Processed lines: 1000000
# Processed lines: 1000000
# Processed lines: 1000000
# Processed lines: 1000000
# Processed lines: 1000000
# Processed lines: 1000000
# Processed lines: 1000000
# Processed lines: 1000000
# Processed lines: 1000000
# Processed lines: 1000000
# Processed lines: 1000000
# Processed lines: 1000000
# Processed lines: 1000000
# Processed lines: 1000000
# Processed lines: 1000000
# Processed lines: 1000000
# Processed lines: 1000000
# Processed lines: 1000000
# Processed lines: 1000000
# Processed lines: 1000000
# Processed lines: 1000000
# Processed lines: 1000000
# Processed lines: 1500000
# Processed lines: 1500000
# Processed lines: 1500000
# Processed lines: 1500000
# Processed lines: 1500000
# Processed lines: 1500000
# Processed lines: 1500000
# Processed lines: 1500000
# Processed lines: 1500000
# Processed lines: 1500000
# Processed lines: 1500000
# Processed lines: 1500000
# Processed lines: 1500000
# Processed lines: 1500000
# Processed lines: 1500000
# Processed lines: 1500000
# Processed lines: 1500000
# Processed lines: 1500000
# Processed lines: 1500000
# Processed lines: 1500000
# Processed lines: 1500000
# Processed lines: 1500000
# Processed lines: 1500000
# Processed lines: 1500000
# Processed lines: 1500000
# Processed lines: 1500000
# Processed lines: 1500000
# Processed lines: 1500000
# Processed lines: 1500000
# Processed lines: 1500000
# Processed lines: 2000000
# Processed lines: 2000000
# Processed lines: 2000000
# Processed lines: 2000000
# Processed lines: 2000000
# Processed lines: 2000000
# Processed lines: 2000000
# Processed lines: 2000000
# Processed lines: 2000000
# Processed lines: 2000000
# Processed lines: 2000000
# Processed lines: 2000000
# Processed lines: 2000000
# Processed lines: 2000000
# Processed lines: 2000000
# Processed lines: 2000000
# Processed lines: 2000000
# Processed lines: 2000000
# Processed lines: 2000000
# Processed lines: 2000000
# Processed lines: 2000000
# Processed lines: 2000000
# Processed lines: 2000000
# Processed lines: 2000000
# Processed lines: 2000000
# Processed lines: 2000000
# Processed lines: 2000000
# Processed lines: 2000000
# Processed lines: 2000000
# Processed lines: 2000000
# Processed lines: 2500000
# Processed lines: 2500000
# Processed lines: 2500000
# Processed lines: 2500000
# Processed lines: 2500000
# Processed lines: 2500000
# Processed lines: 2500000
# Processed lines: 2500000
# Processed lines: 2500000
# Processed lines: 2500000
# Processed lines: 2500000
# Processed lines: 2500000
# Processed lines: 2500000
# Processed lines: 2500000
# Processed lines: 2500000
# Processed lines: 2500000
# Processed lines: 2500000
# Processed lines: 2500000
# Processed lines: 2500000
# Processed lines: 2500000
# Processed lines: 2500000
# Processed lines: 2500000
# Processed lines: 2500000
# Processed lines: 2500000
# Processed lines: 2500000
# Processed lines: 2500000
# Processed lines: 2500000
# Processed lines: 2500000
# Processed lines: 3000000
# Processed lines: 3000000
# Processed lines: 3000000
# Processed lines: 3000000
# Processed lines: 3000000
# Processed lines: 3000000
# Processed lines: 3000000
# Processed lines: 3000000
# Processed lines: 3000000
# Processed lines: 3000000
# Processed lines: 3000000
# Processed lines: 2500000
# Processed lines: 2500000
# Processed lines: 3000000
# Processed lines: 3000000
# Processed lines: 3000000
# Processed lines: 3000000
# Processed lines: 3000000
# Processed lines: 3000000
# Processed lines: 3000000
# Processed lines: 3000000
# Processed lines: 3000000
# Processed lines: 3000000
# Processed lines: 3000000
# Processed lines: 3000000
# Processed lines: 3000000
# Processed lines: 3000000
# Processed lines: 3500000
# Processed lines: 3500000
# Processed lines: 3500000
# Processed lines: 3500000
# Processed lines: 3000000
# Processed lines: 3500000
# Processed lines: 3500000
# Processed lines: 3000000
# Processed lines: 3500000
# Processed lines: 3000000
# Processed lines: 3500000
# Processed lines: 3500000
# Processed lines: 3500000
# Processed lines: 3500000
# Processed lines: 3500000
# Processed lines: 3500000
# Processed lines: 3500000
# Processed lines: 3000000
# Processed lines: 3500000
# Processed lines: 3000000
# Processed lines: 3500000
# Processed lines: 3500000
# Processed lines: 3500000
# Processed lines: 3500000
# Processed lines: 3500000
# Processed lines: 3500000
# Processed lines: 3500000
# Processed lines: 3500000
# Processed lines: 4000000
# Processed lines: 4000000
# Processed lines: 4000000
# Processed lines: 4000000
# Processed lines: 3500000
# Processed lines: 4000000
# Processed lines: 3500000
# Processed lines: 4000000
# Processed lines: 4000000
# Processed lines: 3500000
# Processed lines: 3500000
# Processed lines: 4000000
# Processed lines: 4000000
# Processed lines: 4000000
# Processed lines: 4000000
# Processed lines: 3500000
# Processed lines: 4000000
# Processed lines: 4000000
# Processed lines: 4000000
# Processed lines: 4000000
# Processed lines: 3500000
# Processed lines: 3500000
# Processed lines: 4000000
# Processed lines: 4000000
# Processed lines: 4000000
# Processed lines: 4000000
# Processed lines: 4000000
# Processed lines: 4000000
# Processed lines: 4500000
# Processed lines: 4500000
# Processed lines: 4000000
# Processed lines: 4500000
# Processed lines: 4000000
# Processed lines: 4500000
# Processed lines: 4500000
# Processed lines: 4500000
# Processed lines: 4000000
# Processed lines: 4500000
# Processed lines: 4000000
# Processed lines: 4500000
# Processed lines: 4500000
# Processed lines: 4500000
# Processed lines: 4500000
# Processed lines: 4000000
# Processed lines: 4500000
# Processed lines: 4000000
# Processed lines: 4500000
# Processed lines: 4000000
# Processed lines: 4500000
# Processed lines: 4500000
# Processed lines: 4500000
# Processed lines: 4500000
# Processed lines: 4000000
# Processed lines: 4500000
# Processed lines: 4000000
# Processed lines: 4500000
# Processed lines: 4500000
# Processed lines: 4500000
# Processed lines: 5000000
# Processed lines: 5000000
# Processed lines: 5000000
# Processed lines: 5000000
# Processed lines: 5000000
# Processed lines: 4500000
# Processed lines: 4500000
# Processed lines: 5000000
# Processed lines: 5000000
# Processed lines: 5000000
# Processed lines: 4500000
# Processed lines: 5000000
# Processed lines: 5000000
# Processed lines: 5000000
# Processed lines: 4500000
# Processed lines: 5000000
# Processed lines: 5000000
# Processed lines: 5000000
# Processed lines: 4500000
# Processed lines: 4500000
# Processed lines: 4500000
# Processed lines: 5000000
# Processed lines: 5000000
# Processed lines: 5000000
# Processed lines: 5000000
# Processed lines: 5000000
# Processed lines: 5000000
# Processed lines: 5500000
# Processed lines: 5000000
# Processed lines: 5500000
# Processed lines: 4500000
# Processed lines: 4500000
# Processed lines: 5500000
# Processed lines: 5500000
# Processed lines: 5500000
# Processed lines: 5500000
# Processed lines: 5500000
# Processed lines: 5500000
# Processed lines: 5000000
# Processed lines: 5000000
# Processed lines: 5500000
# Processed lines: 5500000
# Processed lines: 5500000
# Processed lines: 5000000
# Processed lines: 5500000
# Processed lines: 5500000
# Processed lines: 5500000
# Processed lines: 5000000
# Processed lines: 5000000
# Processed lines: 5500000
# Processed lines: 5500000
# Processed lines: 5000000
# Processed lines: 5000000
# Processed lines: 6000000
# Processed lines: 6000000
# Processed lines: 5500000
# Processed lines: 5500000
# Processed lines: 5500000
# Processed lines: 5500000
# Processed lines: 5500000
# Processed lines: 6000000
# Processed lines: 6000000
# Processed lines: 6000000
# Processed lines: 6000000
# Processed lines: 6000000
# Processed lines: 5000000
# Processed lines: 6000000
# Processed lines: 5000000
# Processed lines: 6000000
# Processed lines: 6000000
# Processed lines: 6000000
# Processed lines: 5500000
# Processed lines: 5500000
# Processed lines: 6000000
# Processed lines: 6000000
# Processed lines: 5500000
# Processed lines: 6000000
# Processed lines: 5500000
# Processed lines: 6000000
# Processed lines: 6000000
# Processed lines: 6500000
# Processed lines: 6500000
# Processed lines: 5500000
# Processed lines: 5500000
# Processed lines: 6000000
# Processed lines: 5500000
# Processed lines: 6000000
# Processed lines: 6500000
# Processed lines: 6500000
# Processed lines: 6000000
# Processed lines: 6000000
# Processed lines: 6000000
# Processed lines: 6500000
# Processed lines: 6500000
# Processed lines: 6500000
# Processed lines: 6500000
# Processed lines: 6500000
# Processed lines: 6500000
# Processed lines: 6500000
# Processed lines: 5500000
# Processed lines: 6500000
# Processed lines: 5500000
# Processed lines: 6000000
# Processed lines: 6000000
# Processed lines: 6500000
# Processed lines: 6500000
# Processed lines: 6000000
# Processed lines: 6000000
# Processed lines: 7000000
# Processed lines: 7000000
# Processed lines: 6500000
# Processed lines: 6500000
# Processed lines: 7000000
# Processed lines: 7000000
# Processed lines: 6500000
# Processed lines: 7000000
# Processed lines: 6500000
# Processed lines: 6000000
# Processed lines: 7000000
# Processed lines: 7000000
# Processed lines: 6500000
# Processed lines: 6500000
# Processed lines: 6000000
# Processed lines: 6500000
# Processed lines: 6000000
# Processed lines: 7000000
# Processed lines: 7000000
# Processed lines: 7000000
# Processed lines: 7000000
# Processed lines: 7000000
# Processed lines: 7000000
# Processed lines: 6000000
# Processed lines: 7000000
# Processed lines: 6500000
# Processed lines: 6500000
# Processed lines: 6000000
# Processed lines: 7500000
# Processed lines: 7500000
# Processed lines: 6500000
# Processed lines: 7000000
# Processed lines: 6500000
# Processed lines: 7000000
# Processed lines: 7500000
# Processed lines: 7500000
# Processed lines: 7500000
# Processed lines: 7000000
# Processed lines: 7500000
# Processed lines: 7500000
# Processed lines: 7000000
# Processed lines: 7000000
# Processed lines: 7000000
# Processed lines: 6500000
# Processed lines: 7000000
# Processed lines: 7500000
# Processed lines: 6500000
# Processed lines: 6500000
# Processed lines: 7500000
# Processed lines: 7500000
# Processed lines: 7500000
# Processed lines: 7500000
# Processed lines: 7500000
# Processed lines: 7500000
# Processed lines: 7000000
# Processed lines: 7000000
# Processed lines: 6500000
# Processed lines: 8000000
# Processed lines: 6500000
# Processed lines: 8000000
# Processed lines: 7500000
# Processed lines: 7500000
# Processed lines: 8000000
# Processed lines: 7000000
# Processed lines: 8000000
# Processed lines: 8000000
# Processed lines: 8000000
# Processed lines: 7000000
# Processed lines: 8000000
# Processed lines: 7500000
# Processed lines: 7500000
# Processed lines: 7500000
# Processed lines: 8000000
# Processed lines: 7500000
# Processed lines: 8000000
# Processed lines: 7500000
# Processed lines: 8000000
# Processed lines: 7000000
# Processed lines: 8000000
# Processed lines: 7000000
# Processed lines: 8000000
# Processed lines: 7000000
# Processed lines: 8000000
# Processed lines: 8000000
# Processed lines: 8500000
# Processed lines: 7500000
# Processed lines: 8500000
# Processed lines: 7500000
# Processed lines: 7000000
# Processed lines: 8000000
# Processed lines: 8500000
# Processed lines: 8500000
# Processed lines: 8500000
# Processed lines: 7000000
# Processed lines: 8000000
# Processed lines: 8500000
# Processed lines: 8500000
# Processed lines: 7500000
# Processed lines: 7500000
# Processed lines: 8000000
# Processed lines: 8000000
# Processed lines: 8500000
# Processed lines: 8000000
# Processed lines: 8500000
# Processed lines: 8000000
# Processed lines: 8500000
# Processed lines: 8500000
# Processed lines: 8000000
# Processed lines: 8500000
# Processed lines: 7500000
# Processed lines: 7500000
# Processed lines: 8500000
# Processed lines: 7500000
# Processed lines: 9000000
# Processed lines: 8500000
# Processed lines: 9000000
# Processed lines: 8000000
# Processed lines: 8000000
# Processed lines: 9000000
# Processed lines: 9000000
# Processed lines: 9000000
# Processed lines: 8500000
# Processed lines: 9000000
# Processed lines: 7500000
# Processed lines: 8500000
# Processed lines: 9000000
# Processed lines: 7500000
# Processed lines: 8500000
# Processed lines: 8500000
# Processed lines: 8000000
# Processed lines: 9000000
# Processed lines: 9000000
# Processed lines: 8000000
# Processed lines: 8500000
# Processed lines: 9000000
# Processed lines: 8500000
# Processed lines: 9000000
# Processed lines: 9000000
# Processed lines: 8500000
# Processed lines: 9000000
# Processed lines: 8000000
# Processed lines: 8000000
# Processed lines: 9500000
# Processed lines: 9000000
# Processed lines: 8000000
# Processed lines: 9500000
# Processed lines: 9500000
# Processed lines: 8500000
# Processed lines: 9500000
# Processed lines: 9500000
# Processed lines: 9500000
# Processed lines: 8500000
# Processed lines: 9000000
# Processed lines: 9500000
# Processed lines: 9000000
# Processed lines: 8000000
# Processed lines: 9000000
# Processed lines: 9500000
# Processed lines: 9000000
# Processed lines: 8000000
# Processed lines: 9500000
# Processed lines: 8500000
# Processed lines: 9000000
# Processed lines: 9500000
# Processed lines: 8500000
# Processed lines: 9500000
# Processed lines: 9500000
# Processed lines: 9000000
# Processed lines: 9000000
# Processed lines: 9500000
# Processed lines: 10000000
# Processed lines: 8500000
# Processed lines: 8500000
# Processed lines: 9500000
# Processed lines: 10000000
# Processed lines: 8500000
# Processed lines: 10000000
# Processed lines: 10000000
# Processed lines: 10000000
# Processed lines: 10000000
# Processed lines: 10000000
# Processed lines: 9000000
# Processed lines: 9500000
# Processed lines: 9500000
# Processed lines: 9000000
# Processed lines: 9500000
# Processed lines: 10000000
# Processed lines: 9500000
# Processed lines: 10000000
# Processed lines: 8500000
# Processed lines: 10000000
# Processed lines: 10000000
# Processed lines: 9000000
# Processed lines: 9500000
# Processed lines: 10000000
# Processed lines: 8500000
# Processed lines: 9500000
# Processed lines: 9000000
# Processed lines: 9500000
# Processed lines: 10000000
# Processed lines: 10500000
# Processed lines: 10000000
# Processed lines: 10500000
# Processed lines: 10500000
# Processed lines: 9000000
# Processed lines: 9000000
# Processed lines: 10500000
# Processed lines: 10500000
# Processed lines: 10500000
# Processed lines: 9000000
# Processed lines: 10500000
# Processed lines: 10000000
# Processed lines: 10000000
# Processed lines: 9500000
# Processed lines: 9500000
# Processed lines: 10500000
# Processed lines: 10000000
# Processed lines: 10500000
# Processed lines: 10000000
# Processed lines: 10500000
# Processed lines: 10500000
# Processed lines: 10500000
# Processed lines: 10000000
# Processed lines: 9500000
# Processed lines: 9000000
# Processed lines: 10000000
# Processed lines: 11000000
# Processed lines: 10500000
# Processed lines: 9500000
# Processed lines: 9000000
# Processed lines: 10000000
# Processed lines: 11000000
# Processed lines: 11000000
# Processed lines: 10500000
# Processed lines: 11000000
# Processed lines: 11000000
# Processed lines: 11000000
# Processed lines: 11000000
# Processed lines: 9500000
# Processed lines: 9500000
# Processed lines: 10500000
# Processed lines: 9500000
# Processed lines: 10500000
# Processed lines: 10000000
# Processed lines: 11000000
# Processed lines: 11000000
# Processed lines: 10500000
# Processed lines: 11000000
# Processed lines: 11000000
# Processed lines: 10000000
# Processed lines: 10500000
# Processed lines: 11000000
# Processed lines: 10500000
# Processed lines: 11500000
# Processed lines: 10000000
# Processed lines: 10500000
# Processed lines: 11000000
# Processed lines: 9500000
# Processed lines: 10500000
# Processed lines: 10000000
# Processed lines: 11500000
# Processed lines: 11500000
# Processed lines: 11000000
# Processed lines: 9500000
# Processed lines: 11500000
# Processed lines: 11500000
# Processed lines: 11500000
# Processed lines: 11500000
# Processed lines: 11000000
# Processed lines: 10000000
# Processed lines: 11000000
# Processed lines: 10000000
# Processed lines: 11500000
# Processed lines: 10500000
# Processed lines: 10000000
# Processed lines: 11500000
# Processed lines: 11500000
# Processed lines: 11500000
# Processed lines: 11000000
# Processed lines: 11500000
# Processed lines: 11000000
# Processed lines: 10500000
# Processed lines: 12000000
# Processed lines: 11000000
# Processed lines: 11500000
# Processed lines: 11000000
# Processed lines: 12000000
# Processed lines: 10500000
# Processed lines: 12000000
# Processed lines: 12000000
# Processed lines: 11000000
# Processed lines: 12000000
# Processed lines: 10000000
# Processed lines: 11500000
# Processed lines: 12000000
# Processed lines: 10500000
# Processed lines: 12000000
# Processed lines: 10000000
# Processed lines: 11500000
# Processed lines: 11500000
# Processed lines: 12000000
# Processed lines: 12000000
# Processed lines: 10500000
# Processed lines: 12000000
# Processed lines: 12000000
# Processed lines: 10500000
# Processed lines: 11000000
# Processed lines: 11500000
# Processed lines: 12000000
# Processed lines: 12500000
# Processed lines: 10500000
# Processed lines: 11500000
# Processed lines: 11000000
# Processed lines: 12000000
# Processed lines: 12500000
# Processed lines: 12500000
# Processed lines: 11500000
# Processed lines: 12500000
# Processed lines: 12500000
# Processed lines: 12500000
# Processed lines: 11500000
# Processed lines: 11000000
# Processed lines: 12000000
# Processed lines: 11500000
# Processed lines: 12500000
# Processed lines: 10500000
# Processed lines: 11000000
# Processed lines: 12000000
# Processed lines: 12500000
# Processed lines: 12500000
# Processed lines: 12000000
# Processed lines: 10500000
# Processed lines: 12500000
# Processed lines: 12500000
# Processed lines: 12000000
# Processed lines: 12500000
# Processed lines: 13000000
# Processed lines: 11500000
# Processed lines: 11000000
# Processed lines: 11000000
# Processed lines: 12000000
# Processed lines: 13000000
# Processed lines: 13000000
# Processed lines: 12500000
# Processed lines: 11000000
# Processed lines: 11500000
# Processed lines: 13000000
# Processed lines: 13000000
# Processed lines: 13000000
# Processed lines: 12000000
# Processed lines: 12000000
# Processed lines: 12500000
# Processed lines: 13000000
# Processed lines: 11500000
# Processed lines: 12000000
# Processed lines: 11500000
# Processed lines: 11000000
# Processed lines: 13000000
# Processed lines: 12500000
# Processed lines: 13000000
# Processed lines: 12500000
# Processed lines: 13000000
# Processed lines: 13000000
# Processed lines: 22500000
# Processed lines: 23000000
# Processed lines: 24000000
# Processed lines: 23500000
# Processed lines: 24000000
# Processed lines: 24500000
# Processed lines: 22000000
# Finished processing child process. Exiting..
# Processed lines: 22500000
# Processed lines: 24500000
# Finished processing child process. Exiting..
# Processed lines: 22500000
# Processed lines: 22000000
# Processed lines: 24000000
# Processed lines: 23500000
# Processed lines: 23000000
# Processed lines: 23500000
# Processed lines: 24500000
# Finished processing child process. Exiting..
# Processed lines: 24000000
# Processed lines: 24500000
# Finished processing child process. Exiting..
# Processed lines: 22500000
# Processed lines: 23000000
# Processed lines: 22500000
# Processed lines: 23000000
# Processed lines: 24500000
# Processed lines: 24000000
# Finished processing child process. Exiting..
# Processed lines: 24000000
# Processed lines: 23500000
# Processed lines: 24500000
# Finished processing child process. Exiting..
# Processed lines: 23000000
# Processed lines: 23500000
# Processed lines: 23000000
# Processed lines: 23500000
# Processed lines: 24500000
# Finished processing child process. Exiting..
# Processed lines: 24500000
# Finished processing child process. Exiting..
# Processed lines: 24000000
# Processed lines: 23500000
# Processed lines: 24000000
# Processed lines: 23500000
# Processed lines: 24000000
# Processed lines: 24000000
# Processed lines: 24500000
# Finished processing child process. Exiting..
# Processed lines: 24000000
# Processed lines: 24500000
# Finished processing child process. Exiting..
# Processed lines: 24500000
# Finished processing child process. Exiting..
# Processed lines: 24500000
# Finished processing child process. Exiting..
# Processed lines: 24500000
# Finished processing child process. Exiting..
#
# Merging individual splitting reports into overall report: 'SRR11711272_1_val_1_bismark_bt2_pe_splitting_report.txt'
# Merging from these individual files:
# Now testing Bismark result file >SRR11711272_1_val_1_bismark_bt2_pe.bam< for positional sorting (which would be bad...)	SRR11711272_1_val_1_bismark_bt2_pe_splitting_report.txt.1
# SRR11711272_1_val_1_bismark_bt2_pe_splitting_report.txt.2
# SRR11711272_1_val_1_bismark_bt2_pe_splitting_report.txt.3
# SRR11711272_1_val_1_bismark_bt2_pe_splitting_report.txt.4
# SRR11711272_1_val_1_bismark_bt2_pe_splitting_report.txt.5
# SRR11711272_1_val_1_bismark_bt2_pe_splitting_report.txt.6
# SRR11711272_1_val_1_bismark_bt2_pe_splitting_report.txt.7
# SRR11711272_1_val_1_bismark_bt2_pe_splitting_report.txt.8
# SRR11711272_1_val_1_bismark_bt2_pe_splitting_report.txt.9
# SRR11711272_1_val_1_bismark_bt2_pe_splitting_report.txt.10
# SRR11711272_1_val_1_bismark_bt2_pe_splitting_report.txt.11
# SRR11711272_1_val_1_bismark_bt2_pe_splitting_report.txt.12
# SRR11711272_1_val_1_bismark_bt2_pe_splitting_report.txt.13
# SRR11711272_1_val_1_bismark_bt2_pe_splitting_report.txt.14
# SRR11711272_1_val_1_bismark_bt2_pe_splitting_report.txt.15
# SRR11711272_1_val_1_bismark_bt2_pe_splitting_report.txt.16
# SRR11711272_1_val_1_bismark_bt2_pe_splitting_report.txt.17
# SRR11711272_1_val_1_bismark_bt2_pe_splitting_report.txt.18
# ...
# Now testing Bismark result file >SRR11711273_1_val_1_bismark_bt2_pe.bam< for positional sorting (which would be bad...)	SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.1
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.2
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.3
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.4
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.5
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.6
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.7
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.8
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.9
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.10
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.11
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.12
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.13
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.14
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.15
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.16
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.17
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.18
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.19
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.20
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.21
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.22
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.23
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.24
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.25
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.26
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.27
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.28
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.29
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.30
# Processed 6784977 lines in total
# Total number of methylation call strings processed: 13569954
#
# Final Cytosine Methylation Report
# =================================
# Total number of C's analysed:	93345981
#
# Total methylated C's in CpG context:	6652839
# Total methylated C's in CHG context:	244172
# Total methylated C's in CHH context:	682610
#
# Total C to T conversions in CpG context:	6679675
# Total C to T conversions in CHG context:	20695055
# Total C to T conversions in CHH context:	58391630
#
# C methylated in CpG context:	49.9%
# C methylated in CHG context:	1.2%
# C methylated in CHH context:	1.2%
#
#
#
# Merging individual M-bias reports into overall M-bias statistics from these 30 individual files:
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.1.mbias
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.2.mbias
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.3.mbias
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.4.mbias
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.5.mbias
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.6.mbias
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.7.mbias
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.8.mbias
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.9.mbias
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.10.mbias
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.11.mbias
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.12.mbias
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.13.mbias
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.14.mbias
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.15.mbias
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.16.mbias
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.17.mbias
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.18.mbias
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.19.mbias
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.20.mbias
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.21.mbias
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.22.mbias
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.23.mbias
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.24.mbias
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.25.mbias
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.26.mbias
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.27.mbias
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.28.mbias
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.29.mbias
# SRR11711273_1_val_1_bismark_bt2_pe_splitting_report.txt.30.mbias
# Determining maximum read lengths for M-Bias plots
# Maximum read length of Read 1: 32
# Maximum read length of Read 2: 28
#
# Perl module GD::Graph::lines is not installed, skipping drawing M-bias plots (only writing out M-bias plot table)
# Determining maximum read lengths for M-Bias plots
# Maximum read length of Read 1: 32
# Maximum read length of Read 2: 28
#
# Perl module GD::Graph::lines is not installed, skipping drawing M-bias plots (only writing out M-bias plot table)
# Deleting unused files ...
#
# CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz contains data ->	kept
# CpG_CTOT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz was empty ->	deleted
# CpG_CTOB_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz was empty ->	deleted
# CpG_OB_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz contains data ->	kept
# CHG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz contains data ->	kept
# CHG_CTOT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz was empty ->	deleted
# CHG_CTOB_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz was empty ->	deleted
# CHG_OB_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz contains data ->	kept
# CHH_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz contains data ->	kept
# CHH_CTOT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz was empty ->	deleted
# CHH_CTOB_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz was empty ->	deleted
# CHH_OB_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz contains data ->	kept
#
#
# Using these input files: CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz CpG_OB_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz CHG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz CHG_OB_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz CHH_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz CHH_OB_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz
#
# Summary of parameters for bismark2bedGraph conversion:
# ======================================================
# bedGraph output:		SRR11711273_1_val_1_bismark_bt2_pe.bedGraph.gz
# output directory:		><
# remove whitespaces:		no
# CX context:			no (CpG context only, default)
# No-header selected:		no
# Sorting method:			Unix sort-based (smaller memory footprint, but slower)
# Sort buffer size:		2G
# Coverage threshold:		1
# =============================================================================
# Methylation information will now be written into a bedGraph and coverage file
# =============================================================================
#
# Using the following files as Input:
# /data_gilbert/home/aarab/Projects/Decitabine-treatment/Bisulfite-seq/bam/CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz	/data_gilbert/home/aarab/Projects/Decitabine-treatment/Bisulfite-seq/bam/CpG_OB_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz
# Writing bedGraph to file: SRR11711273_1_val_1_bismark_bt2_pe.bedGraph.gz
# Also writing out a coverage file including counts methylated and unmethylated residues to file: SRR11711273_1_val_1_bismark_bt2_pe.bismark.cov.gz
#
# Now writing methylation information for file >>CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz<< to individual files for each chromosome
# Finished writing out individual chromosome files for CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz
# Now writing methylation information for file >>CpG_OB_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz<< to individual files for each chromosome
# Finished writing out individual chromosome files for CpG_OB_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz
#
# Collecting temporary chromosome file information... Processing the following input file(s):
# CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr6.methXtractor.temp
# CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr10.methXtractor.temp
# CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr5.methXtractor.temp
# CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr14.methXtractor.temp
# CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr7.methXtractor.temp
# CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr12.methXtractor.temp
# CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr15.methXtractor.temp
# CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr11.methXtractor.temp
# CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr17.methXtractor.temp
# CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr18.methXtractor.temp
# CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr8.methXtractor.temp
# CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr1.methXtractor.temp
# CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr22.methXtractor.temp
# CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr19.methXtractor.temp
# CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr3.methXtractor.temp
# CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr9.methXtractor.temp
# CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr13.methXtractor.temp
# CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr20.methXtractor.temp
# CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr2.methXtractor.temp
# CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr16.methXtractor.temp
# CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr21.methXtractor.temp
# CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchrX.methXtractor.temp
# CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr4.methXtractor.temp
# CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchrM.methXtractor.temp
# CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchrY.methXtractor.temp
#
# Sorting input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr1.methXtractor.temp by positions (using -S of 2G)
# Successfully deleted the temporary input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr1.methXtractor.temp
#
# Sorting input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr10.methXtractor.temp by positions (using -S of 2G)
# Successfully deleted the temporary input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr10.methXtractor.temp
#
# Sorting input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr11.methXtractor.temp by positions (using -S of 2G)
# Successfully deleted the temporary input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr11.methXtractor.temp
#
# Sorting input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr12.methXtractor.temp by positions (using -S of 2G)
# Successfully deleted the temporary input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr12.methXtractor.temp
#
# Sorting input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr13.methXtractor.temp by positions (using -S of 2G)
# Successfully deleted the temporary input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr13.methXtractor.temp
#
# Sorting input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr14.methXtractor.temp by positions (using -S of 2G)
# Successfully deleted the temporary input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr14.methXtractor.temp
#
# Sorting input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr15.methXtractor.temp by positions (using -S of 2G)
# Successfully deleted the temporary input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr15.methXtractor.temp
#
# Sorting input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr16.methXtractor.temp by positions (using -S of 2G)
# Successfully deleted the temporary input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr16.methXtractor.temp
#
# Sorting input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr17.methXtractor.temp by positions (using -S of 2G)
# Successfully deleted the temporary input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr17.methXtractor.temp
#
# Sorting input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr18.methXtractor.temp by positions (using -S of 2G)
# Successfully deleted the temporary input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr18.methXtractor.temp
#
# Sorting input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr19.methXtractor.temp by positions (using -S of 2G)
# Successfully deleted the temporary input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr19.methXtractor.temp
#
# Sorting input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr2.methXtractor.temp by positions (using -S of 2G)
# Successfully deleted the temporary input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr2.methXtractor.temp
#
# Sorting input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr20.methXtractor.temp by positions (using -S of 2G)
# Successfully deleted the temporary input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr20.methXtractor.temp
#
# Sorting input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr21.methXtractor.temp by positions (using -S of 2G)
# Successfully deleted the temporary input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr21.methXtractor.temp
#
# Sorting input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr22.methXtractor.temp by positions (using -S of 2G)
# Successfully deleted the temporary input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr22.methXtractor.temp
#
# Sorting input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr3.methXtractor.temp by positions (using -S of 2G)
# Successfully deleted the temporary input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr3.methXtractor.temp
#
# Sorting input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr4.methXtractor.temp by positions (using -S of 2G)
# Successfully deleted the temporary input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr4.methXtractor.temp
#
# Sorting input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr5.methXtractor.temp by positions (using -S of 2G)
# Successfully deleted the temporary input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr5.methXtractor.temp
#
# Sorting input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr6.methXtractor.temp by positions (using -S of 2G)
# Successfully deleted the temporary input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr6.methXtractor.temp
#
# Sorting input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr7.methXtractor.temp by positions (using -S of 2G)
# Successfully deleted the temporary input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr7.methXtractor.temp
#
# Sorting input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr8.methXtractor.temp by positions (using -S of 2G)
# Successfully deleted the temporary input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr8.methXtractor.temp
#
# Sorting input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr9.methXtractor.temp by positions (using -S of 2G)
# Successfully deleted the temporary input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchr9.methXtractor.temp
#
# Sorting input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchrM.methXtractor.temp by positions (using -S of 2G)
# Successfully deleted the temporary input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchrM.methXtractor.temp
#
# Sorting input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchrX.methXtractor.temp by positions (using -S of 2G)
# Successfully deleted the temporary input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchrX.methXtractor.temp
#
# Sorting input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchrY.methXtractor.temp by positions (using -S of 2G)
# Successfully deleted the temporary input file CpG_OT_SRR11711273_1_val_1_bismark_bt2_pe.txt.gz.chrchrY.methXtractor.temp
#
# Finished BedGraph conversion ...

# %% [markdown]
# <!-- __(V) Running bismark2report__ -->
#
# __(VI) Running bismark2summary__

# %%
# %%bash
# cd bismark/
# bismark2summary
# cd ../
# Out:
# No Bismark/Bowtie2 single-end BAM files detected
# Found Bismark/Bowtie2 paired-end files
# No Bismark/HISAT2 single-end BAM files detected
# No Bismark/HISAT2 paired-end BAM files detected
#
# Generating Bismark summary report from 2 Bismark BAM file(s)...
# >> Reading from Bismark report: SRR11711272_1_val_1_bismark_bt2_PE_report.txt
# No deduplication report present, skipping...
# >> Reading from Bismark report: SRR11711273_1_val_1_bismark_bt2_PE_report.txt
# No deduplication report present, skipping...
#
# Wrote Bismark project summary to >> bismark_summary_report.html <<

# %%
# %%bash
# for bam in bismark/*bam; do
#     out=${bam/.bam/.srt.bam}
#     cm="samtools sort -@ 24 -o $out $bam"
#     echo $cm
#     $cm;
#     wait
# done

# %% [markdown]
# #

# %%
# !date
# Out:
# Tue Mar  8 10:20:19 PST 2022
